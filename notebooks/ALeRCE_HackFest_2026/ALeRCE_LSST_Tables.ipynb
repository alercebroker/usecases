# %% [markdown]
# # ALeRCE LSST, database tables
#
# ```Author: Alejandra Muñoz Arancibia. Last updated: 260303```
#
# This notebook introduces the Rubin alert stream data (as well as derived properties) that are stored in the ALeRCE database, showing all tables that are relevant for LSST. We use the pyvo package to execute Astronomical Data Query Language (ADQL) queries to the ALeRCE Table Access Protocol (TAP) service, and display output tables as pandas dataframes.
#
# *It is highly recommended that you try this notebook in Google Colab using the following [link](https://colab.research.google.com/github/alercebroker/usecases/blob/master/notebooks/ALeRCE_HackFest_2026/ALeRCE_LSST_Tables.ipynb).* This will avoid you from having to sort out library installation problems and focus on the contents of the tutorial. You can try installing the dependencies later in your own system.

# %% [markdown]
# # Table of contents
#
# * [Before starting](#before)
#     * [Some settings](#settings)
#     * [Connect to ALeRCE data via TAP](#tap)
# * [The ALeRCE multisurvey database](#multisurvey)
# * [Types of object identifiers](#sid)
# * [Differences with respect to the Rubin alert schema](#schema_differences)
#     * [Renamed object identifiers](#oid)
#     * [Mapped photometric band identifiers](#band)
#     * [Renamed measurement identifiers, splitted tables](#measurement_id)
#     * [Tables that store latest record only](#tables_latest)
# * [Important remarks](#remarks)
#     * [About data types](#int64_ids)
#     * [About column names in ADQL queries](#adql_case)
# * [ALeRCE data tables, their columns and indexes](#tables_full)

# %% [markdown]
# ## Before starting <a class='anchor' id='before'></a>

# %% [markdown]
# ### Some settings <a class='anchor' id='settings'></a>

# %% [markdown]
# Load libraries

# %%
#!pip install pyvo

# %%
import pandas as pd
import pyvo as vo

# %%
pd.set_option('display.max_colwidth', 1000)

# %% [markdown]
# ### Connect to ALeRCE data via TAP <a class='anchor' id='tap'></a>

# %% [markdown]
# We connect to the [ALeRCE TAP service](https://tap.alerce.online/) as

# %%
alerce_tap = vo.dal.TAPService('https://tap.alerce.online/tap')

# %% [markdown]
# ## The ALeRCE multisurvey database <a class='anchor' id='multisurvey'></a>

# %% [markdown]
# We save Rubin alert stream data in a multisurvey database. We distinguish among data sources by using the field ```tid```, for "telescope identifier". LSST (and more generally, all Rubin data observed with the Simonyi telescope) has ```tid = 1```.

# %%
tid = 1

# %% [markdown]
# We store both data from the alerts (e.g. detections, forced photometry points) and quantities computed by the ALeRCE pipeline (e.g. mean coordinates, first and last detection dates, features, probabilities). We distinguish between three types of tables:

# %% [markdown]
# 1. Tables that are common to all surveys:

# %%
common_tables = [
    'object',
    'detection',
    'forced_photometry',
    'xmatch',
    'allwise',
    'feature',
    'probability',
]

# %% [markdown]
# 2. Tables that are survey-specific. For LSST, these are:

# %%
lsst_tables = [
    'lsst_detection',
    'lsst_ss_detection', # ssSource in alert schema
    'lsst_forced_photometry',
    'lsst_dia_object', # diaObject in alert schema
    'lsst_mpc_orbits', # mpc_orbits in alert schema
]

# %% [markdown]
# 3. Lookup tables (LUTs) that store mappings between integer identifiers and original names:

# %%
lookup_tables = [
    'sid_lut',
    'band',
    'catalog_id_lut',
    'feature_name_lut',
    'feature_version_lut',
    'classifier',
    'taxonomy',
]

# %% [markdown]
# The following TAP query provides a description for each of these tables:

# %%
data_tables = common_tables + lsst_tables + lookup_tables

query = '''
SELECT
    table_name, description
FROM
    tap_schema.tables
WHERE
    table_name in (%s)
''' % ','.join(["'alerce_tap.%s'" % table_name for table_name in data_tables])

result = alerce_tap.search(query).to_table().to_pandas()
result['index'] = result['table_name'].str.replace('alerce_tap.', '')
result = result.set_index('index').loc[
   data_tables].reset_index().drop(columns='index').copy()
result['description'] = result['description'].str.replace('\n', ' ')
display(result)
# Out:
#                            table_name  \
# 0                   alerce_tap.object
# 1                alerce_tap.detection
# 2        alerce_tap.forced_photometry
# 3                   alerce_tap.xmatch
# 4                  alerce_tap.allwise
# 5                  alerce_tap.feature
# 6              alerce_tap.probability
# 7           alerce_tap.lsst_detection
# 8        alerce_tap.lsst_ss_detection
# 9   alerce_tap.lsst_forced_photometry
# 10         alerce_tap.lsst_dia_object
# 11         alerce_tap.lsst_mpc_orbits
# 12                 alerce_tap.sid_lut
# 13                    alerce_tap.band
# 14          alerce_tap.catalog_id_lut
# 15        alerce_tap.feature_name_lut
# 16     alerce_tap.feature_version_lut
# 17              alerce_tap.classifier
# 18                alerce_tap.taxonomy
#
#                                                                                                                                                                                                                                                                                                                                                                                                     description
# 0    This table contains aggregated information about astronomical  objects observed in multiple surveys. Each record corresponds  to a unique object identified by its position and survey.  The table includes astrometric properties (mean RA/Dec),  detection statistics (number of detections, forced photometry measurements, non-detections),  and temporal coverage (first and last observation dates).
# 1                                                                                                                                       Generic detection table containing basic information for all detections across multiple surveys, including position, observation time, and photometric band. For detailed survey-specific detection properties, see the corresponding survey-specific detection tables.
# 2                                                                                                                                                                                  Generic forced photometry measurements across multiple surveys, containing basic position and timing information. For detailed survey-specific forced photometry measurements, see the corresponding survey-specific tables.
# 3                                                                                                                                                                                                                                              Cross-match results linking objects to external astronomical catalogs, including angular separation and the matched object's identifier in the external catalog.
# 4                                                                                                                                                                                              Photometric data from the AllWISE catalog for cross-matched objects, including WISE mid-infrared magnitudes (W1-W4 at 3.4, 4.6, 12, 22 microns) and 2MASS near-infrared magnitudes (J, H, K) with uncertainties.
# 5                                                                                                                                                                                                                            Computed features from light curves for each object and photometric band, including time-series statistics and variability metrics used as inputs to machine learning classifiers.
# 6                                                                                                                                                                                                                     Classification probabilities for each object assigned by machine learning classifiers, including probability values, rankings among all classes, and the timestamp of the classification.
# 7                                                                             Individual LSST Difference Image Analysis sources, containing detailed measurements from difference imaging including PSF photometry, aperture photometry, trail and dipole fitting for moving objects, shape moments, forced photometry on science and template images, and extensive quality flags for pixels and measurements.
# 8                                                                                                                                                    Individual LSST detections associated with solar system objects, including observing geometry (phase angle, elongation, ranges), ephemeris predictions, ephemeris offsets (O-C residuals), and heliocentric/topocentric state vectors in ICRS coordinates.
# 9                                                                                                                                                                                                            LSST forced photometry measurements extracted at DIA object positions on individual visit images, including PSF flux and forced science flux with uncertainties, and temporal processing metadata.
# 10                                                                                                                     Summary catalog of transient and variable objects detected in LSST difference imaging. Contains aggregated photometric measurements across all bands (u, g, r, i, z, y), including PSF flux statistics, forced photometry fluxes, and temporal information for each detected DIA object.
# 11                                                                                                                                                Complete orbital solutions from the Minor Planet Center for solar system objects, including Keplerian orbital elements, non-gravitational parameters (Yarkovsky, SRP, A1-A3), observational arc statistics, fit quality metrics, and Earth MOID calculations.
# 12                                                                                                                                                                                                                                                                                                                Lookup table mapping survey identifiers to survey names and associated telescope identifiers.
# 13                                                                                                                                                                                                                                                                                                Lookup table defining photometric bands (filters) for each survey, including band names and display ordering.
# 14                                                                                                                                                                                                                                                                                             Lookup table mapping catalog identifiers to the names of external astronomical catalogs used for cross-matching.
# 15                                                                                                                                                                                                                                                                                Lookup table mapping feature identifiers to descriptive feature names for light curve features used in object classification.
# 16                                                                                                                                                                                                                                                                                                     Lookup table mapping version identifiers to version names for light curve feature extraction algorithms.
# 17                                                                                                                                                                                                                                                        Metadata for machine learning classifiers used to classify astronomical objects, including classifier name, version, and associated telescope/survey.
# 18                                                                                                                                                                                                                                         Taxonomy of astronomical object classes used by classifiers, including class names, display ordering, and the associated classifier producing these classifications.

# %% [markdown]
# ## Types of object identifiers <a class='anchor' id='sid'></a>

# %% [markdown]
# In LSST alerts, astrophysical objects have different identifiers depending on what they are associated to (see the Data Products Definition Document [DPDD](https://ls.st/lse-163) for details). Non-moving objects (e.g. supernovae, active galactic nuclei, variable stars) are associated to diaObjects, while known Solar System moving objects (e.g. asteroids) are associated to ssObjects. Identifiers for diaObjects and ssObjects are generated independent of each other by the LSST pipelines. We distinguish among them using the field ```sid```, for "survey identifier", so that
#
# ```sid = 1``` for diaObjects, and
#
# ```sid = 2``` for ssObjects. These are listed in the ```sid_lut``` table:

# %%
table_name = 'sid_lut'

query = '''
SELECT
    sid, tid, survey_name
FROM
    alerce_tap.%s
WHERE
    tid = %d
''' % (table_name, tid)

result = alerce_tap.search(query).to_table().to_pandas()
display(result)
# Out:
#    sid  tid      survey_name
# 0    1    1  LSST DIA Object
# 1    2    1   LSST SS Object

# %% [markdown]
# It is expected that still-unknown moving objects will initially be associated to diaObjects. Note that at times a non-moving object may be associated in proximity to a known moving object (see below).

# %% [markdown]
# ## Differences with respect to the Rubin alert schema <a class='anchor' id='schema_differences'></a>

# %% [markdown]
# LSST data are stored in the ALeRCE database following the [Alert Production Database (APDB) schema](https://sdm-schemas.lsst.io/apdb.html) for most of the fields, with some exceptions detailed below:

# %% [markdown]
# ### Renamed object identifiers <a class='anchor' id='oid'></a>

# %% [markdown]
# We use the field ```oid``` as the identifier for each object. This ```oid``` is defined in different ways depending on the availability of diaObject information in the alert, so that
#
# ```oid = diaObjectId``` and ```sid = 1``` for objects that have diaObject information, and
#
# ```oid = ssObjectId``` and ```sid = 2``` if they only have ssObject information. In case an object has both identifiers (e.g. a known Solar System object was identified at a small angular distance from a non-moving object), we adopt ```oid = diaObjectId``` and ```sid = 1``` while still saving both their diaObject and ssSource data in the respective tables.
#
# It is very unlikely that an object's diaObjectId is identical to another object's ssObjectId, but we still suggest to always query for the pair ```(oid, sid)``` instead of only using ```oid```.
#
# The field ```oid``` appears in the following tables: ```object```, ```detection```, ```lsst_detection```, ```forced_photometry```, ```lsst_forced_photometry```, ```lsst_dia_object```, ```xmatch```, ```feature```, and ```probability```.

# %% [markdown]
# ### Mapped photometric band identifiers <a class='anchor' id='band'></a>

# %% [markdown]
# Instead of saving band names as they come in alerts, we use integer identifiers and save them in the field ```band```. The mapping between band name and identifier for each ```sid``` is in the ```band``` table:

# %%
table_name = 'band'

query = '''
SELECT
    sid, tid, band, band_name, band_order
FROM
    alerce_tap.%s
WHERE
    tid = %d
ORDER BY
    sid ASC, band_order ASC
''' % (table_name, tid)

result = alerce_tap.search(query).to_table().to_pandas()
display(result)
# Out:
#     sid  tid  band band_name  band_order
# 0     1    1     6         u           0
# 1     1    1     1         g           1
# 2     1    1     2         r           2
# 3     1    1     3         i           3
# 4     1    1     4         z           4
# 5     1    1     5         y           5
# 6     2    1     6         u           0
# 7     2    1     1         g           1
# 8     2    1     2         r           2
# 9     2    1     3         i           3
# 10    2    1     4         z           4
# 11    2    1     5         y           5

# %% [markdown]
# The field ```band``` appears in the following tables: ```band```, ```detection```, ```lsst_detection```, ```forced_photometry```, ```lsst_forced_photometry```, and ```feature```.

# %% [markdown]
# ### Renamed measurement identifiers, splitted tables <a class='anchor' id='measurement_id'></a>

# %% [markdown]
# We call the identifier for each epoch in every survey as ```measurement_id```. For LSST, this means both field ```diaSourceId``` for detections and field ```diaForcedSourceId``` for forced photometry points are renamed ```measurement_id``` in our database. We also rename the mid-visit time for each epoch from field ```midpointMjdTai``` to ```mjd```.
#
# Note that we split the diaSource alert field in two tables: ```detection``` (common to all surveys) and ```lsst_detection```. The full table can be recovered joining these two on ```(oid, sid, measurement_id)```. Similarly, we split the prvDiaForcedSources alert field in tables ```forced_photometry``` (common to all surveys) and ```lsst_forced_photometry```.
#
# Field ```measurement_id``` appears in the following tables: ```band```, ```detection```, ```lsst_detection```, ```ss_detection```, ```forced_photometry```, and ```lsst_forced_photometry```. Field ```mjd``` appears in tables ```detection``` and ```forced_photometry```.

# %% [markdown]
# ### Tables that store latest record only <a class='anchor' id='tables_latest'></a>

# %% [markdown]
# For each object, we only keep the latest record ingested by our pipeline for alert fields diaObject and mpc_orbits. These are saved in tables ```lsst_dia_object``` and ```lsst_mpc_orbits``` respectively.

# %% [markdown]
# ## Important remarks <a class='anchor' id='remarks'></a>

# %% [markdown]
# ### About data types <a class='anchor' id='int64_ids'></a>

# %% [markdown]
# Note that identifiers for objects and epochs (i.e. fields ```oid``` and ```measurement_id```) are stored as long integers, so caution is advised when manipulating these columns. In particular, some operations may implicitly convert long integer data as float if NaN values are also present (e.g., when converting a dictionary to a pandas dataframe column), with the unintended consequence of modifying original values by some digits. For the pandas package, we suggest to include the pyarrow functionality when reading input files (by adding ```dtype_backend='pyarrow'``` as parameter), and convert pandas columns from ```int64``` type to ```Int64``` (or ```int64[pyarrow]```) when needed.

# %% [markdown]
# ### About column names in ADQL queries <a class='anchor' id='adql_case'></a>

# %% [markdown]
# Note that while we store LSST schema names with the same capitalization as the APDB (e.g. we save column ```psfFlux```), ADQL is case-insensitive by default, so ADQL queries to the ALeRCE TAP service return all fields in lower case (e.g. we retrieve the column as ```psfflux```). Caution is advised when working with tables obtained by mixed means (e.g. using ADQL outputs together with RSP catalogs, or with the ALeRCE python client outputs). We suggest converting all relevant column names to lower case, or map ADQL output columns to their original (mixed case) names instead.

# %% [markdown]
# ## ALeRCE data tables, their columns and indexes <a class='anchor' id='tabs_full'></a>

# %% [markdown]
# Here we use TAP queries to get table columns and indexes as

# %%
def show_table_info(table_name):
    query = '''
    SELECT
        table_name, column_name, description,
        unit, datatype, indexed
    FROM
        tap_schema.columns
    WHERE
        table_name = 'alerce_tap.%s'
    ''' % table_name
    
    result = alerce_tap.search(query).to_table().to_pandas()

    print(table_name)
    pd.set_option('display.max_rows', None)
    display(result)
    pd.set_option('display.max_rows', 30)

# %% [markdown]
# The main table and starting point in the ALeRCE database is the ```object``` table. We query this table to find objects by their ```oid```'s in a given survey, or to perform cone searches when such ```oid```'s are unknown. This table also allows filtering by properties like number of detections, as well as by MJD dates of first and last detections in the alert stream. Note that the ```object``` table is updated to the latest alert ingested by our pipeline, so there is always one row per ```oid```.

# %%
table_name = 'object'
show_table_info(table_name)
# Out:
# object
#            table_name   column_name  \
# 0   alerce_tap.object           oid
# 1   alerce_tap.object           tid
# 2   alerce_tap.object           sid
# 3   alerce_tap.object        meanra
# 4   alerce_tap.object       meandec
# 5   alerce_tap.object       sigmara
# 6   alerce_tap.object      sigmadec
# 7   alerce_tap.object      firstmjd
# 8   alerce_tap.object       lastmjd
# 9   alerce_tap.object      deltamjd
# 10  alerce_tap.object         n_det
# 11  alerce_tap.object      n_forced
# 12  alerce_tap.object     n_non_det
# 13  alerce_tap.object  created_date
# 14  alerce_tap.object  updated_date
#
#                                      description unit datatype  indexed
# 0                     Internal object identifier          long        1
# 1                           Telescope identifier         short        0
# 2                              Survey identifier         short        1
# 3                    Mean right ascension (ICRS)  deg   double        1
# 4                        Mean declination (ICRS)  deg   double        1
# 5          Standard deviation of right ascension  deg   double        0
# 6              Standard deviation of declination  deg   double        0
# 7                          First observation MJD    d   double        1
# 8                           Last observation MJD    d   double        1
# 9   Time span between first and last observation    d   double        0
# 10                          Number of detections           int        1
# 11      Number of forced photometry measurements           int        0
# 12                      Number of non-detections           int        0
# 13              Date when the record was created          char        0
# 14         Date when the record was last updated          char        0

# %% [markdown]
# We can use known object identifiers to find epoch data in the following tables:

# %%
data_tables = [
    'detection',
    'lsst_detection',
    'lsst_ss_detection',
    'forced_photometry',
    'lsst_forced_photometry',
]

# %%
for table_name in data_tables:
    show_table_info(table_name)
# Out:
# detection
#              table_name     column_name              description unit  \
# 0  alerce_tap.detection             oid        Object identifier
# 1  alerce_tap.detection             sid        Survey identifier
# 2  alerce_tap.detection  measurement_id   Measurement identifier
# 3  alerce_tap.detection             mjd     Modified Julian Date    d
# 4  alerce_tap.detection              ra          Right ascension  deg
# 5  alerce_tap.detection             dec              Declination  deg
# 6  alerce_tap.detection            band         Photometric band
# 7  alerce_tap.detection    created_date  Date record was created
#
#   datatype  indexed
# 0     long        1
# 1    short        1
# 2     long        1
# 3   double        0
# 4   double        1
# 5   double        1
# 6    short        0
# 7     char        0
# lsst_detection
#                    table_name                         column_name  \
# 0   alerce_tap.lsst_detection                                 oid
# 1   alerce_tap.lsst_detection                                 sid
# 2   alerce_tap.lsst_detection                      measurement_id
# 3   alerce_tap.lsst_detection                   parentdiasourceid
# 4   alerce_tap.lsst_detection                               visit
# 5   alerce_tap.lsst_detection                            detector
# 6   alerce_tap.lsst_detection                         diaobjectid
# 7   alerce_tap.lsst_detection                          ssobjectid
# 8   alerce_tap.lsst_detection                               raerr
# 9   alerce_tap.lsst_detection                              decerr
# 10  alerce_tap.lsst_detection                          ra_dec_cov
# 11  alerce_tap.lsst_detection                                   x
# 12  alerce_tap.lsst_detection                                xerr
# 13  alerce_tap.lsst_detection                                   y
# 14  alerce_tap.lsst_detection                                yerr
# 15  alerce_tap.lsst_detection                       centroid_flag
# 16  alerce_tap.lsst_detection                              apflux
# 17  alerce_tap.lsst_detection                           apfluxerr
# 18  alerce_tap.lsst_detection                         apflux_flag
# 19  alerce_tap.lsst_detection       apflux_flag_aperturetruncated
# 20  alerce_tap.lsst_detection                          isnegative
# 21  alerce_tap.lsst_detection                                 snr
# 22  alerce_tap.lsst_detection                             psfflux
# 23  alerce_tap.lsst_detection                          psffluxerr
# 24  alerce_tap.lsst_detection                              psflnl
# 25  alerce_tap.lsst_detection                             psfchi2
# 26  alerce_tap.lsst_detection                            psfndata
# 27  alerce_tap.lsst_detection                        psfflux_flag
# 28  alerce_tap.lsst_detection                   psfflux_flag_edge
# 29  alerce_tap.lsst_detection           psfflux_flag_nogoodpixels
# 30  alerce_tap.lsst_detection                           trailflux
# 31  alerce_tap.lsst_detection                        trailfluxerr
# 32  alerce_tap.lsst_detection                             trailra
# 33  alerce_tap.lsst_detection                          trailraerr
# 34  alerce_tap.lsst_detection                            traildec
# 35  alerce_tap.lsst_detection                         traildecerr
# 36  alerce_tap.lsst_detection                         traillength
# 37  alerce_tap.lsst_detection                      traillengtherr
# 38  alerce_tap.lsst_detection                          trailangle
# 39  alerce_tap.lsst_detection                       trailangleerr
# 40  alerce_tap.lsst_detection                           trailchi2
# 41  alerce_tap.lsst_detection                          trailndata
# 42  alerce_tap.lsst_detection                     trail_flag_edge
# 43  alerce_tap.lsst_detection                      dipolemeanflux
# 44  alerce_tap.lsst_detection                   dipolemeanfluxerr
# 45  alerce_tap.lsst_detection                      dipolefluxdiff
# 46  alerce_tap.lsst_detection                   dipolefluxdifferr
# 47  alerce_tap.lsst_detection                        dipolelength
# 48  alerce_tap.lsst_detection                         dipoleangle
# 49  alerce_tap.lsst_detection                          dipolechi2
# 50  alerce_tap.lsst_detection                         dipolendata
# 51  alerce_tap.lsst_detection                         scienceflux
# 52  alerce_tap.lsst_detection                      sciencefluxerr
# 53  alerce_tap.lsst_detection                 forced_psfflux_flag
# 54  alerce_tap.lsst_detection            forced_psfflux_flag_edge
# 55  alerce_tap.lsst_detection    forced_psfflux_flag_nogoodpixels
# 56  alerce_tap.lsst_detection                        templateflux
# 57  alerce_tap.lsst_detection                     templatefluxerr
# 58  alerce_tap.lsst_detection                                 ixx
# 59  alerce_tap.lsst_detection                                 iyy
# 60  alerce_tap.lsst_detection                                 ixy
# 61  alerce_tap.lsst_detection                              ixxpsf
# 62  alerce_tap.lsst_detection                              iyypsf
# 63  alerce_tap.lsst_detection                              ixypsf
# 64  alerce_tap.lsst_detection                          shape_flag
# 65  alerce_tap.lsst_detection                shape_flag_no_pixels
# 66  alerce_tap.lsst_detection            shape_flag_not_contained
# 67  alerce_tap.lsst_detection            shape_flag_parent_source
# 68  alerce_tap.lsst_detection                        extendedness
# 69  alerce_tap.lsst_detection                         reliability
# 70  alerce_tap.lsst_detection                            isdipole
# 71  alerce_tap.lsst_detection                  dipolefitattempted
# 72  alerce_tap.lsst_detection                 timeprocessedmjdtai
# 73  alerce_tap.lsst_detection                 timewithdrawnmjdtai
# 74  alerce_tap.lsst_detection                            bboxsize
# 75  alerce_tap.lsst_detection                          pixelflags
# 76  alerce_tap.lsst_detection                      pixelflags_bad
# 77  alerce_tap.lsst_detection                       pixelflags_cr
# 78  alerce_tap.lsst_detection                 pixelflags_crcenter
# 79  alerce_tap.lsst_detection                     pixelflags_edge
# 80  alerce_tap.lsst_detection                   pixelflags_nodata
# 81  alerce_tap.lsst_detection             pixelflags_nodatacenter
# 82  alerce_tap.lsst_detection             pixelflags_interpolated
# 83  alerce_tap.lsst_detection       pixelflags_interpolatedcenter
# 84  alerce_tap.lsst_detection                 pixelflags_offimage
# 85  alerce_tap.lsst_detection                pixelflags_saturated
# 86  alerce_tap.lsst_detection          pixelflags_saturatedcenter
# 87  alerce_tap.lsst_detection                  pixelflags_suspect
# 88  alerce_tap.lsst_detection            pixelflags_suspectcenter
# 89  alerce_tap.lsst_detection                   pixelflags_streak
# 90  alerce_tap.lsst_detection             pixelflags_streakcenter
# 91  alerce_tap.lsst_detection                 pixelflags_injected
# 92  alerce_tap.lsst_detection           pixelflags_injectedcenter
# 93  alerce_tap.lsst_detection        pixelflags_injected_template
# 94  alerce_tap.lsst_detection  pixelflags_injected_templatecenter
# 95  alerce_tap.lsst_detection                         glint_trail
# 96  alerce_tap.lsst_detection                           has_stamp
# 97  alerce_tap.lsst_detection                        created_date
#
#                                                                                                                                                                                                                                                                          description  \
# 0                                                                                                                                                                                                                                                                  Object identifier
# 1                                                                                                                                                                                                                                                                  Survey identifier
# 2                                                                                                                                                                                                                                                Unique identifier of this DiaSource
# 3                                                                                                                                                                                                          Id of the parent diaSource this diaSource has been deblended from, if any
# 4                                                                                                                                                                                                                                                                       Visit number
# 5                                                                                                                                                                                                                                                                    Detector number
# 6                                                                                                                     Id of the diaObject this source was associated with, if any. If not, it is set to NULL (each diaSource will be associated with either a diaObject or ssObject)
# 7                                                                                                                      Id of the ssObject this source was associated with, if any. If not, it is set to NULL (each diaSource will be associated with either a diaObject or ssObject)
# 8                                                                                                                                                                                                                                                                  Uncertainty of ra
# 9                                                                                                                                                                                                                                                                 Uncertainty of dec
# 10                                                                                                                                                                                                                                                     Covariance between ra and dec
# 11                                                                                                                                                                                                                                    x position computed by a centroiding algorithm
# 12                                                                                                                                                                                                                                                                  Uncertainty of x
# 13                                                                                                                                                                                                                                    y position computed by a centroiding algorithm
# 14                                                                                                                                                                                                                                                                  Uncertainty of y
# 15                                                                                                         General centroid algorithm failure flag; set if anything went wrong when fitting the centroid. Another centroid flag field should also be set to provide more information
# 16                                                                                                                                                                                                                        Flux in a 12 pixel radius aperture on the difference image
# 17                                                                                                                                                                                                                                                   Estimated uncertainty of apFlux
# 18                                                                                                 General aperture flux algorithm failure flag; set if anything went wrong when measuring aperture fluxes. Another apFlux flag field should also be set to provide more information
# 19                                                                                                                                                                                                                                     Aperture did not fit within measurement image
# 20                                                                                                                                                                                                                                     Source was detected as significantly negative
# 21                                                                                                                                                                                               The signal-to-noise ratio at which this source was detected in the difference image
# 22                                                                                                                                                             Flux for Point Source model. Note this actually measures the flux difference between the template and the visit image
# 23                                                                                                                                                                                                                                                            Uncertainty of psfFlux
# 24                                                                                                                                                                                                          Natural log likelihood of the observed data given the point source model
# 25                                                                                                                                                                                                                                     Chi^2 statistic of the point source model fit
# 26                                                                                                                                                                                                             The number of data points (pixels) used to fit the point source model
# 27                                                                                                                                                Failure to derive linear least-squares fit of psf model. Another psfFlux flag field should also be set to provide more information
# 28                                                                                                                                                                                                           Object was too close to the edge of the image to use the full PSF model
# 29                                                                                                                                                                                                                         Not enough non-rejected pixels in data to attempt the fit
# 30                                                                                                                                                         Flux for a trailed source model. Note this actually measures the flux difference between the template and the visit image
# 31                                                                                                                                                                                                                                                          Uncertainty of trailFlux
# 32                                                                                                                                                                                                                   Right ascension coordinate of centroid for trailed source model
# 33                                                                                                                                                                                                                                                            Uncertainty of trailRa
# 34                                                                                                                                                                                                                       Declination coordinate of centroid for trailed source model
# 35                                                                                                                                                                                                                                                           Uncertainty of trailDec
# 36                                                                                                                                                                                                                                            Maximum likelihood fit of trail length
# 37                                                                                                                                                                                                                                                        Uncertainty of trailLength
# 38                                                                                                                                                                   Maximum likelihood fit of the angle between the meridian through the centroid and the trail direction (bearing)
# 39                                                                                                                                                                                                                                                         Uncertainty of trailAngle
# 40                                                                                                                                                                                                                                   Chi^2 statistic of the trailed source model fit
# 41                                                                                                                                                                                                           The number of data points (pixels) used to fit the trailed source model
# 42                                                                                                                                                                                                             This flag is set if a trailed source extends onto or past edge pixels
# 43                                                                                                                                                                                           Maximum likelihood value for the mean absolute flux of the two lobes for a dipole model
# 44                                                                                                                                                                                                                                                     Uncertainty of dipoleMeanFlux
# 45                                                                                                                                                                                Maximum likelihood value for the difference of absolute fluxes of the two lobes for a dipole model
# 46                                                                                                                                                                                                                                                     Uncertainty of dipoleFluxDiff
# 47                                                                                                                                                                                                                  Maximum likelihood value for the lobe separation in dipole model
# 48                                                                                                                                  Maximum likelihood fit of the angle between the meridian through the centroid and the dipole direction (bearing, from negative to positive lobe)
# 49                                                                                                                                                                                                                                                  Chi^2 statistic of the model fit
# 50                                                                                                                                                                                                                          The number of data points (pixels) used to fit the model
# 51                                                                                                                                                                        Forced photometry flux for a point source model measured on the visit image centered at DiaSource position
# 52                                                                                                                                                                                                                                              Estimated uncertainty of scienceFlux
# 53                                                                                                                                                   Forced PSF photometry on science image failed. Another forced_PsfFlux flag field should also be set to provide more information
# 54                                                                                                                                                                                 Forced PSF flux on science image was too close to the edge of the image to use the full PSF model
# 55                                                                                                                                                                                                         Forced PSF flux not enough non-rejected pixels in data to attempt the fit
# 56                                                                                                                                                                 Forced photometry flux for a point source model measured on the template image centered at the DiaObject position
# 57                                                                                                                                                                                                                                                       Uncertainty of templateFlux
# 58                                                                                                                                                                                                                                    Adaptive second moment of the source intensity
# 59                                                                                                                                                                                                                                    Adaptive second moment of the source intensity
# 60                                                                                                                                                                                                                                    Adaptive second moment of the source intensity
# 61                                                                                                                                                                                                                                                Adaptive second moment for the PSF
# 62                                                                                                                                                                                                                                                Adaptive second moment for the PSF
# 63                                                                                                                                                                                                                                                Adaptive second moment for the PSF
# 64                                                                                                         General source shape algorithm failure flag; set if anything went wrong when measuring the shape. Another shape flag field should also be set to provide more information
# 65                                                                                                                                                                                                                                                        No pixels to measure shape
# 66                                                                                                                                                                                                                                    Center not contained in footprint bounding box
# 67                                                                                                                                                                           This source is a parent source; we should only be measuring on deblended children in difference imaging
# 68  A measure of extendedness, computed by comparing an object's moment-based traced radius to the PSF moments. extendedness = 1 implies a high degree of confidence that the source is extended. extendedness = 0 implies a high degree of confidence that the source is point-like
# 69                                                                                                                                                                                      Probability (0-1) that the diaSource is astrophysical, derived from a machine learning model
# 70                                                                                                                                                                                                                                                       Source well fit by a dipole
# 71                                                                                                                                                                                                                                    Attempted to fit a dipole model to this source
# 72                                                                                                                                           Time when the image was processed and this DiaSource record was generated, expressed as Modified Julian Date, International Atomic Time
# 73                                                                                                                                                                            Time when this record was marked invalid, expressed as Modified Julian Date, International Atomic Time
# 74                                                                                                                                                                                                       Size of the square bounding box that fully contains the detection footprint
# 75                                                                                   General pixel flags failure; set if anything went wrong when setting pixels flags from this footprint's mask. This implies that some pixelFlags for this source may be incorrectly set to False
# 76                                                                                                                                                                                                                                              Bad pixel in the DiaSource footprint
# 77                                                                                                                                                                                                                                             Cosmic ray in the DiaSource footprint
# 78                                                                                                                                                                                                                                  Cosmic ray in the 3x3 region around the centroid
# 79                                                                                                                                                                                Some of the source footprint is outside usable exposure region (masked EDGE or centroid off image)
# 80                                                                                                                                                                                                                                             NO_DATA pixel in the source footprint
# 81                                                                                                                                                                                                                               NO_DATA pixel in the 3x3 region around the centroid
# 82                                                                                                                                                                                                                                     Interpolated pixel in the DiaSource footprint
# 83                                                                                                                                                                                                                          Interpolated pixel in the 3x3 region around the centroid
# 84                                                                                                                                                                                                                                                     DiaSource center is off image
# 85                                                                                                                                                                                                                                        Saturated pixel in the DiaSource footprint
# 86                                                                                                                                                                                                                             Saturated pixel in the 3x3 region around the centroid
# 87                                                                                                                                                                                                                                     DiaSource's footprint includes suspect pixels
# 88                                                                                                                                                                                                                               Suspect pixel in the 3x3 region around the centroid
# 89                                                                                                                                                                                                                                                 Streak in the DiaSource footprint
# 90                                                                                                                                                                                                                                      Streak in the 3x3 region around the centroid
# 91                                                                                                                                                                                                                                              Injection in the DiaSource footprint
# 92                                                                                                                                                                                                                                   Injection in the 3x3 region around the centroid
# 93                                                                                                                                                                                                                                     Template injection in the DiaSource footprint
# 94                                                                                                                                                                                                                          Template injection in the 3x3 region around the centroid
# 95                                                                                                                                                                                                                           This flag is set if the source is part of a glint trail
# 96                                                                                                                                                                                                                                                              Has image stamp flag
# 97                                                                                                                                                                                                                                                           Date record was created
#
#              unit datatype  indexed
# 0                     long        1
# 1                    short        0
# 2                     long        1
# 3                     long        0
# 4                     long        0
# 5                      int        0
# 6                     long        0
# 7                     long        0
# 8             deg    float        0
# 9             deg    float        0
# 10         deg**2    float        0
# 11            pix    float        0
# 12            pix    float        0
# 13            pix    float        0
# 14            pix    float        0
# 15                 boolean        0
# 16                   float        0
# 17                   float        0
# 18                 boolean        0
# 19                 boolean        0
# 20                 boolean        0
# 21                   float        0
# 22                   float        0
# 23                   float        0
# 24                   float        0
# 25                   float        0
# 26                     int        0
# 27                 boolean        0
# 28                 boolean        0
# 29                 boolean        0
# 30                   float        0
# 31                   float        0
# 32            deg   double        0
# 33            deg    float        0
# 34            deg   double        0
# 35            deg    float        0
# 36         arcsec    float        0
# 37         arcsec    float        0
# 38            deg    float        0
# 39            deg    float        0
# 40                   float        0
# 41                     int        0
# 42                 boolean        0
# 43                   float        0
# 44                   float        0
# 45                   float        0
# 46                   float        0
# 47         arcsec    float        0
# 48            deg    float        0
# 49                   float        0
# 50                     int        0
# 51                   float        0
# 52                   float        0
# 53                 boolean        0
# 54                 boolean        0
# 55                 boolean        0
# 56                   float        0
# 57                   float        0
# 58  nJy.arcsec**2    float        0
# 59  nJy.arcsec**2    float        0
# 60  nJy.arcsec**2    float        0
# 61  nJy.arcsec**2    float        0
# 62  nJy.arcsec**2    float        0
# 63  nJy.arcsec**2    float        0
# 64                 boolean        0
# 65                 boolean        0
# 66                 boolean        0
# 67                 boolean        0
# 68                   float        0
# 69                   float        0
# 70                 boolean        0
# 71                 boolean        0
# 72              d   double        0
# 73              d   double        0
# 74            pix      int        0
# 75                 boolean        0
# 76                 boolean        0
# 77                 boolean        0
# 78                 boolean        0
# 79                 boolean        0
# 80                 boolean        0
# 81                 boolean        0
# 82                 boolean        0
# 83                 boolean        0
# 84                 boolean        0
# 85                 boolean        0
# 86                 boolean        0
# 87                 boolean        0
# 88                 boolean        0
# 89                 boolean        0
# 90                 boolean        0
# 91                 boolean        0
# 92                 boolean        0
# 93                 boolean        0
# 94                 boolean        0
# 95                 boolean        0
# 96                 boolean        0
# 97                    char        0
# lsst_ss_detection
#                       table_name          column_name  \
# 0   alerce_tap.lsst_ss_detection       measurement_id
# 1   alerce_tap.lsst_ss_detection           ssobjectid
# 2   alerce_tap.lsst_ss_detection          designation
# 3   alerce_tap.lsst_ss_detection            ecllambda
# 4   alerce_tap.lsst_ss_detection              eclbeta
# 5   alerce_tap.lsst_ss_detection               gallon
# 6   alerce_tap.lsst_ss_detection               gallat
# 7   alerce_tap.lsst_ss_detection           elongation
# 8   alerce_tap.lsst_ss_detection           phaseangle
# 9   alerce_tap.lsst_ss_detection            toporange
# 10  alerce_tap.lsst_ss_detection        toporangerate
# 11  alerce_tap.lsst_ss_detection           heliorange
# 12  alerce_tap.lsst_ss_detection       heliorangerate
# 13  alerce_tap.lsst_ss_detection                ephra
# 14  alerce_tap.lsst_ss_detection               ephdec
# 15  alerce_tap.lsst_ss_detection              ephvmag
# 16  alerce_tap.lsst_ss_detection              ephrate
# 17  alerce_tap.lsst_ss_detection            ephratera
# 18  alerce_tap.lsst_ss_detection           ephratedec
# 19  alerce_tap.lsst_ss_detection            ephoffset
# 20  alerce_tap.lsst_ss_detection          ephoffsetra
# 21  alerce_tap.lsst_ss_detection         ephoffsetdec
# 22  alerce_tap.lsst_ss_detection  ephoffsetalongtrack
# 23  alerce_tap.lsst_ss_detection  ephoffsetcrosstrack
# 24  alerce_tap.lsst_ss_detection              helio_x
# 25  alerce_tap.lsst_ss_detection              helio_y
# 26  alerce_tap.lsst_ss_detection              helio_z
# 27  alerce_tap.lsst_ss_detection             helio_vx
# 28  alerce_tap.lsst_ss_detection             helio_vy
# 29  alerce_tap.lsst_ss_detection             helio_vz
# 30  alerce_tap.lsst_ss_detection           helio_vtot
# 31  alerce_tap.lsst_ss_detection               topo_x
# 32  alerce_tap.lsst_ss_detection               topo_y
# 33  alerce_tap.lsst_ss_detection               topo_z
# 34  alerce_tap.lsst_ss_detection              topo_vx
# 35  alerce_tap.lsst_ss_detection              topo_vy
# 36  alerce_tap.lsst_ss_detection              topo_vz
# 37  alerce_tap.lsst_ss_detection            topo_vtot
# 38  alerce_tap.lsst_ss_detection      diadistancerank
# 39  alerce_tap.lsst_ss_detection         created_date
#
#                                                                                                                                     description  \
# 0                                                                                              Unique identifier of this DIA source observation
# 1                                                                                                           LSST solar system object identifier
# 2                                                                         Unpacked primary provisional designation for this solar system object
# 3                                                                                                                            Ecliptic longitude
# 4                                                                                                                             Ecliptic latitude
# 5                                                                                                                            Galactic longitude
# 6                                                                                                                             Galactic latitude
# 7                                                   Solar elongation, the angular separation of the object from the Sun on the celestial sphere
# 8                                                                   Phase angle, the angle between the Sun and observer as seen from the object
# 9                                                                               Topocentric range, the distance from the observer to the object
# 10                                                           Topocentric range rate, the radial velocity of the object relative to the observer
# 11                                                                                  Heliocentric range, the distance from the Sun to the object
# 12                                                               Heliocentric range rate, the radial velocity of the object relative to the Sun
# 13                                                           Predicted ICRS right ascension computed from orbit propagation at observation time
# 14                                                               Predicted ICRS declination computed from orbit propagation at observation time
# 15                                                               Predicted V-band magnitude computed from orbit propagation at observation time
# 16                                                                                            Predicted total angular rate of motion on the sky
# 17                                                                                       Predicted angular rate of motion along right ascension
# 18                                                                                           Predicted angular rate of motion along declination
# 19                                                         Total angular offset between observed and predicted position on the celestial sphere
# 20                                         Angular offset in right ascension between observed and predicted position (observed minus predicted)
# 21                                             Angular offset in declination between observed and predicted position (observed minus predicted)
# 22                                                         Angular offset along the direction of motion between observed and predicted position
# 23                                              Angular offset perpendicular to the direction of motion between observed and predicted position
# 24                                                                                    Heliocentric X position component in ICRS reference frame
# 25                                                                                    Heliocentric Y position component in ICRS reference frame
# 26                                                                                    Heliocentric Z position component in ICRS reference frame
# 27                                                                         Heliocentric velocity component along X axis in ICRS reference frame
# 28                                                                         Heliocentric velocity component along Y axis in ICRS reference frame
# 29                                                                         Heliocentric velocity component along Z axis in ICRS reference frame
# 30                                                                                                        Heliocentric total velocity magnitude
# 31                                                            Topocentric X position component in ICRS reference frame relative to the observer
# 32                                                            Topocentric Y position component in ICRS reference frame relative to the observer
# 33                                                            Topocentric Z position component in ICRS reference frame relative to the observer
# 34                                                                          Topocentric velocity component along X axis in ICRS reference frame
# 35                                                                          Topocentric velocity component along Y axis in ICRS reference frame
# 36                                                                          Topocentric velocity component along Z axis in ICRS reference frame
# 37                                                                                                         Topocentric total velocity magnitude
# 38  Ranking based on the distance between this DIA source and the predicted position of the solar system object, with 1 being the closest match
# 39                                                                                                                      Date record was created
#
#         unit datatype  indexed
# 0                long        1
# 1                long        1
# 2                char        0
# 3        deg   double        0
# 4        deg   double        0
# 5        deg   double        0
# 6        deg   double        0
# 7        deg    float        0
# 8        deg    float        0
# 9         AU    float        0
# 10      AU/d    float        0
# 11        AU    float        0
# 12      AU/d    float        0
# 13       deg   double        0
# 14       deg   double        0
# 15       mag    float        0
# 16  arcsec/h    float        0
# 17  arcsec/h    float        0
# 18  arcsec/h    float        0
# 19    arcsec    float        0
# 20       deg   double        0
# 21       deg   double        0
# 22    arcsec    float        0
# 23    arcsec    float        0
# 24        AU    float        0
# 25        AU    float        0
# 26        AU    float        0
# 27      AU/d    float        0
# 28      AU/d    float        0
# 29      AU/d    float        0
# 30      AU/d    float        0
# 31        AU    float        0
# 32        AU    float        0
# 33        AU    float        0
# 34      AU/d    float        0
# 35      AU/d    float        0
# 36      AU/d    float        0
# 37      AU/d    float        0
# 38                int        0
# 39               char        0
# forced_photometry
#                      table_name     column_name              description unit  \
# 0  alerce_tap.forced_photometry             oid        Object identifier
# 1  alerce_tap.forced_photometry             sid        Survey identifier
# 2  alerce_tap.forced_photometry  measurement_id   Measurement identifier
# 3  alerce_tap.forced_photometry             mjd     Modified Julian Date    d
# 4  alerce_tap.forced_photometry              ra          Right ascension  deg
# 5  alerce_tap.forced_photometry             dec              Declination  deg
# 6  alerce_tap.forced_photometry            band         Photometric band
# 7  alerce_tap.forced_photometry    created_date  Date record was created
#
#   datatype  indexed
# 0     long        1
# 1    short        1
# 2     long        1
# 3   double        0
# 4   double        1
# 5   double        1
# 6    short        0
# 7     char        0
# lsst_forced_photometry
#                            table_name          column_name  \
# 0   alerce_tap.lsst_forced_photometry                  oid
# 1   alerce_tap.lsst_forced_photometry                  sid
# 2   alerce_tap.lsst_forced_photometry       measurement_id
# 3   alerce_tap.lsst_forced_photometry                visit
# 4   alerce_tap.lsst_forced_photometry             detector
# 5   alerce_tap.lsst_forced_photometry              psfflux
# 6   alerce_tap.lsst_forced_photometry           psffluxerr
# 7   alerce_tap.lsst_forced_photometry          scienceflux
# 8   alerce_tap.lsst_forced_photometry       sciencefluxerr
# 9   alerce_tap.lsst_forced_photometry  timeprocessedmjdtai
# 10  alerce_tap.lsst_forced_photometry  timewithdrawnmjdtai
# 11  alerce_tap.lsst_forced_photometry         created_date
#
#                                                                                                        description  \
# 0                                                                                                Object identifier
# 1                                                                                                Survey identifier
# 2                                                                                                        Unique id
# 3                                                             Id of the visit where this forcedSource was measured
# 4                                                          Id of the detector where this forcedSource was measured
# 5                                                                                          Point Source model flux
# 6                                                                                           Uncertainty of psfFlux
# 7   Forced photometry flux for a point source model measured on the visit image centered at the DiaObject position
# 8                                                                                       Uncertainty of scienceFlux
# 9                Time when this record was generated, expressed as Modified Julian Date, International Atomic Time
# 10          Time when this record was marked invalid, expressed as Modified Julian Date, International Atomic Time
# 11                                                                                         Date record was created
#
#    unit datatype  indexed
# 0           long        1
# 1          short        0
# 2           long        1
# 3           long        0
# 4            int        0
# 5          float        0
# 6          float        0
# 7          float        0
# 8          float        0
# 9     d   double        0
# 10    d   double        0
# 11          char        0

# %% [markdown]
# Latest record data for both diaObjects and MPC designations can be found in the following tables, respectively:

# %%
data_tables = [
    'lsst_dia_object',
    'lsst_mpc_orbits',
]

# %%
for table_name in data_tables:
    show_table_info(table_name)
# Out:
# lsst_dia_object
#                     table_name           column_name  \
# 0   alerce_tap.lsst_dia_object                   oid
# 1   alerce_tap.lsst_dia_object   validitystartmjdtai
# 2   alerce_tap.lsst_dia_object                    ra
# 3   alerce_tap.lsst_dia_object                 raerr
# 4   alerce_tap.lsst_dia_object                   dec
# 5   alerce_tap.lsst_dia_object                decerr
# 6   alerce_tap.lsst_dia_object            ra_dec_cov
# 7   alerce_tap.lsst_dia_object         u_psffluxmean
# 8   alerce_tap.lsst_dia_object      u_psffluxmeanerr
# 9   alerce_tap.lsst_dia_object        u_psffluxsigma
# 10  alerce_tap.lsst_dia_object        u_psffluxndata
# 11  alerce_tap.lsst_dia_object          u_fpfluxmean
# 12  alerce_tap.lsst_dia_object       u_fpfluxmeanerr
# 13  alerce_tap.lsst_dia_object         g_psffluxmean
# 14  alerce_tap.lsst_dia_object      g_psffluxmeanerr
# 15  alerce_tap.lsst_dia_object        g_psffluxsigma
# 16  alerce_tap.lsst_dia_object        g_psffluxndata
# 17  alerce_tap.lsst_dia_object          g_fpfluxmean
# 18  alerce_tap.lsst_dia_object       g_fpfluxmeanerr
# 19  alerce_tap.lsst_dia_object         r_psffluxmean
# 20  alerce_tap.lsst_dia_object      r_psffluxmeanerr
# 21  alerce_tap.lsst_dia_object        r_psffluxsigma
# 22  alerce_tap.lsst_dia_object        r_psffluxndata
# 23  alerce_tap.lsst_dia_object          r_fpfluxmean
# 24  alerce_tap.lsst_dia_object       r_fpfluxmeanerr
# 25  alerce_tap.lsst_dia_object         i_psffluxmean
# 26  alerce_tap.lsst_dia_object      i_psffluxmeanerr
# 27  alerce_tap.lsst_dia_object        i_psffluxsigma
# 28  alerce_tap.lsst_dia_object        i_psffluxndata
# 29  alerce_tap.lsst_dia_object          i_fpfluxmean
# 30  alerce_tap.lsst_dia_object       i_fpfluxmeanerr
# 31  alerce_tap.lsst_dia_object         z_psffluxmean
# 32  alerce_tap.lsst_dia_object      z_psffluxmeanerr
# 33  alerce_tap.lsst_dia_object        z_psffluxsigma
# 34  alerce_tap.lsst_dia_object        z_psffluxndata
# 35  alerce_tap.lsst_dia_object          z_fpfluxmean
# 36  alerce_tap.lsst_dia_object       z_fpfluxmeanerr
# 37  alerce_tap.lsst_dia_object         y_psffluxmean
# 38  alerce_tap.lsst_dia_object      y_psffluxmeanerr
# 39  alerce_tap.lsst_dia_object        y_psffluxsigma
# 40  alerce_tap.lsst_dia_object        y_psffluxndata
# 41  alerce_tap.lsst_dia_object          y_fpfluxmean
# 42  alerce_tap.lsst_dia_object       y_fpfluxmeanerr
# 43  alerce_tap.lsst_dia_object     u_sciencefluxmean
# 44  alerce_tap.lsst_dia_object  u_sciencefluxmeanerr
# 45  alerce_tap.lsst_dia_object     g_sciencefluxmean
# 46  alerce_tap.lsst_dia_object  g_sciencefluxmeanerr
# 47  alerce_tap.lsst_dia_object     r_sciencefluxmean
# 48  alerce_tap.lsst_dia_object  r_sciencefluxmeanerr
# 49  alerce_tap.lsst_dia_object     i_sciencefluxmean
# 50  alerce_tap.lsst_dia_object  i_sciencefluxmeanerr
# 51  alerce_tap.lsst_dia_object     z_sciencefluxmean
# 52  alerce_tap.lsst_dia_object  z_sciencefluxmeanerr
# 53  alerce_tap.lsst_dia_object     y_sciencefluxmean
# 54  alerce_tap.lsst_dia_object  y_sciencefluxmeanerr
# 55  alerce_tap.lsst_dia_object          u_psffluxmin
# 56  alerce_tap.lsst_dia_object          u_psffluxmax
# 57  alerce_tap.lsst_dia_object     u_psffluxmaxslope
# 58  alerce_tap.lsst_dia_object      u_psffluxerrmean
# 59  alerce_tap.lsst_dia_object          g_psffluxmin
# 60  alerce_tap.lsst_dia_object          g_psffluxmax
# 61  alerce_tap.lsst_dia_object     g_psffluxmaxslope
# 62  alerce_tap.lsst_dia_object      g_psffluxerrmean
# 63  alerce_tap.lsst_dia_object          r_psffluxmin
# 64  alerce_tap.lsst_dia_object          r_psffluxmax
# 65  alerce_tap.lsst_dia_object     r_psffluxmaxslope
# 66  alerce_tap.lsst_dia_object      r_psffluxerrmean
# 67  alerce_tap.lsst_dia_object          i_psffluxmin
# 68  alerce_tap.lsst_dia_object          i_psffluxmax
# 69  alerce_tap.lsst_dia_object     i_psffluxmaxslope
# 70  alerce_tap.lsst_dia_object      i_psffluxerrmean
# 71  alerce_tap.lsst_dia_object          z_psffluxmin
# 72  alerce_tap.lsst_dia_object          z_psffluxmax
# 73  alerce_tap.lsst_dia_object     z_psffluxmaxslope
# 74  alerce_tap.lsst_dia_object      z_psffluxerrmean
# 75  alerce_tap.lsst_dia_object          y_psffluxmin
# 76  alerce_tap.lsst_dia_object          y_psffluxmax
# 77  alerce_tap.lsst_dia_object     y_psffluxmaxslope
# 78  alerce_tap.lsst_dia_object      y_psffluxerrmean
# 79  alerce_tap.lsst_dia_object  firstdiasourcemjdtai
# 80  alerce_tap.lsst_dia_object   lastdiasourcemjdtai
# 81  alerce_tap.lsst_dia_object           ndiasources
# 82  alerce_tap.lsst_dia_object          created_date
#
#                                                                                                              description  \
# 0                                                                                    Unique identifier of this DiaObject
# 1   Processing time when validity of this diaObject starts, expressed as Modified Julian Date, International Atomic Time
# 2                                                               Right ascension coordinate of the position of the object
# 3                                                                                                      Uncertainty of ra
# 4                                                                   Declination coordinate of the position of the object
# 5                                                                                                     Uncertainty of dec
# 6                                                                                          Covariance between ra and dec
# 7                                                                Weighted mean point-source model magnitude for u filter
# 8                                                                                        Standard error of u_psfFluxMean
# 9                                                                    Standard deviation of the distribution of u_psfFlux
# 10                                                                                      The number of u-band data points
# 11                                                                     Weighted mean forced photometry flux for u filter
# 12                                                                                        Standard error of u_fpFluxMean
# 13                                                               Weighted mean point-source model magnitude for g filter
# 14                                                                                       Standard error of g_psfFluxMean
# 15                                                                   Standard deviation of the distribution of g_psfFlux
# 16                                                                                      The number of g-band data points
# 17                                                                     Weighted mean forced photometry flux for g filter
# 18                                                                                        Standard error of g_fpFluxMean
# 19                                                               Weighted mean point-source model magnitude for r filter
# 20                                                                                       Standard error of r_psfFluxMean
# 21                                                                   Standard deviation of the distribution of r_psfFlux
# 22                                                                                      The number of r-band data points
# 23                                                                     Weighted mean forced photometry flux for r filter
# 24                                                                                        Standard error of r_fpFluxMean
# 25                                                               Weighted mean point-source model magnitude for i filter
# 26                                                                                       Standard error of i_psfFluxMean
# 27                                                                   Standard deviation of the distribution of i_psfFlux
# 28                                                                                      The number of i-band data points
# 29                                                                     Weighted mean forced photometry flux for i filter
# 30                                                                                        Standard error of i_fpFluxMean
# 31                                                               Weighted mean point-source model magnitude for z filter
# 32                                                                                       Standard error of z_psfFluxMean
# 33                                                                   Standard deviation of the distribution of z_psfFlux
# 34                                                                                      The number of z-band data points
# 35                                                                     Weighted mean forced photometry flux for z filter
# 36                                                                                        Standard error of z_fpFluxMean
# 37                                                               Weighted mean point-source model magnitude for y filter
# 38                                                                                       Standard error of y_psfFluxMean
# 39                                                                   Standard deviation of the distribution of y_psfFlux
# 40                                                                                      The number of y-band data points
# 41                                                                     Weighted mean forced photometry flux for y filter
# 42                                                                                        Standard error of y_fpFluxMean
# 43                                                                     Weighted mean forced photometry flux for u filter
# 44                                                                                   Standard error of u_scienceFluxMean
# 45                                                                     Weighted mean forced photometry flux for g filter
# 46                                                                                   Standard error of g_scienceFluxMean
# 47                                                                     Weighted mean forced photometry flux for r filter
# 48                                                                                   Standard error of r_scienceFluxMean
# 49                                                                     Weighted mean forced photometry flux for i filter
# 50                                                                                   Standard error of i_scienceFluxMean
# 51                                                                     Weighted mean forced photometry flux for z filter
# 52                                                                                   Standard error of z_scienceFluxMean
# 53                                                                     Weighted mean forced photometry flux for y filter
# 54                                                                                   Standard error of y_scienceFluxMean
# 55                                                                                        Minimum observed u band fluxes
# 56                                                                                        Maximum observed u band fluxes
# 57                                              Maximum slope between u band flux obsevations max(delta_flux/delta_time)
# 58                                                                                        Mean of the u band flux errors
# 59                                                                                        Minimum observed g band fluxes
# 60                                                                                        Maximum observed g band fluxes
# 61                                              Maximum slope between g band flux obsevations max(delta_flux/delta_time)
# 62                                                                                        Mean of the g band flux errors
# 63                                                                                        Minimum observed r band fluxes
# 64                                                                                        Maximum observed r band fluxes
# 65                                              Maximum slope between r band flux obsevations max(delta_flux/delta_time)
# 66                                                                                        Mean of the r band flux errors
# 67                                                                                        Minimum observed i band fluxes
# 68                                                                                        Maximum observed i band fluxes
# 69                                              Maximum slope between i band flux obsevations max(delta_flux/delta_time)
# 70                                                                                        Mean of the i band flux errors
# 71                                                                                        Minimum observed z band fluxes
# 72                                                                                        Maximum observed z band fluxes
# 73                                              Maximum slope between z band flux obsevations max(delta_flux/delta_time)
# 74                                                                                        Mean of the z band flux errors
# 75                                                                                        Minimum observed y band fluxes
# 76                                                                                        Maximum observed y band fluxes
# 77                                              Maximum slope between y band flux obsevations max(delta_flux/delta_time)
# 78                                                                                        Mean of the y band flux errors
# 79                                                                                           First DIA source MJD in TAI
# 80                                                                                            Last DIA source MJD in TAI
# 81                                                                                                 Number of DIA sources
# 82                                                                                               Date record was created
#
#       unit datatype  indexed
# 0              long        1
# 1        d   double        0
# 2      deg   double        1
# 3      deg    float        0
# 4      deg   double        1
# 5      deg    float        0
# 6   deg**2    float        0
# 7             float        0
# 8             float        0
# 9             float        0
# 10              int        0
# 11            float        0
# 12            float        0
# 13            float        0
# 14            float        0
# 15            float        0
# 16              int        0
# 17            float        0
# 18            float        0
# 19            float        0
# 20            float        0
# 21            float        0
# 22              int        0
# 23            float        0
# 24            float        0
# 25            float        0
# 26            float        0
# 27            float        0
# 28              int        0
# 29            float        0
# 30            float        0
# 31            float        0
# 32            float        0
# 33            float        0
# 34              int        0
# 35            float        0
# 36            float        0
# 37            float        0
# 38            float        0
# 39            float        0
# 40              int        0
# 41            float        0
# 42            float        0
# 43            float        0
# 44            float        0
# 45            float        0
# 46            float        0
# 47            float        0
# 48            float        0
# 49            float        0
# 50            float        0
# 51            float        0
# 52            float        0
# 53            float        0
# 54            float        0
# 55            float        0
# 56            float        0
# 57   nJy/d    float        0
# 58            float        0
# 59            float        0
# 60            float        0
# 61   nJy/d    float        0
# 62            float        0
# 63            float        0
# 64            float        0
# 65   nJy/d    float        0
# 66            float        0
# 67            float        0
# 68            float        0
# 69   nJy/d    float        0
# 70            float        0
# 71            float        0
# 72            float        0
# 73   nJy/d    float        0
# 74            float        0
# 75            float        0
# 76            float        0
# 77   nJy/d    float        0
# 78            float        0
# 79       d   double        0
# 80       d   double        0
# 81              int        0
# 82             char        0
# lsst_mpc_orbits
#                     table_name                               column_name  \
# 0   alerce_tap.lsst_mpc_orbits                                ssobjectid
# 1   alerce_tap.lsst_mpc_orbits                               designation
# 2   alerce_tap.lsst_mpc_orbits    packed_primary_provisional_designation
# 3   alerce_tap.lsst_mpc_orbits  unpacked_primary_provisional_designation
# 4   alerce_tap.lsst_mpc_orbits                             mpc_orb_jsonb
# 5   alerce_tap.lsst_mpc_orbits                                created_at
# 6   alerce_tap.lsst_mpc_orbits                                updated_at
# 7   alerce_tap.lsst_mpc_orbits                            orbit_type_int
# 8   alerce_tap.lsst_mpc_orbits                                   u_param
# 9   alerce_tap.lsst_mpc_orbits                                      nopp
# 10  alerce_tap.lsst_mpc_orbits                          arc_length_total
# 11  alerce_tap.lsst_mpc_orbits                            arc_length_sel
# 12  alerce_tap.lsst_mpc_orbits                                nobs_total
# 13  alerce_tap.lsst_mpc_orbits                            nobs_total_sel
# 14  alerce_tap.lsst_mpc_orbits                                         a
# 15  alerce_tap.lsst_mpc_orbits                                         q
# 16  alerce_tap.lsst_mpc_orbits                                         e
# 17  alerce_tap.lsst_mpc_orbits                                         i
# 18  alerce_tap.lsst_mpc_orbits                                      node
# 19  alerce_tap.lsst_mpc_orbits                                   argperi
# 20  alerce_tap.lsst_mpc_orbits                                 peri_time
# 21  alerce_tap.lsst_mpc_orbits                                 yarkovsky
# 22  alerce_tap.lsst_mpc_orbits                                       srp
# 23  alerce_tap.lsst_mpc_orbits                                        a1
# 24  alerce_tap.lsst_mpc_orbits                                        a2
# 25  alerce_tap.lsst_mpc_orbits                                        a3
# 26  alerce_tap.lsst_mpc_orbits                                        dt
# 27  alerce_tap.lsst_mpc_orbits                              mean_anomaly
# 28  alerce_tap.lsst_mpc_orbits                                    period
# 29  alerce_tap.lsst_mpc_orbits                               mean_motion
# 30  alerce_tap.lsst_mpc_orbits                                     a_unc
# 31  alerce_tap.lsst_mpc_orbits                                     q_unc
# 32  alerce_tap.lsst_mpc_orbits                                     e_unc
# 33  alerce_tap.lsst_mpc_orbits                                     i_unc
# 34  alerce_tap.lsst_mpc_orbits                                  node_unc
# 35  alerce_tap.lsst_mpc_orbits                               argperi_unc
# 36  alerce_tap.lsst_mpc_orbits                             peri_time_unc
# 37  alerce_tap.lsst_mpc_orbits                             yarkovsky_unc
# 38  alerce_tap.lsst_mpc_orbits                                   srp_unc
# 39  alerce_tap.lsst_mpc_orbits                                    a1_unc
# 40  alerce_tap.lsst_mpc_orbits                                    a2_unc
# 41  alerce_tap.lsst_mpc_orbits                                    a3_unc
# 42  alerce_tap.lsst_mpc_orbits                                    dt_unc
# 43  alerce_tap.lsst_mpc_orbits                          mean_anomaly_unc
# 44  alerce_tap.lsst_mpc_orbits                                period_unc
# 45  alerce_tap.lsst_mpc_orbits                           mean_motion_unc
# 46  alerce_tap.lsst_mpc_orbits                                 epoch_mjd
# 47  alerce_tap.lsst_mpc_orbits                                         h
# 48  alerce_tap.lsst_mpc_orbits                                         g
# 49  alerce_tap.lsst_mpc_orbits                        not_normalized_rms
# 50  alerce_tap.lsst_mpc_orbits                            normalized_rms
# 51  alerce_tap.lsst_mpc_orbits                                earth_moid
# 52  alerce_tap.lsst_mpc_orbits                          fitting_datetime
# 53  alerce_tap.lsst_mpc_orbits                              created_date
# 54  alerce_tap.lsst_mpc_orbits                              updated_date
#
#                                                                              description  \
# 0                                                         Solar system object identifier
# 1                           The unpacked primary provisional designation for this object
# 2                      The primary provisional designation in packed form (e.g. K08A00B)
# 3                    The primary provisional designation in unpacked form (e.g. 2008 AB)
# 4                                             Details of the orbit solution in JSON form
# 5                                                              When this row was created
# 6                                                              When this row was updated
# 7                                                                        Orbit type code
# 8                                                                            U parameter
# 9                                                                  Number of oppositions
# 10                                             Arc length over total observations [days]
# 11                                  Arc length over total observations *selected* [days]
# 12                          Total number of all observations (optical + radar) available
# 13  Total number of all observations (optical + radar) selected for use in orbit fitting
# 14                                                                  Semi Major Axis [au]
# 15                                                              Pericenter Distance [au]
# 16                                                                          Eccentricity
# 17                                                                 Inclination [degrees]
# 18                                                 Longitude of Ascending Node [degrees]
# 19                                                      Argument of Pericenter [degrees]
# 20                                                   Time from Pericenter Passage [days]
# 21                                               Yarkovsky Component [10^(-10)*au/day^2]
# 22                                          Solar-Radiation Pressure Component [m^2/ton]
# 23                                                      A1 non-grav components [m^2/ton]
# 24                                                      A2 non-grav components [m^2/ton]
# 25                                                      A3 non-grav components [m^2/ton]
# 26                                                                 DT non-grav component
# 27                                                                Mean Anomaly [degrees]
# 28                                                                 Orbital Period [days]
# 29                                                 Orbital Mean Motion [degrees per day]
# 30                                                   Uncertainty on Semi Major Axis [au]
# 31                                               Uncertainty on Pericenter Distance [au]
# 32                                                           Uncertainty on Eccentricity
# 33                                                  Uncertainty on Inclination [degrees]
# 34                                  Uncertainty on Longitude of Ascending Node [degrees]
# 35                                       Uncertainty on Argument of Pericenter [degrees]
# 36                                                Time of perihelion passage uncertainty
# 37                                                Yarkovsky effect parameter uncertainty
# 38                                        Solar radiation pressure parameter uncertainty
# 39                                            A1 non-gravitational parameter uncertainty
# 40                                            A2 non-gravitational parameter uncertainty
# 41                                            A3 non-gravitational parameter uncertainty
# 42                                                               Time offset uncertainty
# 43                                                              Mean anomaly uncertainty
# 44                                                            Orbital period uncertainty
# 45                                                               Mean motion uncertainty
# 46                                                                          Epoch in MJD
# 47                                                                  Absolute magnitude H
# 48                                                                     Slope parameter G
# 49                                                             Non-normalized RMS of fit
# 50                                                                 Normalized RMS of fit
# 51                                             Earth minimum orbit intersection distance
# 52                                                               DateTime of orbital fit
# 53                                                               Date record was created
# 54                                                          Date record was last updated
#
#             unit datatype  indexed
# 0                    long        1
# 1                    char        0
# 2                    char        0
# 3                    char        0
# 4                    char        0
# 5                    char        0
# 6                    char        0
# 7                     int        0
# 8                     int        0
# 9                     int        0
# 10             d   double        0
# 11             d   double        0
# 12                    int        0
# 13                    int        0
# 14            AU   double        0
# 15            AU   double        0
# 16                 double        0
# 17           deg   double        0
# 18           deg   double        0
# 19           deg   double        0
# 20             d   double        0
# 21  1e-10.au.d-2   double        0
# 22        m2.t-1   double        0
# 23        m2.t-1   double        0
# 24        m2.t-1   double        0
# 25        m2.t-1   double        0
# 26                 double        0
# 27           deg   double        0
# 28             d   double        0
# 29       deg.d-1   double        0
# 30            AU   double        0
# 31            AU   double        0
# 32                 double        0
# 33           deg   double        0
# 34           deg   double        0
# 35           deg   double        0
# 36             d   double        0
# 37                 double        0
# 38                 double        0
# 39                 double        0
# 40                 double        0
# 41                 double        0
# 42             d   double        0
# 43           deg   double        0
# 44             d   double        0
# 45         deg/d   double        0
# 46             d   double        0
# 47           mag   double        0
# 48                 double        0
# 49                 double        0
# 50                 double        0
# 51            AU   double        0
# 52                   char        0
# 53                   char        0
# 54                   char        0

# %% [markdown]
# The ALeRCE pipeline computes crossmatches with external catalogs based on proximity. At this time, we obtain crossmatches between alert data and the [AllWISE](https://irsa.ipac.caltech.edu/data/WISE/docs/release/AllWISE/) catalog:

# %%
table_name = 'catalog_id_lut'

query = '''
SELECT
    catid, catalog_name
FROM
    alerce_tap.%s
''' % table_name

result = alerce_tap.search(query).to_table().to_pandas()
display(result)
# Out:
#    catid catalog_name
# 0      0      AllWISE

# %% [markdown]
# We store these matches in the ```xmatch``` table, while ancillary data for external catalog objects are stored in this case in the ```allwise``` table:

# %%
data_tables = [
    'xmatch',
    'allwise'
]

# %%
for table_name in data_tables:
    show_table_info(table_name)
# Out:
# xmatch
#           table_name   column_name                            description  \
# 0  alerce_tap.xmatch           oid                      Object identifier
# 1  alerce_tap.xmatch           sid                      Survey identifier
# 2  alerce_tap.xmatch         catid                     Catalog identifier
# 3  alerce_tap.xmatch          dist                   Cross-match distance
# 4  alerce_tap.xmatch   oid_catalog  Object identifier in external catalog
# 5  alerce_tap.xmatch  created_date                Date record was created
# 6  alerce_tap.xmatch  updated_date           Date record was last updated
#
#      unit datatype  indexed
# 0             long        1
# 1            short        1
# 2            short        1
# 3  arcsec    float        0
# 4             char        0
# 5             char        0
# 6             char        0
# allwise
#             table_name   column_name  \
# 0   alerce_tap.allwise   oid_catalog
# 1   alerce_tap.allwise            ra
# 2   alerce_tap.allwise           dec
# 3   alerce_tap.allwise        w1mpro
# 4   alerce_tap.allwise        w2mpro
# 5   alerce_tap.allwise        w3mpro
# 6   alerce_tap.allwise        w4mpro
# 7   alerce_tap.allwise     w1sigmpro
# 8   alerce_tap.allwise     w2sigmpro
# 9   alerce_tap.allwise     w3sigmpro
# 10  alerce_tap.allwise     w4sigmpro
# 11  alerce_tap.allwise     j_m_2mass
# 12  alerce_tap.allwise  j_msig_2mass
# 13  alerce_tap.allwise     h_m_2mass
# 14  alerce_tap.allwise  h_msig_2mass
# 15  alerce_tap.allwise     k_m_2mass
# 16  alerce_tap.allwise  k_msig_2mass
#
#                                         description unit datatype  indexed
# 0              Object identifier in AllWISE catalog          char        0
# 1              Right ascension from AllWISE catalog  deg   double        0
# 2                  Declination from AllWISE catalog  deg   double        0
# 3    W1 magnitude (3.4 micron) from AllWISE catalog  mag   double        0
# 4    W2 magnitude (4.6 micron) from AllWISE catalog  mag   double        0
# 5     W3 magnitude (12 micron) from AllWISE catalog  mag   double        0
# 6     W4 magnitude (22 micron) from AllWISE catalog  mag   double        0
# 7     W1 magnitude uncertainty from AllWISE catalog  mag   double        0
# 8     W2 magnitude uncertainty from AllWISE catalog  mag   double        0
# 9     W3 magnitude uncertainty from AllWISE catalog  mag   double        0
# 10    W4 magnitude uncertainty from AllWISE catalog  mag   double        0
# 11              J-band magnitude from 2MASS catalog  mag   double        0
# 12  J-band magnitude uncertainty from 2MASS catalog  mag   double        0
# 13              H-band magnitude from 2MASS catalog  mag   double        0
# 14  H-band magnitude uncertainty from 2MASS catalog  mag   double        0
# 15              K-band magnitude from 2MASS catalog  mag   double        0
# 16  K-band magnitude uncertainty from 2MASS catalog  mag   double        0

# %% [markdown]
# For LSST, the ALeRCE pipeline computes a set of features for diaObjects that have two or more detections. This includes variability features (both per band and multiband) and colors based on AllWISE crossmatches:

# %%
lookup_tables = [
    'feature_name_lut',
    'feature_version_lut',
]

# %%
for table_name in lookup_tables:
    print(table_name)
    
    query = '''
    SELECT
        *
    FROM
        alerce_tap.%s
    WHERE
        tid = %d
    ''' % (table_name, tid)
    
    result = alerce_tap.search(query).to_table().to_pandas()
    pd.set_option('display.max_rows', None)
    display(result)
    pd.set_option('display.max_rows', 30)
# Out:
# feature_name_lut
#      feature_id                   feature_name created_date  sid  tid
# 0             0                       u-g_mean   2026-02-13    1    1
# 1             1                        u-g_max   2026-02-13    1    1
# 2             2                       g-r_mean   2026-02-13    1    1
# 3             3                        g-r_max   2026-02-13    1    1
# 4             4                       r-i_mean   2026-02-13    1    1
# 5             5                        r-i_max   2026-02-13    1    1
# 6             6                       i-z_mean   2026-02-13    1    1
# 7             7                        i-z_max   2026-02-13    1    1
# 8             8                       z-y_mean   2026-02-13    1    1
# 9             9                        z-y_max   2026-02-13    1    1
# 10           10                  u-g_mean_corr   2026-02-13    1    1
# 11           11                   u-g_max_corr   2026-02-13    1    1
# 12           12                  g-r_mean_corr   2026-02-13    1    1
# 13           13                   g-r_max_corr   2026-02-13    1    1
# 14           14                  r-i_mean_corr   2026-02-13    1    1
# 15           15                   r-i_max_corr   2026-02-13    1    1
# 16           16                  i-z_mean_corr   2026-02-13    1    1
# 17           17                   i-z_max_corr   2026-02-13    1    1
# 18           18                  z-y_mean_corr   2026-02-13    1    1
# 19           19                   z-y_max_corr   2026-02-13    1    1
# 20           20                       Timespan   2026-02-13    1    1
# 21           21                   Coordinate_x   2026-02-13    1    1
# 22           22                   Coordinate_y   2026-02-13    1    1
# 23           23                   Coordinate_z   2026-02-13    1    1
# 24           24                      TDE_decay   2026-02-13    1    1
# 25           25                  TDE_decay_chi   2026-02-13    1    1
# 26           26                       TDE_mag0   2026-02-13    1    1
# 27           27               Multiband_period   2026-02-13    1    1
# 28           28                            PPE   2026-02-13    1    1
# 29           29                    Period_band   2026-02-13    1    1
# 30           30                   delta_period   2026-02-13    1    1
# 31           31                 Power_rate_1/4   2026-02-13    1    1
# 32           32                 Power_rate_1/3   2026-02-13    1    1
# 33           33                 Power_rate_1/2   2026-02-13    1    1
# 34           34                   Power_rate_2   2026-02-13    1    1
# 35           35                   Power_rate_3   2026-02-13    1    1
# 36           36                   Power_rate_4   2026-02-13    1    1
# 37           37                     MHPS_ratio   2026-02-13    1    1
# 38           38                       MHPS_low   2026-02-13    1    1
# 39           39                      MHPS_high   2026-02-13    1    1
# 40           40                  MHPS_non_zero   2026-02-13    1    1
# 41           41                   MHPS_PN_flag   2026-02-13    1    1
# 42           42              MHPS_ratio_365_30   2026-02-13    1    1
# 43           43                   MHPS_low_365   2026-02-13    1    1
# 44           44                   MHPS_high_30   2026-02-13    1    1
# 45           45                   GP_DRW_sigma   2026-02-13    1    1
# 46           46                     GP_DRW_tau   2026-02-13    1    1
# 47           47                         Psi_CS   2026-02-13    1    1
# 48           48                        Psi_eta   2026-02-13    1    1
# 49           49                  Harmonics_mse   2026-02-13    1    1
# 50           50                  Harmonics_chi   2026-02-13    1    1
# 51           51                Harmonics_mag_1   2026-02-13    1    1
# 52           52                Harmonics_mag_2   2026-02-13    1    1
# 53           53              Harmonics_phase_2   2026-02-13    1    1
# 54           54                Harmonics_mag_3   2026-02-13    1    1
# 55           55              Harmonics_phase_3   2026-02-13    1    1
# 56           56                Harmonics_mag_4   2026-02-13    1    1
# 57           57              Harmonics_phase_4   2026-02-13    1    1
# 58           58                Harmonics_mag_5   2026-02-13    1    1
# 59           59              Harmonics_phase_5   2026-02-13    1    1
# 60           60                Harmonics_mag_6   2026-02-13    1    1
# 61           61              Harmonics_phase_6   2026-02-13    1    1
# 62           62                Harmonics_mag_7   2026-02-13    1    1
# 63           63              Harmonics_phase_7   2026-02-13    1    1
# 64           64                      Amplitude   2026-02-13    1    1
# 65           65                AndersonDarling   2026-02-13    1    1
# 66           66                 Autocor_length   2026-02-13    1    1
# 67           67                     Beyond1Std   2026-02-13    1    1
# 68           68                            Con   2026-02-13    1    1
# 69           69                          Eta_e   2026-02-13    1    1
# 70           70                          Gskew   2026-02-13    1    1
# 71           71                       MaxSlope   2026-02-13    1    1
# 72           72                           Mean   2026-02-13    1    1
# 73           73                   Meanvariance   2026-02-13    1    1
# 74           74                   MedianAbsDev   2026-02-13    1    1
# 75           75                      MedianBRP   2026-02-13    1    1
# 76           76                 PairSlopeTrend   2026-02-13    1    1
# 77           77               PercentAmplitude   2026-02-13    1    1
# 78           78                            Q31   2026-02-13    1    1
# 79           79                            Rcs   2026-02-13    1    1
# 80           80                           Skew   2026-02-13    1    1
# 81           81                  SmallKurtosis   2026-02-13    1    1
# 82           82                            Std   2026-02-13    1    1
# 83           83                       StetsonK   2026-02-13    1    1
# 84           84                           Pvar   2026-02-13    1    1
# 85           85                      ExcessVar   2026-02-13    1    1
# 86           86                SF_ML_amplitude   2026-02-13    1    1
# 87           87                    SF_ML_gamma   2026-02-13    1    1
# 88           88                        IAR_phi   2026-02-13    1    1
# 89           89                    LinearTrend   2026-02-13    1    1
# 90           90                          SPM_A   2026-02-13    1    1
# 91           91                         SPM_t0   2026-02-13    1    1
# 92           92                      SPM_gamma   2026-02-13    1    1
# 93           93                       SPM_beta   2026-02-13    1    1
# 94           94                   SPM_tau_rise   2026-02-13    1    1
# 95           95                   SPM_tau_fall   2026-02-13    1    1
# 96           96                        SPM_chi   2026-02-13    1    1
# 97           97                        fleet_a   2026-02-13    1    1
# 98           98                        fleet_w   2026-02-13    1    1
# 99           99                      fleet_chi   2026-02-13    1    1
# 100         100                       fleet_m0   2026-02-13    1    1
# 101         101                       fleet_t0   2026-02-13    1    1
# 102         102                color_variation   2026-02-13    1    1
# 103         103              positive_fraction   2026-02-13    1    1
# 104         104      n_forced_phot_band_before   2026-02-13    1    1
# 105         105     dbrightness_first_det_band   2026-02-13    1    1
# 106         106   dbrightness_forced_phot_band   2026-02-13    1    1
# 107         107    last_brightness_before_band   2026-02-13    1    1
# 108         108     max_brightness_before_band   2026-02-13    1    1
# 109         109  median_brightness_before_band   2026-02-13    1    1
# 110         110       n_forced_phot_band_after   2026-02-13    1    1
# 111         111      max_brightness_after_band   2026-02-13    1    1
# 112         112   median_brightness_after_band   2026-02-13    1    1
# 113         113                       ulens_u0   2026-02-13    1    1
# 114         114                       ulens_tE   2026-02-13    1    1
# 115         115                       ulens_fs   2026-02-13    1    1
# 116         116                      ulens_chi   2026-02-13    1    1
# 117         117                       ulens_t0   2026-02-13    1    1
# 118         118                     ulens_mag0   2026-02-13    1    1
# 119         119                          W1-W2   2026-02-13    1    1
# 120         120                          W2-W3   2026-02-13    1    1
# 121         121                          W3-W4   2026-02-13    1    1
# 122         122                           u-W1   2026-02-13    1    1
# 123         123                           u-W2   2026-02-13    1    1
# 124         124                           u-W3   2026-02-13    1    1
# 125         125                           u-W4   2026-02-13    1    1
# 126         126                           g-W1   2026-02-13    1    1
# 127         127                           g-W2   2026-02-13    1    1
# 128         128                           g-W3   2026-02-13    1    1
# 129         129                           g-W4   2026-02-13    1    1
# 130         130                           r-W1   2026-02-13    1    1
# 131         131                           r-W2   2026-02-13    1    1
# 132         132                           r-W3   2026-02-13    1    1
# 133         133                           r-W4   2026-02-13    1    1
# 134         134                           i-W1   2026-02-13    1    1
# 135         135                           i-W2   2026-02-13    1    1
# 136         136                           i-W3   2026-02-13    1    1
# 137         137                           i-W4   2026-02-13    1    1
# 138         138                           z-W1   2026-02-13    1    1
# 139         139                           z-W2   2026-02-13    1    1
# 140         140                           z-W3   2026-02-13    1    1
# 141         141                           z-W4   2026-02-13    1    1
# 142         142                           y-W1   2026-02-13    1    1
# 143         143                           y-W2   2026-02-13    1    1
# 144         144                           y-W3   2026-02-13    1    1
# 145         145                           y-W4   2026-02-13    1    1
# feature_version_lut
#    version_id version_name  sid  tid
# 0           1    27.5.7a31    1    1

# %%
table_name = 'feature'
show_table_info(table_name)
# Out:
# feature
#            table_name    column_name                   description unit  \
# 0  alerce_tap.feature            oid             Object identifier
# 1  alerce_tap.feature            sid             Survey identifier
# 2  alerce_tap.feature     feature_id            Feature identifier
# 3  alerce_tap.feature           band              Photometric band
# 4  alerce_tap.feature        version               Feature version
# 5  alerce_tap.feature  feature_value                 Feature value
# 6  alerce_tap.feature   updated_date  Date record was last updated
#
#   datatype  indexed
# 0     long        1
# 1    short        1
# 2    short        1
# 3    short        1
# 4    short        0
# 5   double        0
# 6     char        0

# %% [markdown]
# Note that features with NaN values are not stored.

# %% [markdown]
# The ALeRCE pipeline computes probabilities for different classifiers. At this time, we classify LSST objects using the ALeRCE stamp classifier (still in beta mode), which is a deep learning classifier based on each object's first alert image cutouts (manuscript in preparation; see [Carrasco-Davis et al. 2021](https://ui.adsabs.harvard.edu/abs/2021AJ....162..231C/abstract) for a similar version using the ZTF public alert stream). This classifier taxonomy includes five classes, and is used to pre-select transient candidates (e.g. supernovae, tidal disruption events) early after their first light.

# %% [markdown]
# Note that we use integer identifiers for both classifiers and their taxonomies. We recover the classifier and class names using the mapping defined in the ```classifier``` and ```taxonomy``` tables, respectively:

# %%
table_name = 'classifier'

query = '''
SELECT
    classifier_id, classifier_name, classifier_version, tid
FROM
    alerce_tap.%s
WHERE
    tid = %d
''' % (table_name, tid)

result = alerce_tap.search(query).to_table().to_pandas()
display(result)
# Out:
#    classifier_id              classifier_name classifier_version  tid
# 0              1  stamp_classifier_rubin_beta              2.0.1    1

# %%
classifier_id = 1 # Stamp classifier

# %%
table_name = 'taxonomy'

query = '''
SELECT
    class_id, class_name, classifier_id
FROM
    alerce_tap.%s
WHERE
    classifier_id = %d
''' % (table_name, classifier_id)

result = alerce_tap.search(query).to_table().to_pandas()
display(result)
# Out:
#    class_id class_name  classifier_id
# 0         0         SN              1
# 1         1        AGN              1
# 2         2         VS              1
# 3         3   asteroid              1
# 4         4      bogus              1

# %%
table_name = 'probability'
show_table_info(table_name)
# Out:
# probability
#                table_name         column_name                 description  \
# 0  alerce_tap.probability            class_id            Class identifier
# 1  alerce_tap.probability                 oid           Object identifier
# 2  alerce_tap.probability                 sid           Survey identifier
# 3  alerce_tap.probability       classifier_id       Classifier identifier
# 4  alerce_tap.probability  classifier_version          Classifier version
# 5  alerce_tap.probability         probability  Classification probability
# 6  alerce_tap.probability             ranking      Classification ranking
# 7  alerce_tap.probability             lastmjd        Last observation MJD
#
#   unit datatype  indexed
# 0         short        1
# 1          long        1
# 2         short        1
# 3         short        1
# 4         short        1
# 5         float        1
# 6         short        1
# 7    d   double        0
