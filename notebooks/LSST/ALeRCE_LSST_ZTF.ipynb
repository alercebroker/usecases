# %% [markdown]
# # ALeRCE LSST + ZTF queries
#
# ```Author: Alejandra Muñoz Arancibia. Last updated: 260326```
#
# This notebook shows how to query both Rubin and ZTF alert stream data (as well as derived properties) stored by the ALeRCE broker. We show examples of queries to our databases tables via: the ALeRCE python client (for both LSST and ZTF), Astronomical Data Query Language (ADQL) queries to the ALeRCE Table Access Protocol (TAP) service (for LSST), and Structured Query Language (SQL) queries to our PostgreSQL database (for ZTF). We use the pandas package to manipulate output tables as dataframes.
#
# We refer to [this notebook](https://github.com/alercebroker/usecases/tree/master/notebooks/LSST/ALeRCE_LSST_Tables.ipynb) for a detailed description of how Rubin data are stored in the ALeRCE multistream database. The ALeRCE python client is described in more detail in [this notebook](https://github.com/alercebroker/usecases/tree/master/notebooks/LSST/ALeRCE_LSST_Client_Queries.ipynb). Advanced queries not yet available for the python client can be done using Astronomical Data Query Language (ADQL) queries to the ALeRCE Table Access Protocol (TAP) service, as described in detail in [this notebook](https://github.com/alercebroker/usecases/tree/master/notebooks/LSST/ALeRCE_LSST_TAP_Queries.ipynb).
#
# *It is highly recommended that you try this notebook in Google Colab using the following [link](https://colab.research.google.com/github/alercebroker/usecases/blob/master/notebooks/LSST/ALeRCE_LSST_ZTF.ipynb).* This will avoid you from having to sort out library installation problems and focus on the contents of the tutorial. You can try installing the dependencies later in your own system.

# %% [markdown]
# # Table of contents
#
# * [Before starting](#before)
#     * [Some settings](#settings)
#     * [Initialize the ALeRCE client](#client)
#     * [Connect to ALeRCE data via TAP](#tap)
#     * [LSST queries to the ALeRCE multisurvey database](#multisurvey)
#     * [Types of object identifiers](#sid)
# * [How to query LSST and ZTF data for a given object](#query_one_lsst_ztf)
#     * [Generate ALeRCE Explorer links](#explorer_url)
#     * [Light curves](#light_curves)
#     * [Features](#features)

# %% [markdown]
# ## Before starting <a class='anchor' id='before'></a>

# %% [markdown]
# ### Some settings <a class='anchor' id='settings'></a>

# %% [markdown]
# Install the [ALeRCE python client](https://alerce.readthedocs.io/en/latest/) uncommenting the following line. In case you have a previous alerce package version, note that you need to update it to version 2.2.1 or newer to retrieve Rubin data.

# %%
#!pip install alerce

# %% [markdown]
# We also use custom functions defined in ```lib_multisurvey```. In case you are using Google Colab, download this uncommenting the following line.

# %%
#!wget https://raw.githubusercontent.com/alercebroker/usecases/master/notebooks/LSST/lib_multisurvey/alerce_multisurvey_tools.py -P lib_multisurvey/

# %% [markdown]
# Load libraries

# %%
#!pip install pyvo
#!pip install requests
#!pip install sqlalchemy
#!pip install psycopg2-binary

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from astropy.cosmology import Planck18
import pyvo as vo
import requests
import sqlalchemy as sa
import sys

# %%
from IPython.core.display import HTML
pd.set_option('display.max_colwidth', 1000)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 20)

# %%
from alerce.core import Alerce

# %% [markdown]
# ### Initialize the ALeRCE client <a class='anchor' id='client'></a>

# %%
alerce_client = Alerce()

# %% [markdown]
# ### Connect to ALeRCE data via TAP <a class='anchor' id='tap'></a>

# %% [markdown]
# We connect to the [ALeRCE TAP service](https://tap.alerce.online/) as

# %%
alerce_tap = vo.dal.TAPService('https://tap.alerce.online/tap')

# %% [markdown]
# ### LSST queries to the ALeRCE multisurvey database <a class='anchor' id='multisurvey'></a>

# %% [markdown]
# We save Rubin alert stream data in a multisurvey database. We distinguish among data sources by using the field ```tid```, for "telescope identifier". LSST (and more generally, all Rubin data observed with the Simonyi telescope) has ```tid = 1```.

# %%
tid = 1

# %% [markdown]
# ### Types of object identifiers <a class='anchor' id='sid'></a>

# %% [markdown]
# In LSST alerts, astrophysical objects have different identifiers depending on what they are associated to. Non-moving objects (e.g. supernovae, active galactic nuclei, variable stars) are associated to diaObjects, while known Solar System moving objects (e.g. asteroids) are associated to ssObjects. Identifiers for diaObjects and ssObjects are generated independent of each other by the lsst pipelines. We distinguish among them using the field ```sid```, for "survey identifier".
#
# We use the field ```oid``` as the identifier for each object. This ```oid``` is defined in different ways depending on the availability of diaObject information in the alert, so that
#
# ```oid = diaObjectId``` and ```sid = 1``` for objects that have diaObject information, and
#
# ```oid = ssObjectId``` and ```sid = 2``` if they only have ssObject information. In case an object has both identifiers (e.g. a known Solar System object was identified at a small angular distance from a non-moving object), we adopt ```oid = diaObjectId``` and ```sid = 1``` while still saving both their diaObject and ssObject data in the respective tables.
#
# We call the identifier for each epoch in every survey as ```measurement_id```. For LSST, this means both field ```diaSourceId``` for detections and field ```diaForcedSourceId``` for forced photometry points are renamed ```measurement_id``` in our database. We also rename the mid-visit time for each epoch from field ```midpointMjdTai``` to ```mjd```.

# %% [markdown]
# ## How to query LSST and ZTF data for a given object <a class='anchor' id='query_one_lsst_ztf'></a>

# %% [markdown]
# Here we illustrate a cone search through the ALeRCE client as an example. This case is useful to explore LSST and ZTF data for an object from an external catalog whose equatorial coordinates are known. Along this example we show how to query several properties, like basic statistics and light curves.
#
# Let us say we want to know if the known supernova [SN 2026asx](https://www.wis-tns.org/object/2026asx) has triggered Rubin and/or ZTF alerts. This object has equatorial coordinates (187.020186, 6.967836) deg, and was reported by ALeRCE to the [Transient Name Server](https://www.wis-tns.org/) based on ZTF detections. According to the TNS report, its host (LEDA 1311098) has redshift $z = 0.076$. We use a cone search with a small radius (e.g. 1.5 arcsec)

# %%
ra = 187.020186
dec = 6.967836
z_obj = 0.076
radius = 1.5

# %% [markdown]
# Note that you need to provide object coordinates in equatorial system in deg, and search radius in arcsec. If found, this query will return the main properties of the matching object

# %%
df_obj_lsst = alerce_client.query_objects(
    survey='lsst',
    ra=ra,
    dec=dec,
    radius=radius
)
df_obj_lsst
# Out:
#                   oid  tid  sid      meanra   meandec       sigmara  \
# 0  170028526513684557    1    1  187.020189  6.967839  1.241193e-07
#
#        sigmadec      firstmjd       lastmjd  deltamjd  n_det  n_forced  \
# 0  1.279507e-07  61090.247937  61098.241373  7.993435    526       552
#
#    n_non_det stellar class_name              classifier_name  \
# 0          0    None         SN  stamp_classifier_rubin_beta
#
#   classfier_version  probability  ranking
# 0              None     0.984521        1

# %%
df_obj_ztf = alerce_client.query_objects(
    survey='ztf',
    ra=ra,
    dec=dec,
    radius=radius
)
df_obj_ztf
# Out:
#             oid ndethist  ncovhist  mjdstarthist    mjdendhist  corrected  \
# 0  ZTF26aacextk       23      2217   61058.43963  61078.519271      False
#
#    stellar  ndet g_r_max g_r_max_corr g_r_mean g_r_mean_corr     firstmjd  \
# 0    False     6    None         None     None          None  61059.56081
#
#         lastmjd    deltajd      meanra   meandec   sigmara  sigmadec class  \
# 0  61078.519271  18.958461  187.020241  6.967839  0.030032   0.02981  None
#
#   classifier probability    step_id_corr
# 0       None        None  27.5.7a32.dev1

# %% [markdown]
# Now that we know the object identifiers in LSST and ZTF we can query its detections in each survey. For LSST we use its ```sid``` from the output table, while for ZTF we use ```sid = 0```

# %%
oid_lsst = df_obj_lsst.loc[0, 'oid']
oid_ztf = df_obj_ztf.loc[0, 'oid']

# %%
sid_lsst = df_obj_lsst.loc[0, 'sid']
sid_ztf = 0

# %% [markdown]
# ### Generate ALeRCE Explorer links <a class='anchor' id='explorer_url'></a>

# %% [markdown]
# Note that the interfaces accept a maximum of 200 objects

# %%
def print_link_lsst(index=None):
    if len(index) == 1:
        expr = 'https://lsst.alerce.online/object/' + str(index[0]) \
               + '?survey=lsst'
    else:
        expr1 = 'https://lsst.alerce.online/?oid='
        expr2 = ','.join(list([str(x) for x in index]))
        expr3 = '&survey=lsst'
        expr = expr1 + expr2 + expr3
    
    display(HTML("<a href='%s' target=\"_blank\"> %s <a>" % (expr, expr)))

# %%
def print_link_ztf(index=None, classifier=None):
    expr1 = 'https://alerce.online/?oid='
    expr2 = '&oid='.join(list(index))
    expr3 = '&selectedClassifier=' + classifier + '_classifier&page=1'
    expr = expr1 + expr2 + expr3

    display(HTML("<a href='%s' target=\"_blank\"> %s <a>" % (expr, expr)))

# %%
print_link_lsst(index=[oid_lsst])
print_link_ztf(index=[oid_ztf], classifier='stamp')
# Out:
# <a href='https://lsst.alerce.online/object/170028526513684557?survey=lsst' target="_blank"> https://lsst.alerce.online/object/170028526513684557?survey=lsst <a>
# <a href='https://alerce.online/?oid=ZTF26aacextk&selectedClassifier=stamp_classifier&page=1' target="_blank"> https://alerce.online/?oid=ZTF26aacextk&selectedClassifier=stamp_classifier&page=1 <a>

# %% [markdown]
# ### Light curves <a class='anchor' id='light_curves'></a>

# %% [markdown]
# We obtain its light curve (detections and forced photometry points) by using the ```query_detections``` and ```query_forced_photometry ```functions

# %%
df_dets_lsst = alerce_client.query_detections(
    oid_lsst,
    survey='lsst',
    format='pandas'
)
display(df_dets_lsst)
# Out:
#      band           mjd survey_id          ra       dec                 oid  \
# 0       3  61090.247937      lsst  187.020188  6.967830  170028526513684557
# 1       3  61090.248460      lsst  187.020186  6.967837  170028526513684557
# 2       3  61090.248928      lsst  187.020187  6.967841  170028526513684557
# 3       3  61090.249392      lsst  187.020190  6.967834  170028526513684557
# 4       3  61090.249860      lsst  187.020188  6.967830  170028526513684557
# ..    ...           ...       ...         ...       ...                 ...
# 521     2  61098.239503      lsst  187.020189  6.967841  170028526513684557
# 522     2  61098.239970      lsst  187.020193  6.967841  170028526513684557
# 523     2  61098.240440      lsst  187.020189  6.967839  170028526513684557
# 524     2  61098.240904      lsst  187.020187  6.967837  170028526513684557
# 525     2  61098.241373      lsst  187.020191  6.967841  170028526513684557
#
#          measurement_id  parentDiaSourceId         diaObjectId    psfFlux  \
# 0    170028526513684557                  0  170028526513684557  28242.050
# 525  2272.81860  0.033214          False  20281.531  564.57837        False
#
#      apFlux_flag_apertureTruncated  isNegative        snr psfLnL    psfChi2  \
# 0                            False       False  76.423260   None  1775.4773
# 1                            False       False  74.090126   None  1606.1893
# 2                            False       False  79.224450   None  1826.5992
# 3                            False       False  72.395950   None  1588.3430
# 4                            False       False  74.018690   None  1684.8805
# ..                             ...         ...        ...    ...        ...
# 521                          False       False  81.164150   None  1690.3773
# 522                          False       False  82.001940   None  1813.2837
# 523                          False       False  85.261475   None  1620.2916
# 524                          False       False  80.572230   None  1623.4309
# 525                          False       False  84.771010   None  1752.9266
#
#      psfNdata  trailFlux  trailFluxErr     trailRa trailRaErr  trailDec  \
# 0        1681  27233.220      0.699775  187.020189       None  6.967829
# 1        1681  26824.934      0.011511  187.020187       None  6.967838
# 2        1681  28082.600      0.376741  187.020187       None  6.967841
# 3        1681  26803.895      0.140040  187.020191       None  6.967834
# 4        1681  27319.984      0.077404  187.020189       None  6.967830
# ..        ...        ...           ...         ...        ...       ...
# 521      1681  21218.205      0.510520  187.020189       None  6.967841
# 522      1681  20913.078      1.050264  187.020193       None  6.967841
# 523      1681  20895.156      1.350155  187.020191       None  6.967842
# 524      1681  20198.408      1.086755  187.020188       None  6.967838
# 525      1681  21032.979      1.290182  187.020192       None  6.967843
#
#     trailDecErr  trailLength trailLengthErr  trailAngle trailAngleErr  \
# 0          None     0.733123           None  114.661380          None
# 1          None     0.548408           None  103.760250          None
# 2          None     0.315864           None   98.725360          None
# 3          None     0.596485           None  125.201904          None
# 4          None     0.416224           None  -16.275635          None
# ..          ...          ...            ...         ...           ...
# 521        None     0.938773           None   36.683520          None
# 522        None     0.881609           None   45.040016          None
# 523        None     0.901682           None   41.261837          None
# 524        None     0.764273           None   46.705290          None
# 525        None     0.869178           None   42.288673          None
#
#     trailChi2  trailNdata  trail_flag_edge dipoleMeanFlux dipoleMeanFluxErr  \
# 0        None           0            False           None              None
# 1        None           0            False           None              None
# 2        None           0            False           None              None
# 3        None           0            False           None              None
# 4        None           0            False           None              None
# ..        ...         ...              ...            ...               ...
# 521      None           0            False           None              None
# 522      None           0            False           None              None
# 523      None           0            False           None              None
# 524      None           0            False           None              None
# 525      None           0            False           None              None
#
#     dipoleFluxDiff dipoleFluxDiffErr dipoleLength dipoleAngle dipoleChi2  \
# 0             None              None         None        None       None
# 1             None              None         None        None       None
# 2             None              None         None        None       None
# 3             None              None         None        None       None
# 4             None              None         None        None       None
# ..             ...               ...          ...         ...        ...
# 521           None              None         None        None       None
# 522           None              None         None        None       None
# 523           None              None         None        None       None
# 524           None              None         None        None       None
# 525           None              None         None        None       None
#
#      dipoleNdata  forced_PsfFlux_flag  forced_PsfFlux_flag_edge  \
# 0              0                False                     False
# 1              0                False                     False
# 2              0                False                     False
# 3              0                False                     False
# 4              0                False                     False
# ..           ...                  ...                       ...
# 521            0                False                     False
# 522            0                False                     False
# 523            0                False                     False
# 524            0                False                     False
# 525            0                False                     False
#
#      forced_PsfFlux_flag_noGoodPixels  templateFlux  templateFluxErr  \
# 0                               False     46383.430        23.967625
# 1                               False     48106.562        18.704697
# 2                               False     46111.094        23.524155
# 3                               False     51603.746        17.156672
# 4                               False     49205.926        18.719421
# ..                                ...           ...              ...
# 521                             False     20141.656        25.397350
# 522                             False     18638.290        36.304020
# 523                             False     17889.790        54.613045
# 524                             False     19970.322        28.857027
# 525                             False     17990.950        36.631615
#
#           ixx       iyy       ixy    ixxPSF    iyyPSF    ixyPSF  shape_flag  \
# 0    0.258646  0.304292  0.005605  0.265069  0.314855  0.003109       False
# 1    0.323573  0.324159  0.012824  0.321277  0.301220  0.005265       False
# 2    0.321203  0.320733  0.004183  0.313450  0.294817  0.003391       False
# 3    0.328384  0.353651  0.008485  0.316669  0.349283  0.009625       False
# 4    0.308005  0.317539 -0.005554  0.294611  0.315395 -0.004665       False
# ..        ...       ...       ...       ...       ...       ...         ...
# 521  0.245845  0.166318 -0.009849  0.230407  0.158573 -0.007714       False
# 522  0.224939  0.153851  0.005489  0.225371  0.147266  0.007098       False
# 523  0.213062  0.137369  0.004833  0.210136  0.132984  0.002594       False
# 524  0.207302  0.159117  0.010778  0.217301  0.160105  0.008992       False
# 525  0.203208  0.137366  0.012639  0.207425  0.140687  0.008019       False
#
#      shape_flag_no_pixels  shape_flag_not_contained  shape_flag_parent_source  \
# 0                   False                     False                     False
# 1                   False                     False                     False
# 2                   False                     False                     False
# 3                   False                     False                     False
# 4                   False                     False                     False
# ..                    ...                       ...                       ...
# 521                 False                     False                     False
# 522                 False                     False                     False
# 523                 False                     False                     False
# 524                 False                     False                     False
# 525                 False                     False                     False
#
#      extendedness  reliability  isDipole  dipoleFitAttempted  \
# 0        0.006199     0.999984     False               False
# 1        0.012710     0.999961     False               False
# 2        0.023009     0.999987     False               False
# 3        0.004842     0.999927     False               False
# 4        0.004937     0.999932     False               False
# ..            ...          ...       ...                 ...
# 521      0.017116     0.999914     False               False
# 522      0.001268     0.999822     False               False
# 523      0.001944     0.999677     False               False
# 524      0.003988     0.999724     False               False
# 525      0.002037     0.999732     False               False
#
#      timeProcessedMjdTai timeWithdrawnMjdTai  bboxSize  pixelFlags  \
# 0           61090.249555                None        33       False
# 1           61090.250148                None        39       False
# 2           61090.250538                None        58       False
# 3           61090.251117                None        40       False
# 4           61090.251622                None        57       False
# ..                   ...                 ...       ...         ...
# 521         61098.241052                None        27       False
# 522         61098.241581                None        25       False
# 523         61098.242058                None        25       False
# 524         61098.242520                None        25       False
# 525         61098.242920                None        25       False
#
#      pixelFlags_bad  pixelFlags_cr  pixelFlags_crCenter  pixelFlags_edge  \
# 0             False          False                False            False
# 1             False          False                False            False
# 2             False          False                False            False
# 3             False          False                False            False
# 4             False          False                False            False
# ..              ...            ...                  ...              ...
# 521           False          False                False            False
# 522           False          False                False            False
# 523           False          False                False            False
# 524           False          False                False            False
# 525           False          False                False            False
#
#      pixelFlags_nodata  pixelFlags_nodataCenter  pixelFlags_interpolated  \
# 0                False                    False                    False
# 1                False                    False                    False
# 2                False                    False                    False
# 3                False                    False                    False
# 4                False                    False                    False
# ..                 ...                      ...                      ...
# 521              False                    False                    False
# 522              False                    False                    False
# 523              False                    False                    False
# 524              False                    False                    False
# 525              False                    False                    False
#
#      pixelFlags_interpolatedCenter  pixelFlags_offimage  pixelFlags_saturated  \
# 0                            False                False                 False
# 1                            False                False                 False
# 2                            False                False                 False
# 3                            False                False                 False
# 4                            False                False                 False
# ..                             ...                  ...                   ...
# 521                          False                False                 False
# 522                          False                False                 False
# 523                          False                False                 False
# 524                          False                False                 False
# 525                          False                False                 False
#
#      pixelFlags_saturatedCenter  pixelFlags_suspect  pixelFlags_suspectCenter  \
# 0                         False               False                     False
# 1                         False               False                     False
# 2                         False               False                     False
# 3                         False               False                     False
# 4                         False               False                     False
# ..                          ...                 ...                       ...
# 521                       False               False                     False
# 522                       False               False                     False
# 523                       False               False                     False
# 524                       False               False                     False
# 525                       False               False                     False
#
#      pixelFlags_streak  pixelFlags_streakCenter  pixelFlags_injected  \
# 0                False                    False                False
# 1                False                    False                False
# 2                False                    False                False
# 3                False                    False                False
# 4                False                    False                False
# ..                 ...                      ...                  ...
# 521              False                    False                False
# 522              False                    False                False
# 523              False                    False                False
# 524              False                    False                False
# 525              False                    False                False
#
#      pixelFlags_injectedCenter  pixelFlags_injected_template  \
# 0                        False                         False
# 1                        False                         False
# 2                        False                         False
# 3                        False                         False
# 4                        False                         False
# ..                         ...                           ...
# 521                      False                         False
# 522                      False                         False
# 523                      False                         False
# 524                      False                         False
# 525                      False                         False
#
#      pixelFlags_injected_templateCenter  glint_trail band_name
# 0                                 False        False         i
# 1                                 False        False         i
# 2                                 False        False         i
# 3                                 False        False         i
# 4                                 False        False         i
# ..                                  ...          ...       ...
# 521                               False        False         r
# 522                               False        False         r
# 523                               False        False         r
# 524                               False        False         r
# 525                               False        False         r
#
# [526 rows x 102 columns]

# %%
df_dets_ztf = alerce_client.query_detections(
    oid_ztf,
    survey='ztf',
    format='pandas'
)
df_dets_ztf['oid'] = oid_ztf
display(df_dets_ztf)
# Out:
#    tid           mjd               candid  fid            pid  diffmaglim  \
# 0  ztf  61059.560810  3305560815515015025    1  3305560815515   20.492268
# 1  ztf  61061.454224  3307454225515015023    1  3307454225515   20.578934
# 2  ztf  61061.543889  3307543885515015017    2  3307543885515   19.945002
# 3  ztf  61069.459850  3315459845515015013    2  3315459845515   19.763500
# 4  ztf  61069.508484  3315508485515015025    1  3315508485515   20.310700
# 5  ztf  61078.519271  3324519275515015004    2  3324519275515   19.720327
#
#    isdiffpos   nid    distnr     magpsf    magap  sigmapsf  sigmagap  \
# 0          1  3305  1.491836  20.141708  20.1365  0.183754    0.2805
# 1          1  3307  1.715862  20.073265  20.1090  0.212786    0.2520
# 2          1  3307  4.528496  19.761988  19.4851  0.160267    0.2668
# 3          1  3315  4.357890  19.411000  19.3742  0.213132    0.2418
# 4          1  3315  1.355290  19.838900  20.2155  0.237601    0.3167
# 5          1  3324  4.301351  19.594992  19.7324  0.179135    0.3838
#
#            ra       dec        rb  rbversion       drb  magapbig  sigmagapbig  \
# 0  187.020236  6.967859  0.764286  t17_f5_c3  0.999971   20.1899       0.3743
# 1  187.020232  6.967944  0.820000  t17_f5_c3  0.999997   20.0094       0.2916
# 2  187.020187  6.967794  0.800000  t17_f5_c3  0.999894   19.4458       0.3278
# 16  1.868   20.302799          1    0.180    473     0.000018          0
# 17  5.745   20.000099          1    0.429    473     0.000014          0
# 18  1.868   19.861099          1    0.180    473     0.000035          0
# 19  1.868   19.874001          1    0.180    473     0.000025          0

# %% [markdown]
# We show these light curves together using a custom function defined in ```lib_multisurvey```

# %%
sys.path.append('./lib_multisurvey')
import alerce_multisurvey_tools as ms

# %% [markdown]
# We define some dictionaries to customize how to show the light curves. We will show both difference and science fluxes, including detections and (when available) forced photometry epochs

# %%
# More parameters (and their default values) defined in
# lib_multisurvey/alerce_multisurvey_tools.py, function plot_lc
lc_params = {
    'use_mag': False,
    'use_flux': True,
    'show_yr': False,
    'figwidth': 8,
    'pheight': 3,
    'fontsize': 9,
    'alpha': 0.5,
}

# %%
df_dets_lsst.set_index('oid', inplace=True)
if len(df_forced_lsst) > 0:
    df_forced_lsst.set_index('oid', inplace=True)

epochs_lsst = {
    'detections': df_dets_lsst,
    'forced_photometry': df_forced_lsst,
}

# %% [markdown]
# For ZTF data, we obtain flux density measurements from magnitudes, and adapt the column that contains filter information to the input expected by the custom function

# %%
def flux_epochs_ztf(df=None, col_mag=None, col_magerr=None,
                    col_isdiffpos='isdiffpos'):
    df = df.copy()
    
    df['fluxdiff_nJy'] = ms.mag2fluxnjy(df[col_mag]) * df[col_isdiffpos]
    df['fluxdiff_err_nJy'] = ms.mag_err_2_fluxnjy_err(df[col_magerr], df[col_mag])
    
    if col_mag + '_corr' in df.columns:
        df['fluxsci_nJy'] = ms.mag2fluxnjy(df[col_mag + '_corr'])
        mask = ~df[col_magerr + '_corr_ext'].isna() & ~df[col_magerr + '_corr_ext'].isna()
        df.loc[mask, 'fluxsci_err_nJy'] = ms.mag_err_2_fluxnjy_err(df[col_magerr + '_corr_ext'], df[col_mag + '_corr'])
        df.loc[~mask, 'fluxsci_err_nJy'] = np.nan
    
    return df

# %%
df_dets_ztf['band'] = [ms.sid_map_bands[sid_ztf][x] for x in df_dets_ztf['fid']]
df_dets_ztf = flux_epochs_ztf(df_dets_ztf, col_mag='magpsf', col_magerr='sigmapsf')

# %%
df_forced_ztf['band'] = [ms.sid_map_bands[sid_ztf][x] for x in df_forced_ztf['fid']]
df_forced_ztf = flux_epochs_ztf(df_forced_ztf, col_mag='mag', col_magerr='e_mag')

# %%
df_dets_ztf.set_index('oid', inplace=True)
if len(df_forced_ztf) > 0:
    df_forced_ztf.set_index('oid', inplace=True)

epochs_ztf = {
    'detections': df_dets_ztf,
    'forced_photometry': df_forced_ztf,
}

# %%
d_objs = ms.group_data_sid_oid(
    sid=sid_lsst,
    oid=oid_lsst,
    df_dets=epochs_lsst['detections'].copy(),
    df_forced=epochs_lsst['forced_photometry'].copy() \
        if oid_lsst in epochs_lsst['forced_photometry'].index else pd.DataFrame(),
    lc_kwargs=ms.init_lc_kwargs()
)

# %%
d_objs = ms.group_data_sid_oid(
    d_objs=d_objs,
    sid=sid_ztf,
    oid=oid_ztf,
    df_dets=epochs_ztf['detections'].copy(),
    df_forced=epochs_ztf['forced_photometry'].copy() \
        if oid_ztf in epochs_ztf['forced_photometry'].index else pd.DataFrame(),
    lc_kwargs=ms.init_lc_kwargs()
)

# %% [markdown]
# We show the light curves

# %%
d_objs[sid_lsst][oid_lsst]['lc_kwargs']['show_forced'] = True
d_objs[sid_ztf][oid_ztf]['lc_kwargs']['show_forced'] = True

ms.plot_lc_1panel(d_objs=d_objs, lc_params=lc_params)

# %% [markdown]
# We can show these light curves using magnitude units

# %%
d_objs[sid_lsst][oid_lsst]['lc_kwargs']['show_flux'] = False
d_objs[sid_lsst][oid_lsst]['lc_kwargs']['show_forced'] = False

d_objs[sid_ztf][oid_ztf]['lc_kwargs']['show_flux'] = False
d_objs[sid_ztf][oid_ztf]['lc_kwargs']['show_forced'] = False

ms.plot_lc_1panel(d_objs=d_objs, lc_params=lc_params)

# %% [markdown]
# We can also show them using absolute magnitudes, assuming the redshift of the tentative host and the Planck 2018 cosmology

# %%
d_objs[sid_lsst][oid_lsst]['lc_kwargs']['show_absolute_mag'] = True
d_objs[sid_lsst][oid_lsst]['lc_kwargs']['z_obj'] = z_obj
d_objs[sid_lsst][oid_lsst]['lc_kwargs']['cosmo'] = Planck18

d_objs[sid_ztf][oid_ztf]['lc_kwargs']['show_absolute_mag'] = True
d_objs[sid_ztf][oid_ztf]['lc_kwargs']['z_obj'] = z_obj
d_objs[sid_ztf][oid_ztf]['lc_kwargs']['cosmo'] = Planck18

ms.plot_lc_1panel(d_objs=d_objs, lc_params=lc_params)

# %% [markdown]
# ### Features <a class='anchor' id='features'></a>

# %% [markdown]
# We query the features computed by ALeRCE in each survey. For LSST this is done using TAP, while for ZTF is done through a direct connection to our database.
#
# For LSST, note that we use integer identifiers for both feature names and LSST bands. We recover the original names using the mapping defined in the ```feature_name_lut``` and ```band``` lookup tables (LUTs) respectively.

# %%
table_name = 'feature_name_lut'

query = '''
SELECT
    *
FROM
    alerce_tap.%s
    WHERE
        tid = %d
''' % (table_name, tid)
df_feature_names = alerce_tap.search(query).to_table().to_pandas()

display(df_feature_names)
# Out:
#      feature_id feature_name created_date  sid  tid
# 0             0     u-g_mean   2026-02-13    1    1
# 1             1      u-g_max   2026-02-13    1    1
# 2             2     g-r_mean   2026-02-13    1    1
# 3             3      g-r_max   2026-02-13    1    1
# 4             4     r-i_mean   2026-02-13    1    1
# ..          ...          ...          ...  ...  ...
# 141         141         z-W4   2026-02-13    1    1
# 142         142         y-W1   2026-02-13    1    1
# 143         143         y-W2   2026-02-13    1    1
# 144         144         y-W3   2026-02-13    1    1
# 145         145         y-W4   2026-02-13    1    1
#
# [146 rows x 5 columns]

# %%
table_name = 'band'

query = '''
SELECT
    sid, tid, band, band_name, band_order
FROM
    alerce_tap.%s
WHERE
    tid = %d
ORDER BY
    sid ASC, band_order ASC
''' % (table_name, tid)

df_bands = alerce_tap.search(query).to_table().to_pandas()
display(df_bands)
# Out:
#     sid  tid  band band_name  band_order
# 0     1    1     6         u           0
# 1     1    1     1         g           1
# 2     1    1     2         r           2
# 3     1    1     3         i           3
# 4     1    1     4         z           4
# 5     1    1     5         y           5
# 6     2    1     6         u           0
# 7     2    1     1         g           1
# 8     2    1     2         r           2
# 9     2    1     3         i           3
# 10    2    1     4         z           4
# 11    2    1     5         y           5

# %%
query = '''
SELECT
    *
FROM
    alerce_tap.feature
WHERE
    oid = %d
    AND sid = %d
''' % (oid_lsst, sid_lsst)
df_ft_lsst = alerce_tap.search(query).to_table().to_pandas()

display(df_ft_lsst)
# Out:
#                     oid  sid  feature_id  band  version  feature_value  \
# 0    170028526513684557    1           2     0        1       1.315615
# 1    170028526513684557    1           3     0        1       1.038762
# 2    170028526513684557    1           4     0        1       0.228292
# 3    170028526513684557    1           5     0        1       0.158628
# 4    170028526513684557    1          12     0        1       0.808968
# ..                  ...  ...         ...   ...      ...            ...
# 258  170028526513684557    1         117     2        1      -0.744105
# 259  170028526513684557    1         117     3        1       0.105211
# 260  170028526513684557    1         118     1        1      24.089010
# 261  170028526513684557    1         118     2        1      22.774665
# 262  170028526513684557    1         118     3        1      19.462795
#
#     updated_date
# 0     2026-03-04
# 1     2026-03-04
# 2     2026-03-04
# 3     2026-03-04
# 4     2026-03-04
# ..           ...
# 258   2026-03-04
# 259   2026-03-04
# 260   2026-03-04
# 261   2026-03-04
# 262   2026-03-04
#
# [263 rows x 7 columns]

# %% [markdown]
# We create a function to apply the mapping between columns, useful for both LUTs

# %%
def add_mapped_column(df=None, df_lut=None,
                      col=None, col_mapped=None):
    def map_column(row):
        row_index = (row['sid'], row[col]) \
                    if 'sid' in df_lut.columns \
                    else row[col]
        col_new = df_aux.loc[
            row_index, col_mapped] \
            if row_index in df_aux.index \
            else None
        return col_new
    
    df = df.copy()

    if len(df) > 0:
        row_index = ['sid', col] if 'sid' in df_lut.columns else col
        df_aux = df_lut.set_index(row_index).copy()
        
        df[col_mapped] = df.apply(
            lambda row: map_column(row),
            axis=1)
    else:
        df[col_mapped] = None

    return df

# %%
df_ft_lsst = add_mapped_column(
    df=df_ft_lsst,
    df_lut=df_bands,
    col='band',
    col_mapped='band_name'
)

# %%
df_ft_lsst = add_mapped_column(
    df=df_ft_lsst,
    df_lut=df_feature_names,
    col='feature_id',
    col_mapped='feature_name')

# %% [markdown]
# We show the list of features retrieved (note that features with NaN values are not stored)

# %%
pd.set_option('display.max_rows', None)
display(df_ft_lsst)
pd.set_option('display.max_rows', 30)
# Out:
#                     oid  sid  feature_id  band  version  feature_value  \
# 0    170028526513684557    1           2     0        1   1.315615e+00
# 1    170028526513684557    1           3     0        1   1.038762e+00
# 2    170028526513684557    1           4     0        1   2.282916e-01
# 3    170028526513684557    1           5     0        1   1.586284e-01
# 4    170028526513684557    1          12     0        1   8.089678e-01
# 5    170028526513684557    1          13     0        1   6.920177e-01
# 6    170028526513684557    1          14     0        1   2.599193e-01
# 7    170028526513684557    1          15     0        1   2.432009e-01
# 8    170028526513684557    1          20     0        1   7.993832e+00
# 9    170028526513684557    1          21     0        1  -9.851729e-01
# 10   170028526513684557    1          22     0        1  -1.213164e-01
# 11   170028526513684557    1          23     0        1   1.213122e-01
# 12   170028526513684557    1          24     1        1   3.033234e+00
# 13   170028526513684557    1          24     2        1   1.599357e+00
# 14   170028526513684557    1          24     3        1   1.396696e-01
# 15   170028526513684557    1          25     1        1   1.683736e+00
# 16   170028526513684557    1          25     2        1   1.330078e+00
# 17   170028526513684557    1          25     3        1   2.368937e+00
# 18   170028526513684557    1          26     1        1   9.338158e+00
# 19   170028526513684557    1          26     2        1   1.392453e+01
# 20   170028526513684557    1          26     3        1   1.966041e+01
# 21   170028526513684557    1          27     0        1   6.248638e-01
# 249  170028526513684557    1         114     2        1   1.879375e+02
# 250  170028526513684557    1         114     3        1   1.391708e-01
# 251  170028526513684557    1         115     1        1   9.999998e-01
# 252  170028526513684557    1         115     2        1   9.999999e-01
# 253  170028526513684557    1         115     3        1   9.172254e-01
# 254  170028526513684557    1         116     1        1   4.986123e+01
# 255  170028526513684557    1         116     2        1   5.008502e+01
# 256  170028526513684557    1         116     3        1   3.654877e+01
# 257  170028526513684557    1         117     1        1  -8.528660e-01
# 258  170028526513684557    1         117     2        1  -7.441054e-01
# 259  170028526513684557    1         117     3        1   1.052107e-01
# 260  170028526513684557    1         118     1        1   2.408901e+01
# 261  170028526513684557    1         118     2        1   2.277467e+01
# 262  170028526513684557    1         118     3        1   1.946279e+01
#
#     updated_date band_name                  feature_name
# 0     2026-03-04      None                      g-r_mean
# 1     2026-03-04      None                       g-r_max
# 2     2026-03-04      None                      r-i_mean
# 3     2026-03-04      None                       r-i_max
# 4     2026-03-04      None                 g-r_mean_corr
# 5     2026-03-04      None                  g-r_max_corr
# 6     2026-03-04      None                 r-i_mean_corr
# 7     2026-03-04      None                  r-i_max_corr
# 8     2026-03-04      None                      Timespan
# 9     2026-03-04      None                  Coordinate_x
# 10    2026-03-04      None                  Coordinate_y
# 11    2026-03-04      None                  Coordinate_z
# 12    2026-03-04         g                     TDE_decay
# 13    2026-03-04         r                     TDE_decay
# 14    2026-03-04         i                     TDE_decay
# 15    2026-03-04         g                 TDE_decay_chi
# 16    2026-03-04         r                 TDE_decay_chi
# 17    2026-03-04         i                 TDE_decay_chi
# 18    2026-03-04         g                      TDE_mag0
# 19    2026-03-04         r                      TDE_mag0
# 20    2026-03-04         i                      TDE_mag0
# 21    2026-03-04      None              Multiband_period
# 22    2026-03-04      None                           PPE
# 23    2026-03-04         g                   Period_band
# 24    2026-03-04         r                   Period_band
# 25    2026-03-04         i                   Period_band
# 26    2026-03-04         g                  delta_period
# 27    2026-03-04         r                  delta_period
# 28    2026-03-04         i                  delta_period
# 29    2026-03-04      None                Power_rate_1/4
# 30    2026-03-04      None                Power_rate_1/3
# 31    2026-03-04      None                Power_rate_1/2
# 32    2026-03-04      None                  Power_rate_2
# 33    2026-03-04      None                  Power_rate_3
# 34    2026-03-04      None                  Power_rate_4
# 35    2026-03-04         g                    MHPS_ratio
# 36    2026-03-04         r                    MHPS_ratio
# 37    2026-03-04         i                    MHPS_ratio
# 38    2026-03-04         g                      MHPS_low
# 39    2026-03-04         r                      MHPS_low
# 40    2026-03-04         i                      MHPS_low
# 41    2026-03-04         g                     MHPS_high
# 42    2026-03-04         r                     MHPS_high
# 43    2026-03-04         i                     MHPS_high
# 44    2026-03-04         g                 MHPS_non_zero
# 45    2026-03-04         r                 MHPS_non_zero
# 46    2026-03-04         i                 MHPS_non_zero
# 47    2026-03-04         g                  MHPS_PN_flag
# 48    2026-03-04         r                  MHPS_PN_flag
# 49    2026-03-04         i                  MHPS_PN_flag
# 50    2026-03-04         g             MHPS_ratio_365_30
# 51    2026-03-04         r             MHPS_ratio_365_30
# 52    2026-03-04         i             MHPS_ratio_365_30
# 53    2026-03-04         g                  MHPS_low_365
# 54    2026-03-04         r                  MHPS_low_365
# 55    2026-03-04         i                  MHPS_low_365
# 56    2026-03-04         g                  MHPS_high_30
# 57    2026-03-04         r                  MHPS_high_30
# 58    2026-03-04         i                  MHPS_high_30
# 59    2026-03-04         g                  GP_DRW_sigma
# 60    2026-03-04         r                  GP_DRW_sigma
# 61    2026-03-04         i                  GP_DRW_sigma
# 62    2026-03-04         g                    GP_DRW_tau
# 63    2026-03-04         r                    GP_DRW_tau
# 64    2026-03-04         i                    GP_DRW_tau
# 65    2026-03-04         g                        Psi_CS
# 66    2026-03-04         r                        Psi_CS
# 67    2026-03-04         i                        Psi_CS
# 68    2026-03-04         g                       Psi_eta
# 69    2026-03-04         r                       Psi_eta
# 70    2026-03-04         i                       Psi_eta
# 71    2026-03-04         g                 Harmonics_mse
# 72    2026-03-04         r                 Harmonics_mse
# 73    2026-03-04         i                 Harmonics_mse
# 74    2026-03-04         g                 Harmonics_chi
# 75    2026-03-04         r                 Harmonics_chi
# 76    2026-03-04         i                 Harmonics_chi
# 77    2026-03-04         g               Harmonics_mag_1
# 78    2026-03-04         r               Harmonics_mag_1
# 79    2026-03-04         i               Harmonics_mag_1
# 80    2026-03-04         g               Harmonics_mag_2
# 81    2026-03-04         r               Harmonics_mag_2
# 82    2026-03-04         i               Harmonics_mag_2
# 83    2026-03-04         g             Harmonics_phase_2
# 84    2026-03-04         r             Harmonics_phase_2
# 85    2026-03-04         i             Harmonics_phase_2
# 86    2026-03-04         g               Harmonics_mag_3
# 87    2026-03-04         r               Harmonics_mag_3
# 88    2026-03-04         i               Harmonics_mag_3
# 89    2026-03-04         g             Harmonics_phase_3
# 90    2026-03-04         r             Harmonics_phase_3
# 91    2026-03-04         i             Harmonics_phase_3
# 92    2026-03-04         g               Harmonics_mag_4
# 93    2026-03-04         r               Harmonics_mag_4
# 94    2026-03-04         i               Harmonics_mag_4
# 95    2026-03-04         g             Harmonics_phase_4
# 96    2026-03-04         r             Harmonics_phase_4
# 97    2026-03-04         i             Harmonics_phase_4
# 98    2026-03-04         g               Harmonics_mag_5
# 99    2026-03-04         r               Harmonics_mag_5
# 100   2026-03-04         i               Harmonics_mag_5
# 101   2026-03-04         g             Harmonics_phase_5
# 102   2026-03-04         r             Harmonics_phase_5
# 103   2026-03-04         i             Harmonics_phase_5
# 104   2026-03-04         g               Harmonics_mag_6
# 105   2026-03-04         r               Harmonics_mag_6
# 106   2026-03-04         i               Harmonics_mag_6
# 107   2026-03-04         g             Harmonics_phase_6
# 108   2026-03-04         r             Harmonics_phase_6
# 109   2026-03-04         i             Harmonics_phase_6
# 110   2026-03-04         g               Harmonics_mag_7
# 111   2026-03-04         r               Harmonics_mag_7
# 112   2026-03-04         i               Harmonics_mag_7
# 113   2026-03-04         g             Harmonics_phase_7
# 114   2026-03-04         r             Harmonics_phase_7
# 115   2026-03-04         i             Harmonics_phase_7
# 116   2026-03-04         g                     Amplitude
# 117   2026-03-04         r                     Amplitude
# 118   2026-03-04         i                     Amplitude
# 119   2026-03-04         g               AndersonDarling
# 120   2026-03-04         r               AndersonDarling
# 121   2026-03-04         i               AndersonDarling
# 122   2026-03-04         g                Autocor_length
# 123   2026-03-04         r                Autocor_length
# 124   2026-03-04         i                Autocor_length
# 125   2026-03-04         g                    Beyond1Std
# 126   2026-03-04         r                    Beyond1Std
# 127   2026-03-04         i                    Beyond1Std
# 128   2026-03-04         g                           Con
# 129   2026-03-04         r                           Con
# 130   2026-03-04         i                           Con
# 131   2026-03-04         g                         Eta_e
# 132   2026-03-04         r                         Eta_e
# 133   2026-03-04         i                         Eta_e
# 134   2026-03-04         g                         Gskew
# 135   2026-03-04         r                         Gskew
# 136   2026-03-04         i                         Gskew
# 137   2026-03-04         g                      MaxSlope
# 138   2026-03-04         r                      MaxSlope
# 139   2026-03-04         i                      MaxSlope
# 140   2026-03-04         g                          Mean
# 141   2026-03-04         r                          Mean
# 142   2026-03-04         i                          Mean
# 143   2026-03-04         g                  Meanvariance
# 144   2026-03-04         r                  Meanvariance
# 145   2026-03-04         i                  Meanvariance
# 146   2026-03-04         g                  MedianAbsDev
# 147   2026-03-04         r                  MedianAbsDev
# 148   2026-03-04         i                  MedianAbsDev
# 149   2026-03-04         g                     MedianBRP
# 150   2026-03-04         r                     MedianBRP
# 151   2026-03-04         i                     MedianBRP
# 152   2026-03-04         g                PairSlopeTrend
# 153   2026-03-04         r                PairSlopeTrend
# 154   2026-03-04         i                PairSlopeTrend
# 155   2026-03-04         g              PercentAmplitude
# 156   2026-03-04         r              PercentAmplitude
# 157   2026-03-04         i              PercentAmplitude
# 158   2026-03-04         g                           Q31
# 159   2026-03-04         r                           Q31
# 160   2026-03-04         i                           Q31
# 161   2026-03-04         g                           Rcs
# 162   2026-03-04         r                           Rcs
# 163   2026-03-04         i                           Rcs
# 164   2026-03-04         g                          Skew
# 165   2026-03-04         r                          Skew
# 166   2026-03-04         i                          Skew
# 167   2026-03-04         g                 SmallKurtosis
# 168   2026-03-04         r                 SmallKurtosis
# 169   2026-03-04         i                 SmallKurtosis
# 170   2026-03-04         g                           Std
# 171   2026-03-04         r                           Std
# 172   2026-03-04         i                           Std
# 173   2026-03-04         g                      StetsonK
# 174   2026-03-04         r                      StetsonK
# 175   2026-03-04         i                      StetsonK
# 176   2026-03-04         g                          Pvar
# 177   2026-03-04         r                          Pvar
# 178   2026-03-04         i                          Pvar
# 179   2026-03-04         g                     ExcessVar
# 180   2026-03-04         r                     ExcessVar
# 181   2026-03-04         i                     ExcessVar
# 182   2026-03-04         g               SF_ML_amplitude
# 183   2026-03-04         r               SF_ML_amplitude
# 184   2026-03-04         i               SF_ML_amplitude
# 185   2026-03-04         g                   SF_ML_gamma
# 186   2026-03-04         r                   SF_ML_gamma
# 187   2026-03-04         i                   SF_ML_gamma
# 188   2026-03-04         g                       IAR_phi
# 189   2026-03-04         r                       IAR_phi
# 190   2026-03-04         i                       IAR_phi
# 191   2026-03-04         g                   LinearTrend
# 192   2026-03-04         r                   LinearTrend
# 193   2026-03-04         i                   LinearTrend
# 194   2026-03-04         g                         SPM_A
# 195   2026-03-04         r                         SPM_A
# 196   2026-03-04         i                         SPM_A
# 197   2026-03-04         g                        SPM_t0
# 198   2026-03-04         r                        SPM_t0
# 199   2026-03-04         i                        SPM_t0
# 200   2026-03-04         g                     SPM_gamma
# 201   2026-03-04         r                     SPM_gamma
# 202   2026-03-04         i                     SPM_gamma
# 203   2026-03-04         g                      SPM_beta
# 204   2026-03-04         r                      SPM_beta
# 205   2026-03-04         i                      SPM_beta
# 206   2026-03-04         g                  SPM_tau_rise
# 207   2026-03-04         r                  SPM_tau_rise
# 208   2026-03-04         i                  SPM_tau_rise
# 209   2026-03-04         g                  SPM_tau_fall
# 210   2026-03-04         r                  SPM_tau_fall
# 211   2026-03-04         i                  SPM_tau_fall
# 212   2026-03-04         g                       SPM_chi
# 213   2026-03-04         r                       SPM_chi
# 214   2026-03-04         i                       SPM_chi
# 215   2026-03-04         g                       fleet_a
# 216   2026-03-04         r                       fleet_a
# 217   2026-03-04         i                       fleet_a
# 218   2026-03-04         g                       fleet_w
# 219   2026-03-04         r                       fleet_w
# 220   2026-03-04         i                       fleet_w
# 221   2026-03-04         g                     fleet_chi
# 222   2026-03-04         r                     fleet_chi
# 223   2026-03-04         i                     fleet_chi
# 224   2026-03-04         g                      fleet_m0
# 225   2026-03-04         r                      fleet_m0
# 226   2026-03-04         i                      fleet_m0
# 227   2026-03-04         g                      fleet_t0
# 228   2026-03-04         r                      fleet_t0
# 229   2026-03-04         i                      fleet_t0
# 230   2026-03-04         g             positive_fraction
# 231   2026-03-04         r             positive_fraction
# 232   2026-03-04         i             positive_fraction
# 233   2026-03-04         g     n_forced_phot_band_before
# 234   2026-03-04         r     n_forced_phot_band_before
# 235   2026-03-04         i     n_forced_phot_band_before
# 236   2026-03-04         g      n_forced_phot_band_after
# 237   2026-03-04         r      n_forced_phot_band_after
# 238   2026-03-04         i      n_forced_phot_band_after
# 239   2026-03-04         g     max_brightness_after_band
# 240   2026-03-04         r     max_brightness_after_band
# 241   2026-03-04         i     max_brightness_after_band
# 242   2026-03-04         g  median_brightness_after_band
# 243   2026-03-04         r  median_brightness_after_band
# 244   2026-03-04         i  median_brightness_after_band
# 245   2026-03-04         g                      ulens_u0
# 246   2026-03-04         r                      ulens_u0
# 247   2026-03-04         i                      ulens_u0
# 248   2026-03-04         g                      ulens_tE
# 249   2026-03-04         r                      ulens_tE
# 250   2026-03-04         i                      ulens_tE
# 251   2026-03-04         g                      ulens_fs
# 252   2026-03-04         r                      ulens_fs
# 253   2026-03-04         i                      ulens_fs
# 254   2026-03-04         g                     ulens_chi
# 255   2026-03-04         r                     ulens_chi
# 256   2026-03-04         i                     ulens_chi
# 257   2026-03-04         g                      ulens_t0
# 258   2026-03-04         r                      ulens_t0
# 259   2026-03-04         i                      ulens_t0
# 260   2026-03-04         g                    ulens_mag0
# 261   2026-03-04         r                    ulens_mag0
# 262   2026-03-04         i                    ulens_mag0

# %% [markdown]
# For ZTF, we open the connection and do an SQL query and show the list of features retrieved

# %%
url = "https://raw.githubusercontent.com/alercebroker/usecases/master/alercereaduser_v4.json"
params = requests.get(url).json()['params']

# %%
engine = sa.create_engine('postgresql+psycopg2://' + params['user'] \
                          + ':' + params['password'] + '@' + params['host'] \
                          + '/' + params['dbname'])
conn_ztf = engine.connect()

# %%
query = '''
SELECT
    *
FROM
    feature
WHERE
    oid = '%s'
''' % oid_ztf

df_feat_ztf = pd.read_sql_query(query, conn_ztf)

pd.set_option('display.max_rows', None)
display(df_feat_ztf)
pd.set_option('display.max_rows', 30)
# Out:
#               oid                           name       value  fid version
# 0    ZTF26aacextk                       g-r_mean    0.428631   12  27.5.6
# 1    ZTF26aacextk                        g-r_max    0.427900   12  27.5.6
# 2    ZTF26aacextk                  g-r_mean_corr         NaN   12  27.5.6
# 3    ZTF26aacextk                   g-r_max_corr         NaN   12  27.5.6
# 4    ZTF26aacextk                          W1-W2         NaN    0  27.5.6
# 5    ZTF26aacextk                          W2-W3         NaN    0  27.5.6
# 6    ZTF26aacextk                          W3-W4         NaN    0  27.5.6
# 7    ZTF26aacextk                           g-W1         NaN    0  27.5.6
# 8    ZTF26aacextk                           r-W1         NaN    0  27.5.6
# 9    ZTF26aacextk                           g-W2         NaN    0  27.5.6
# 10   ZTF26aacextk                           r-W2         NaN    0  27.5.6
# 11   ZTF26aacextk                           g-W3         NaN    0  27.5.6
# 12   ZTF26aacextk                           r-W3         NaN    0  27.5.6
# 13   ZTF26aacextk                           g-W4         NaN    0  27.5.6
# 14   ZTF26aacextk                           r-W4         NaN    0  27.5.6
# 15   ZTF26aacextk                       sgscore1    0.500000    0  27.5.6
# 16   ZTF26aacextk                      distpsnr1    2.953084    0  27.5.6
# 17   ZTF26aacextk                         ps_g-r         NaN    0  27.5.6
# 18   ZTF26aacextk                         ps_r-i   -0.092001    0  27.5.6
# 19   ZTF26aacextk                         ps_i-z         NaN    0  27.5.6
# 20   ZTF26aacextk                     MHPS_ratio         NaN    1  27.5.6
# 21   ZTF26aacextk                       MHPS_low         NaN    1  27.5.6
# 22   ZTF26aacextk                      MHPS_high         NaN    1  27.5.6
# 23   ZTF26aacextk                  MHPS_non_zero         NaN    1  27.5.6
# 24   ZTF26aacextk                   MHPS_PN_flag         NaN    1  27.5.6
# 25   ZTF26aacextk                     MHPS_ratio         NaN    2  27.5.6
# 26   ZTF26aacextk                       MHPS_low         NaN    2  27.5.6
# 27   ZTF26aacextk                      MHPS_high         NaN    2  27.5.6
# 28   ZTF26aacextk                  MHPS_non_zero         NaN    2  27.5.6
# 29   ZTF26aacextk                   MHPS_PN_flag         NaN    2  27.5.6
# 30   ZTF26aacextk              MHPS_ratio_365_30         NaN    1  27.5.6
# 31   ZTF26aacextk                   MHPS_low_365         NaN    1  27.5.6
# 32   ZTF26aacextk                   MHPS_high_30         NaN    1  27.5.6
# 33   ZTF26aacextk              MHPS_ratio_365_30         NaN    2  27.5.6
# 34   ZTF26aacextk                   MHPS_low_365         NaN    2  27.5.6
