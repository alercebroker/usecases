# %% [markdown]
# # ALeRCE client starter

# %% [markdown]
# Francisco Förster
#
# Last modification: 20221104
#
# Very simple examples on how to interact with the ALeRCE client https://alerce.readthedocs.io/en/latest/index.html.
#
# See https://alerce.readthedocs.io/en/latest/apis.html for the API documentation.
#
# We recommend that you run this notebook from the following [link](https://colab.research.google.com/github/alercebroker/usecases/blob/master/notebooks/ADASS_XXXII_Nov2022_tutorial/ALeRCE_Client_starter.ipynb).

# %% [markdown]
# Load libraries

# %%
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib.colors

# %%
#!pip install alerce

# %%
from alerce.core import Alerce

# %% [markdown]
# # Initialize alerce api object

# %% [markdown]
# Let's start the ALeRCE client

# %%
client = Alerce()

# %% [markdown]
# We will explore different methods from the client:
#
# * Query global properties of an individual object
# * Query properties per band of an individual object
# * Query detections of an individual object
# * Query image stamps
# * Crossmatch with objects in the vicinity
# * Query non detections of an individual object
# * Query features of an individual object
# * Query probabilities of an individual object
# * Query global properties of a group of objects

# %% [markdown]
# # Query properties for an individual object

# %% [markdown]
# We will now query the global properties of one object based on a given object id, ZTF20aaelulu in this case. You can see this object in the website https://alerce.online/object/ZTF20aaelulu.

# %%
oid = "ZTF20aaelulu"
query_results = client.query_objects(
        oid=oid,
        format='pandas')
properties = query_results # save for later
query_results
# Out:
#             oid ndethist  ncovhist  mjdstarthist    mjdendhist  corrected  \
# 0  ZTF20aaelulu      259       792  58855.458808  58967.227049      False
#
#    stellar  ndet   g_r_max g_r_max_corr  ...       lastmjd     deltajd  \
# 0    False    58  0.440634         None  ...  58967.227049  111.684757
#
#        meanra    meandec   sigmara  sigmadec  class  classifier  probability  \
# 0  185.728862  15.823611  0.000021  0.000015   None        None         None
#
#       step_id_corr
# 0  corr_bulk_0.0.1
#
# [1 rows x 23 columns]

# %% [markdown]
# The column names are the following

# %%
", ".join(query_results)
# Out:
# 'oid, ndethist, ncovhist, mjdstarthist, mjdendhist, corrected, stellar, ndet, g_r_max, g_r_max_corr, g_r_mean, g_r_mean_corr, firstmjd, lastmjd, deltajd, meanra, meandec, sigmara, sigmadec, class, classifier, probability, step_id_corr'

# %% [markdown]
# The columns are described in here https://alerce.readthedocs.io/en/latest/models.html

# %% [markdown]
# # Query properties per band for an indivual object

# %%
query_results = client.query_magstats(
        oid=oid,
        format='pandas')
query_results
# Out:
#    fid  stellar  corrected  ndet  ndubious    magmean  magmedian     magmax  \
# 0    1    False       True    31         0  17.011618  16.972418  18.607530
# 1    2    False      False    27         0  16.311693  16.427551  18.513012
#
#       magmin magsigma    maglast   magfirst   firstmjd    lastmjd  \
# 0  14.300256     None  18.607530  14.916227  58859.523  58967.227
# 1  13.859622     None  18.513012  17.279879  58855.543  58965.285
#
#          step_id_corr
# 0  bulk_version_0.0.1
# 1  bulk_version_0.0.1

# %% [markdown]
# You can see that the results are different statistics in two rows, one per band. The columns are described in here https://alerce.readthedocs.io/en/latest/models.html

# %%
", ".join(query_results)
# Out:
# 'fid, stellar, corrected, ndet, ndubious, magmean, magmedian, magmax, magmin, magsigma, maglast, magfirst, firstmjd, lastmjd, step_id_corr'

# %% [markdown]
# # Query detections and non-detections for an individual object

# %% [markdown]
# Now we obtain a list of all the detections and non-detections (limiting magnitude) in two bands.
#
# Note that both dataframes include a unique identifier for the telescope (`tid`), which hints at the multi-stream nature of ALeRCE (soon to be available).

# %%
detections = client.query_detections(
        oid=oid,
        format='pandas')
nondetections = client.query_non_detections(
        oid=oid,
        format='pandas')
display(detections)
display(nondetections)
# Out:
#     tid           mjd               candid  fid            pid  diffmaglim  \
# 0   ztf  58855.542292  1101542291015015004    2  1101542291015   20.367030
# 1   ztf  58859.481250  1105481241015015001    2  1105481241015   19.761808
# 2   ztf  58859.522280  1105522281015015000    1  1105522281015   19.590542
# 3   ztf  58867.440336  1113440331015015001    1  1113440331015   20.265388
# 4   ztf  58867.481562  1113481561015015006    2  1113481561015   20.348034
# 5   ztf  58871.442685  1117442681015015004    1  1117442681015   20.396467
# 6   ztf  58871.502234  1117502231015015005    2  1117502231015   20.242445
# 7   ztf  58875.456991  1121456991015015006    1  1121456991015   20.504930
# 8   ztf  58875.521076  1121521071015015006    2  1121521071015   20.243944
# 9   ztf  58878.360509  1124360501015015005    2  1124360501015   19.797495
# 10  ztf  58878.486551  1124486551015015005    1  1124486551015   20.345293
# 11  ztf  58881.461458  1127461451015015002    1  1127461451015   20.643034
# 12  ztf  58881.538657  1127538651015015005    2  1127538651015   20.477050
# 13  ztf  58884.442303  1130442301015015001    1  1130442301015   19.826284
# 14  ztf  58884.516238  1130516231015015000    2  1130516231015   19.908821
# 15  ztf  58887.425776  1133425771015015000    1  1133425771015   19.429384
# 16  ztf  58887.515914  1133515911015015002    2  1133515911015   19.709732
# 17  ztf  58892.316887  1138316881015015001    2  1138316881015   19.335730
# 18  ztf  58892.380914  1138380911015015004    1  1138380911015   19.602169
# 19  ztf  58895.384074  1141384071015015002    1  1141384071015   20.547344
# 20  ztf  58895.442454  1141442451015015004    2  1141442451015   20.353218
# 21  ztf  58898.373877  1144373871015015007    2  1144373871015   20.685673
# 22  ztf  58898.419491  1144419491015015008    1  1144419491015   20.836143
# 23  ztf  58899.400116  1145400111015015005    1  1145400111015   20.661860
# 24  ztf  58899.441007  1145441001015015005    2  1145441001015   20.569092
# 25  ztf  58900.437523  1146437521015015008    2  1146437521015   20.478890
# 26  ztf  58901.418901  1147418901015015006    2  1147418901015   20.551418
# 27  ztf  58903.356863  1149356861015015010    1  1149356861015   20.593908
# 28  ztf  58904.458808  1150458801015015003    1  1150458801015   20.413898
# 29  ztf  58904.470556  1150470551015015009    2  1150470551015   20.158913
# 30  ztf  58905.307396  1151307391015015004    1  1151307391015   20.119078
# 31  ztf  58906.333831  1152333831015025004    1  1152333831015   20.449600
# 32  ztf  58906.445926  1152445921015025010    2  1152445921015   20.170600
# 33  ztf  58908.340926  1154340921015015004    1  1154340921015   20.550001
# 34  ztf  58908.340926  1154340921015025004    1  1154340921015   20.550000
# 35  ztf  58908.449653  1154449651015015010    2  1154449651015   20.565456
# 36  ztf  58908.449653  1154449651015025010    2  1154449651015   20.565500
# 37  ztf  58911.399387  1157399381015015004    1  1157399381015   20.399746
# 38  ztf  58911.446366  1157446361015015005    2  1157446361015   20.132082
# 39  ztf  58912.446690  1158446681015015006    2  1158446681015   20.488462
# 40  ztf  58913.330891  1159330891015015004    1  1159330891015   19.968367
# 41  ztf  58913.445336  1159445331015015002    2  1159445331015   20.105420
# 42  ztf  58914.424745  1160424741015015001    1  1160424741015   19.592520
# 43  ztf  58915.403657  1161403651015015003    2  1161403651015   19.335365
# 44  ztf  58915.444468  1161444461015015003    1  1161444461015   19.404776
# 45  ztf  58936.289768  1182289761015015008    1  1182289761015   20.618000
# 46  ztf  58936.412882  1182412881015015006    2  1182412881015   20.408224
# 47  ztf  58939.337685  1185337681015015003    1  1185337681015   20.050423
# 48  ztf  58940.393982  1186393981015015002    1  1186393981015   20.251009
# 49  ztf  58954.258796  1200258791015015003    2  1200258791015   20.525400
# 50  ztf  58954.298067  1200298061015015004    1  1200298061015   20.643800
# 51  ztf  58955.267755  1201267751015015006    2  1201267751015   20.580900
# 52  ztf  58955.300162  1201300161015015003    1  1201300161015   20.626900
# 53  ztf  58962.232974  1208232971015015005    1  1208232971015   20.663795
# 54  ztf  58963.311748  1209311741015015002    1  1209311741015   20.624800
# 55  ztf  58965.232292  1211232291015015002    1  1211232291015   20.825500
# 56  ztf  58965.286690  1211286681015015007    2  1211286681015   20.632238
# 57  ztf  58967.227049  1213227041015015005    1  1213227041015   20.466776
#
#     isdiffpos   nid    distnr     magpsf  ...         rfid  has_stamp  \
# 0           1  1101  2.120077  17.279879  ...  576120210.0      False
# 1           1  1105  2.123806  14.768740  ...  576120210.0      False
# 2           1  1105  0.549287  14.916227  ...  576120110.0      False
# 3           1  1113  0.499874  14.300256  ...  576120110.0      False
# 4           1  1113  2.172854  13.859622  ...  576120210.0      False
# 5           1  1117  0.551084  15.030325  ...  576120110.0      False
# 6           1  1117  2.161602  14.170009  ...  576120210.0      False
# 7           1  1121  0.521960  15.676039  ...  576120110.0      False
# 8           1  1121  2.198571  14.676664  ...  576120210.0      False
# 9           1  1124  2.211310  15.056566  ...  576120210.0      False
# 10          1  1124  0.539071  16.039352  ...  576120110.0      False
# 11          1  1127  0.546491  16.326006  ...  576120110.0      False
# 12          1  1127  2.177597  15.391163  ...  576120210.0      False
# 13          1  1130  0.509774  16.490767  ...  576120110.0      False
# 14          1  1130  2.256048  15.629835  ...  576120210.0      False
# 15          1  1133  0.543290  16.608180  ...  576120110.0      False
# 16          1  1133  2.114058  15.836470  ...  576120210.0      False
# 17          1  1138  2.146771  16.089048  ...  576120210.0      False
# 18          1  1138  0.573291  16.765865  ...  576120110.0      False
# 19          1  1141  0.532298  16.816044  ...  576120110.0      False
# 20          1  1141  2.185065  16.182260  ...  576120210.0      False
# 21          1  1144  2.116159  16.301437  ...  576120210.0      False
# 22          1  1144  0.556635  16.893100  ...  576120110.0      False
# 23          1  1145  0.535672  16.916061  ...  576120110.0      False
# 24          1  1145  2.119095  16.380474  ...  576120210.0      False
# 25          1  1146  2.115661  16.392672  ...  576120210.0      False
# 26          1  1147  2.152260  16.427551  ...  576120210.0      False
# 27          1  1149  0.554517  16.924618  ...  576120110.0      False
# 28          1  1150  0.492181  16.972418  ...  576120110.0      False
# 29          1  1150  2.177363  16.497473  ...  576120210.0      False
# 30          1  1151  0.530563  16.962164  ...  576120110.0      False
# 31          1  1152  0.586401  16.945000  ...          NaN      False
# 32          1  1152  2.152670  16.598900  ...          NaN      False
# 33          1  1154  0.545271  17.035381  ...  576120110.0      False
# 34          1  1154  0.545271  17.035400  ...          NaN      False
# 35          1  1154  2.159903  16.637669  ...  576120210.0      False
# 36          1  1154  2.159900  16.637700  ...          NaN      False
# 37          1  1157  0.487625  17.165120  ...  576120110.0      False
# 38          1  1157  2.203247  16.720867  ...  576120210.0      False
# 39          1  1158  2.164778  16.808950  ...  576120210.0      False
# 40          1  1159  0.558177  17.102070  ...  576120110.0      False
# 41          1  1159  2.074039  16.823560  ...  576120210.0      False
# 42          1  1160  0.498235  17.244246  ...  576120110.0      False
# 43          1  1161  2.112018  16.894718  ...  576120210.0      False
# 44          1  1161  0.568705  17.179087  ...  576120110.0      False
# 45          1  1182  0.549695  17.690000  ...          NaN      False
# 46          1  1182  2.151718  17.593666  ...  576120210.0      False
# 47          1  1185  0.618330  17.873266  ...  576120110.0      False
# 48          1  1186  0.610870  17.759047  ...  576120110.0      False
# 49          1  1200  2.153900  18.113700  ...          NaN      False
# 50          1  1200  0.572410  18.283800  ...          NaN      False
# 51          1  1201  2.219300  18.133100  ...          NaN      False
# 52          1  1201  0.595002  18.307600  ...          NaN      False
# 53          1  1208  0.776635  18.438562  ...  576120110.0      False
# 54          1  1209  0.871032  18.600100  ...          NaN      False
# 55          1  1211  0.869811  18.456500  ...          NaN      False
# 56          1  1211  2.134563  18.513012  ...  576120210.0      False
# 57          1  1213  0.594295  18.607530  ...  576120110.0       True
#
#     corrected  dubious  step_id_corr  phase        parent_candid  magpsf_corr  \
# 0       False    False    bulk_1.0.0    0.0  1121521071015015006          NaN
# 1       False    False    bulk_1.0.0    0.0  1133425771015015000          NaN
# 2        True    False    bulk_1.0.0    0.0  1133425771015015000    14.601364
# 3        True    False    bulk_1.0.0    0.0  1133425771015015000    14.110689
# 4       False    False    bulk_1.0.0    0.0  1133425771015015000          NaN
# 5        True    False    bulk_1.0.0    0.0  1133425771015015000    14.685591
# 6       False    False    bulk_1.0.0    0.0  1133425771015015000          NaN
# 7        True    False    bulk_1.0.0    0.0  1133425771015015000    15.114477
# 8       False    False    bulk_1.0.0    0.0  1133425771015015000          NaN
# 9       False    False    bulk_1.0.0    0.0  1133425771015015000          NaN
# 10       True    False    bulk_1.0.0    0.0  1133425771015015000    15.316192
# 11       True    False    bulk_1.0.0    0.0  1133425771015015000    15.454006
# 12      False    False    bulk_1.0.0    0.0  1133425771015015000          NaN
# 13       True    False    bulk_1.0.0    0.0  1133425771015015000    15.524734
# 14      False    False    bulk_1.0.0    0.0  1133425771015015000          NaN
# 15       True    False    bulk_1.0.0    0.0  1150458801015015003    15.571436
# 16      False    False    bulk_1.0.0    0.0  1150458801015015003          NaN
# 17      False    False    bulk_1.0.0    0.0  1150458801015015003          NaN
# 18       True    False    bulk_1.0.0    0.0  1150458801015015003    15.629444
# 19       True    False    bulk_1.0.0    0.0  1150458801015015003    15.646799
# 20      False    False    bulk_1.0.0    0.0  1150458801015015003          NaN
# 21      False    False    bulk_1.0.0    0.0  1150458801015015003          NaN
# 22       True    False    bulk_1.0.0    0.0  1150458801015015003    15.672439
# 23       True    False    bulk_1.0.0    0.0  1150458801015015003    15.679845
# 24      False    False    bulk_1.0.0    0.0  1150458801015015003          NaN
# 25      False    False    bulk_1.0.0    0.0  1150458801015015003          NaN
# 26      False    False    bulk_1.0.0    0.0  1150458801015015003          NaN
# 27       True    False    bulk_1.0.0    0.0  1150458801015015003    15.682578
# 28       True    False    bulk_1.0.0    0.0  1154449651015015010    15.697578
# 29      False    False    bulk_1.0.0    0.0  1154449651015015010          NaN
# 30       True    False    bulk_1.0.0    0.0  1154449651015015010    15.694399
# 31       True    False    bulk_1.0.0    0.0  1154449651015015010    15.689030
# 32      False    False    bulk_1.0.0    0.0  1154449651015015010          NaN
# 33       True    False    bulk_1.0.0    0.0  1154449651015015010    15.716652
# 34       True    False    bulk_1.0.0    0.0  1182412881015015006    15.716657
# 35      False    False    bulk_1.0.0    0.0  1161444461015015003          NaN
# 36      False    False    bulk_1.0.0    0.0  1182412881015015006          NaN
# 37       True    False    bulk_1.0.0    0.0  1182412881015015006    15.753571
# 38      False    False    bulk_1.0.0    0.0  1182412881015015006          NaN
# 39      False    False    bulk_1.0.0    0.0  1182412881015015006          NaN
# 40       True    False    bulk_1.0.0    0.0  1182412881015015006    15.736023
# 41      False    False    bulk_1.0.0    0.0  1182412881015015006          NaN
# 42       True    False    bulk_1.0.0    0.0  1182412881015015006    15.774568
# 43      False    False    bulk_1.0.0    0.0  1182412881015015006          NaN
# 44       True    False    bulk_1.0.0    0.0  1182412881015015006    15.757359
# 45       True    False    bulk_1.0.0    0.0  1182412881015015006    15.873362
# 46      False    False    bulk_1.0.0    0.0  1185337681015015003          NaN
# 47       True    False    bulk_1.0.0    0.0  1213227041015015005    15.905476
# 48       True    False    bulk_1.0.0    0.0  1213227041015015005    15.885987
# 49      False    False    bulk_1.0.0    0.0  1213227041015015005          NaN
# 50       True    False    bulk_1.0.0    0.0  1213227041015015005    15.962770
# 51      False    False    bulk_1.0.0    0.0  1213227041015015005          NaN
# 52       True    False    bulk_1.0.0    0.0  1213227041015015005    15.965550
# 53       True    False    bulk_1.0.0    0.0  1213227041015015005    15.979914
# 54       True    False    bulk_1.0.0    0.0  1213227041015015005    15.995619
# 55       True    False    bulk_1.0.0    0.0  1213227041015015005    15.981764
# 56      False    False    bulk_1.0.0    0.0  1213227041015015005          NaN
# 57       True    False    bulk_1.0.0    0.0                    0    15.996292
#
#     sigmapsf_corr  sigmapsf_corr_ext
# 0             NaN                NaN
# 1             NaN                NaN
# 2       100.00000           0.021050
# 3         0.02116           0.025516
# 4             NaN                NaN
# 5       100.00000           0.017573
# 6             NaN                NaN
# 7       100.00000           0.014803
# 8             NaN                NaN
# 9             NaN                NaN
# 10      100.00000           0.012553
# 11      100.00000           0.011427
# 12            NaN                NaN
# 13      100.00000           0.013519
# 14            NaN                NaN
# 15      100.00000           0.016633
# 16            NaN                NaN
# 17            NaN                NaN
# 18      100.00000           0.012458
# 19      100.00000           0.009501
# 20            NaN                NaN
# 21            NaN                NaN
# 22      100.00000           0.011623
# 23      100.00000           0.011887
# 24            NaN                NaN
# 25            NaN                NaN
# 26            NaN                NaN
# 27      100.00000           0.011592
# 28      100.00000           0.015160
# 29            NaN                NaN
# 30      100.00000           0.013494
# 31      100.00000           0.012068
# 32            NaN                NaN
# 33      100.00000           0.014606
# 34      100.00000           0.014606
# 35            NaN                NaN
# 36            NaN                NaN
# 37      100.00000           0.011891
# 38            NaN                NaN
# 39            NaN                NaN
# 40      100.00000           0.012020
# 41            NaN                NaN
# 42      100.00000           0.011943
# 43            NaN                NaN
# 44      100.00000           0.011268
# 45      100.00000           0.009478
# 46            NaN                NaN
# 47      100.00000           0.011262
# 48      100.00000           0.012056
# 49            NaN                NaN
# 50      100.00000           0.007863
# 51            NaN                NaN
# 52      100.00000           0.008146
# 53      100.00000           0.007969
# 54      100.00000           0.008343
# 55      100.00000           0.010322
# 56            NaN                NaN
# 57      100.00000           0.009292
#
# [58 rows x 30 columns]
#     tid           mjd  fid  diffmaglim
# 0   ztf  58828.547824    1     19.2005
# 1   ztf  58831.548472    1     19.4442
# 2   ztf  58833.565347    1     18.8578
# 3   ztf  58834.523704    2     18.8942
# 4   ztf  58837.462141    2     19.5815
# 5   ztf  58837.546817    1     19.6237
# 6   ztf  58838.569375    2     18.4409
# 7   ztf  58846.546181    1     20.4808
# 8   ztf  58846.567025    2     20.4058
# 9   ztf  58849.503183    1     20.5516
# 10  ztf  58852.546400    2     20.5218
# 11  ztf  58914.377870    2     19.9006
# 12  ztf  58939.359919    2     18.3916
# 13  ztf  58941.456620    1     20.0322
# 14  ztf  58955.281192    2     20.2934
# 15  ztf  58962.280312    2     20.5318
# 16  ztf  58964.269456    2     20.6648

# %% [markdown]
# The most important columns for the detections are the time (`mjd`), the unique detection identifier (`candid`), the band (`fid`), the difference magnitude (`magpsf`) and its error (`sigmapsf`).
#
# The columns for the non-detections are the time (`mjd`), the band (`fid`), and the limiting magnitude (`diffmaglim`).
#
# All the field are explained in here The columns are described in here https://alerce.readthedocs.io/en/latest/models.html.

# %% [markdown]
# # Query image stamps
#
# We can also query the image stamps associated to a specific object and candid.

# %% [markdown]
# We will use the first candid from the previously queried detections.

# %%
stamps = client.get_stamps(oid, detections.iloc[0].candid)
print(stamps)
# Out:
# [<astropy.io.fits.hdu.image.PrimaryHDU object at 0x7fb0dcee04c0>, <astropy.io.fits.hdu.image.ImageHDU object at 0x7fb0dcefe250>, <astropy.io.fits.hdu.image.ImageHDU object at 0x7fb0dcefe8e0>]
# WARNING: VerifyWarning: Keyword name 'STAMP_TYPE' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]

# %% [markdown]
# The image stamps are a triplet of science, reference and difference images. Let's look at the first image:

# %%
fig, ax = plt.subplots(ncols=3)
for i in range(3):
    ax[i].imshow(stamps[i].data)

# %% [markdown]
# We can also directly plot the images stamps using the plot_stamps command.

# %%
client.plot_stamps(oid, detections.iloc[0].candid)
# Out:
#         <div>ZTF oid: ZTF20aaelulu, candid: 1101542291015015004</div>
#         <div>&emsp;&emsp;&emsp;&emsp;&emsp;
#         Science
#         &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;
#         Template
#         &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;
#         Difference
#         <div class="container">
#         <div style="float:left;width:20%"><img src="https://avro.alerce.online/get_stamp?oid=ZTF20aaelulu&candid=1101542291015015004&type=science&format=png"></div>
#         <div style="float:left;width:20%"><img src="https://avro.alerce.online/get_stamp?oid=ZTF20aaelulu&candid=1101542291015015004&type=template&format=png"></div>
#         <div style="float:left;width:20%"><img src="https://avro.alerce.online/get_stamp?oid=ZTF20aaelulu&candid=1101542291015015004&type=difference&format=png"></div>
#         </div>

# %% [markdown]
# If `candid` is not given the last available value will be used.

# %%
client.plot_stamps(oid)
print(detections.candid.max())
# Out:
#         <div>ZTF oid: ZTF20aaelulu, candid: 1213227041015015005</div>
#         <div>&emsp;&emsp;&emsp;&emsp;&emsp;
#         Science
#         &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;
#         Template
#         &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;
#         Difference
#         <div class="container">
#         <div style="float:left;width:20%"><img src="https://avro.alerce.online/get_stamp?oid=ZTF20aaelulu&candid=1213227041015015005&type=science&format=png"></div>
#         <div style="float:left;width:20%"><img src="https://avro.alerce.online/get_stamp?oid=ZTF20aaelulu&candid=1213227041015015005&type=template&format=png"></div>
#         <div style="float:left;width:20%"><img src="https://avro.alerce.online/get_stamp?oid=ZTF20aaelulu&candid=1213227041015015005&type=difference&format=png"></div>
#         </div>
# 1213227041015015005

# %% [markdown]
# # Crossmatch with objects in the vicinity

# %% [markdown]
# We can also crossmatch the object's position with objects from the catsHTM collection of catalogs (https://github.com/maayane/catsHTM). The catalogs included in catsHTM are:
#
# * 2MASS (input name: TMASS)
# * 2MASSxsc (input name: TMASSxsc) - 2MASS extended source catalog
# * AKARI (input name: AKARI)
# * APASS (input name: APASS) - AAVSO All Sky Photometric Sky Survey (~5.5x10^7 sources)
# * Cosmos (input name: Cosmos) - Sources in the Cosmos field
# * DECaLS (input name: DECaLS) - DECaLS DR5 release
# * FIRST (input name: FIRST) - (~9.5x10^5 sources)
# * GAIA/DR1 (input name: GAIADR1) - (~1.1x10^9 sources).
# * GAIA/DR2 (input name: GAIADR2) - NEW! (~1.6x10^9 sources)
# * GAIA/EDR3 (input name: GAIAEDR3) - NEW! (~1.8x10^9 sources)
# * GALEX (input name: GALEX) - GALAEX/GR6Plus7 (~1.7x10^8 sources).
# * HSC/v2 (input name: HSCv2)- Hubble source catalog
# * IPHAS/DR2 (input name: IPHAS)
# * NED redshifts (input name: NEDz)
# * NVSS (input name: NVSS) - (~1.8x10^6 sources)
# * HYPERLEDA (input name: PGC)
# * PS1 (input name: PS1) - Pan-STARRS (~2.6x10^9 sources; A cleaned version of the PS1 stack catalog; some missing tiles below declination of zero [being corrected])
# * The PTF photometric catalog (input name: PTFpc)
# * ROSATfsc (input name: ROSATfsc) - ROSAT faint source catalog
# * SDSS/DR10 (input name: SDSSDR10)- Primary sources from SDSS/DR10 (last photometric release)
# * Skymapper DR1 (input name: Skymapper)
# * SpecSDSS/DR14 (input name: SpecSDSS) - SDSS spectroscopic catalog
# * Spitzer/SAGE (input name SAGE)
# * Spitzer/IRAC (input name IRACgc) - Spitzer IRAC galactic center survey
# * UCAC4 (input name: UCAC4) - (~1.1x10^8 sources)
# * UKIDSS/DR10 (input name: UKIDSS)
# * USNOB1 (not yet available)
# * VISTA/Viking/DR3 (not yet available)
# * VST/ATLAS/DR3 (input name: VSTatlas)
# * VST/KiDS/DR3 (input name: VSTkids)
# * WISE (input name: WISE) - ~5.6x10^8 sources
# * XMM (input name: XMM)- 7.3x10^5 sources 3XMM-DR7 (Rosen et al. 2016; A&A 26, 590)
# * ZTF-DR1 stellar variability catalog (input name: ztfSrcLCDR1)
# * ZTF-DR1 variable star candidates (input name: ztfSrcLCDR1)

# %%
ra = properties.meanra
dec = properties.meandec
radius = 30 # arcsec
cone_objects = {}
for catalog_name in ["GAIA/DR1", "SpecSDSS", "NEDz", "GALEX", "SDSSDR10"]:
    cone_objects[catalog_name] = client.catshtm_conesearch(ra, dec, radius, catalog_name, format="pandas")
cone_objects
# Out:
# {'GAIA/DR1':           Dec     ErrDec   ErrMagG      ErrRA  ExcessNoise  ExcessNoiseSig  \
#  0   15.819296   8.866578  0.042748  17.157946    18.812951      542.235000
#  1   15.819440   2.148437  0.013572   3.214391     8.882165      371.195851
#  2   15.819902   5.084703  0.018570   7.506664    17.606524     1161.494779
#  3   15.819962   1.008291  0.010087   1.486499     4.831095      165.399819
#  4   15.820374   2.110112  0.016731   2.903802     7.955912      197.761159
#  5   15.820486   7.489231  0.024263  11.967957    18.975523     1243.177136
#  6   15.820638   1.169002  0.011240   1.629961     4.949941      232.562016
#  7   15.820966   7.341491  0.019189  10.520847    12.831808      360.504247
#  8   15.821334   4.266789  0.017510   7.387818    13.092168      920.381217
#  9   15.821678   3.243127  0.024405   6.671627    16.174836     1182.263363
#  10  15.822306   1.786580  0.015176   2.616887     7.645438     2997.715286
#  11  15.822344   4.286698  0.016630   6.151887    13.609887     1092.668271
#  12  15.822629   9.828831  0.021065  15.547542    18.537766      464.269987
#  13  15.822640   1.986086  0.014420   2.525685     7.391311      503.342092
#  14  15.822721  20.423632  0.096174  24.150871     6.920048       78.876603
#  15  15.822844   1.565662  0.012125   2.127865     6.410292      379.991634
#  16  15.823596   1.495638  0.010734   2.099878     6.495285      239.602542
#  17  15.823604   1.822837  0.013455   2.504583     7.507110      462.849594
#  18  15.823658   6.171841  0.024629  12.012730    15.661957     1178.621098
#  19  15.825801  18.742504  0.088952  44.481506    14.868282      183.817488
#  20  15.826961   5.756498  0.019574   8.776315    17.775848      120.425690
#  21  15.827194   7.677591  0.018403  18.517145    12.775069       63.975199
#
#           MagG          RA          cat_name
#  0   18.583562  185.729297  catsHTM_GAIA/DR1
#  1   18.241900  185.729143  catsHTM_GAIA/DR1
#  2   18.224941  185.728794  catsHTM_GAIA/DR1
#  3   17.899880  185.728144  catsHTM_GAIA/DR1
#  4   18.494435  185.730390  catsHTM_GAIA/DR1
#  5   17.989187  185.728986  catsHTM_GAIA/DR1
#  6   17.990298  185.727915  catsHTM_GAIA/DR1
#  7   18.465914  185.729160  catsHTM_GAIA/DR1
#  8   17.854050  185.727424  catsHTM_GAIA/DR1
#  9   18.111355  185.731027  catsHTM_GAIA/DR1
#  10  15.970880  185.728880  catsHTM_GAIA/DR1
#  11  17.803269  185.727294  catsHTM_GAIA/DR1
#  12  18.379292  185.731110  catsHTM_GAIA/DR1
#  13  17.800128  185.729856  catsHTM_GAIA/DR1
#  14  17.615077  185.729875  catsHTM_GAIA/DR1
#  15  17.739736  185.726576  catsHTM_GAIA/DR1
#  16  18.118375  185.729988  catsHTM_GAIA/DR1
#  17  17.880780  185.728834  catsHTM_GAIA/DR1
#  18  17.695146  185.726977  catsHTM_GAIA/DR1
#  19  19.931523  185.729809  catsHTM_GAIA/DR1
#  20  19.944567  185.732160  catsHTM_GAIA/DR1
#  21  19.774733  185.726111  catsHTM_GAIA/DR1  ,
#  'SpecSDSS': Class                         1.0
#  DOF                        3794.0
#  Dec                     15.821231
#  RA                       185.7274
#  elodieBV                      0.0
#  elodieFeH                     0.0
#  elodieLogG                    0.0
#  elodieTEff                    0.0
#  fiberID                     373.0
#  fracNSigma_10            0.003157
#  fracNSigma_5             0.009208
#  fracNSigma_8             0.003683
#  mjd                       53436.0
#  modelMagErr_g                None
#  modelMagErr_i                None
#  modelMagErr_r                None
#  modelMagErr_u                None
#  modelMagErr_z                None
#  modelMag_g                   None
#  modelMag_i                   None
#  modelMag_r                   None
#  modelMag_u                   None
#  modelMag_z                   None
#  plate                      1767.0
#  rChi2                    2.712347
#  snMedian_r               45.94141
#  subClass                    164.0
#  velDisp                   76.1338
#  velDispErr                 5.8987
#  z                        0.005289
#  zErr                     0.000012
#  zWarning                      0.0
#  cat_name         catsHTM_SpecSDSS
#  Name: catsHTM_SpecSDSS, dtype: object,
#  'NEDz':         Dec Filter   Mag  ObjType         RA  RedshiftType  Velocity        z  \
#  0  15.82122   16.0  14.1     21.0  185.72742           1.0    1556.0  0.00519
#  1  15.82182    3.0  9.84     11.0  185.72846           1.0    1571.0  0.00524
#  2  15.82287   None  None     13.0  185.73314           1.0    1289.0  0.00430
#
#         cat_name
#  0  catsHTM_NEDz
#  1  catsHTM_NEDz
#  2  catsHTM_NEDz  ,
#  'GALEX': None,
#  'SDSSDR10': None}

# %% [markdown]
# We obtained many crossmatches from the [catsHTM](https://arxiv.org/abs/1805.02666_) catalog. Let's look at the catalogs where matches were found:

# %% [markdown]
# Let's plot the location of all crossmatches  at the SDSS/DR10 xmatches, highlighting objects with redshift if there are any from the table SpecSDSS.

# %%
fig, ax = plt.subplots(figsize=(10, 10))
cmap = plt.cm.tab20
norm = matplotlib.colors.Normalize(vmin=0, vmax=len(cone_objects.keys()))
for idx, i in enumerate(cone_objects.keys()):
    try:
        aux = cone_objects[i].rename({"RA": "ra", "Dec": "dec"}, axis=1)
        ax.scatter(aux.ra, aux.dec, color=cmap(norm(idx)), label=i, s=50)
        if i == "SpecSDSS": # the table with spectroscopic redshifts
            s = 500
            for idxrow, row in aux.iterrows():
                ax.text(row.ra, row.dec, "z=%.5f" % row.z, fontsize=20)
    except:
        print(i)
        
ax.scatter(ra, dec, c='k', marker='o', s=100, label=oid)
ax.set_xlim(ax.get_xlim()[::-1])
plt.legend()
# Out:
# SpecSDSS
# GALEX
# SDSSDR10

# %% [markdown]
# # Query features for an individual object

# %% [markdown]
# Now we will query the features used by our light curve classifier. These are hand made statistics or contextual information based on the object's light curve.

# %%
query_results = client.query_features(
        oid=oid,
        format='pandas')
query_results
# Out:
#              name       value  fid                version
# 0           gal_b   76.900066    0  lc_classifier_1.2.1-P
# 1           gal_l  271.133944    0  lc_classifier_1.2.1-P
# 2         g-r_max    0.440634   12  lc_classifier_1.2.1-P
# 3        g-r_mean    0.734401   12  lc_classifier_1.2.1-P
# 4    g-r_max_corr         NaN   12  lc_classifier_1.2.1-P
# ..            ...         ...  ...                    ...
# 173         W2-W3         NaN    0  lc_classifier_1.2.1-P
# 174          g-W2         NaN    0  lc_classifier_1.2.1-P
# 175          g-W3         NaN    0  lc_classifier_1.2.1-P
# 176          r-W2         NaN    0  lc_classifier_1.2.1-P
# 177          r-W3         NaN    0  lc_classifier_1.2.1-P
#
# [178 rows x 4 columns]

# %% [markdown]
# You can see that there are 178 rows, where each row has a feature name (`name`), a value (`value`), a band id (`fid`), and a feature version (`version`).
#
# A detailed explanation of all the features can be found in http://alerce.science/features/.

# %% [markdown]
# We can pivot these dataframe to make the features appear as columns. To do this we will add an auxiliary columns that contains the feature name and filter id all in one string, as well as adding the object identifier as a column.

# %%
query_results["oid"] = oid
query_results['feature'] = [f"{name}_{fid}" for name, fid in zip(query_results.name, query_results.fid)]

# %%
query_results.pivot(index='oid', columns='feature', values='value')
# Out:
# feature       Amplitude_1  Amplitude_2  AndersonDarling_1  AndersonDarling_2  \
# oid
# ZTF20aaelulu     1.997787      2.15412           0.982534           0.759591
#
# feature       Autocor_length_1  Autocor_length_2  Beyond1Std_1  Beyond1Std_2  \
# oid
# ZTF20aaelulu               5.0               3.0       0.37931          0.24
#
# feature       Con_1  Con_2  ...  n_non_det_before_fid_1  \
# oid                         ...
# ZTF20aaelulu    0.0    0.0  ...                     6.0
#
# feature       n_non_det_before_fid_2  n_pos_1  n_pos_2  positive_fraction_1  \
# oid
# ZTF20aaelulu                     5.0     29.0     25.0                  1.0
#
# feature       positive_fraction_2  r-W2_0  r-W3_0      rb_0  sgscore1_0
# oid
# ZTF20aaelulu                  1.0     NaN     NaN  0.845714    0.227482
#
# [1 rows x 178 columns]

# %% [markdown]
# # Query probabilities for an individual object

# %% [markdown]
# Similarly, we can query the classification probabilities for a given object.
#
# Note that an object can be classified by different classifiers with different versions, which is shown in the columns `classifier_name` and `classifier_version`, respectively.

# %%
query_results = client.query_probabilities(
        oid=oid,
        format='pandas')
query_results
# Out:
#              classifier_name      classifier_version      class_name  \
# 0              lc_classifier   hierarchical_rf_1.1.0            SNIa
# 1     lc_classifier_periodic   hierarchical_rf_1.1.0             LPV
# 2   lc_classifier_stochastic   hierarchical_rf_1.1.0             QSO
# 3          lc_classifier_top   hierarchical_rf_1.1.0       Transient
# 4    lc_classifier_transient   hierarchical_rf_1.1.0            SNIa
# 5           stamp_classifier  stamp_classifier_1.0.0              SN
# 6              lc_classifier   hierarchical_rf_1.1.0           SNIbc
# 7     lc_classifier_periodic   hierarchical_rf_1.1.0               E
# 8   lc_classifier_stochastic   hierarchical_rf_1.1.0             AGN
# 9          lc_classifier_top   hierarchical_rf_1.1.0      Stochastic
# 10   lc_classifier_transient   hierarchical_rf_1.1.0           SNIbc
# 11          stamp_classifier  stamp_classifier_1.0.0             AGN
# 12             lc_classifier   hierarchical_rf_1.1.0            SNII
# 13    lc_classifier_periodic   hierarchical_rf_1.1.0            DSCT
# 14  lc_classifier_stochastic   hierarchical_rf_1.1.0          Blazar
# 15         lc_classifier_top   hierarchical_rf_1.1.0        Periodic
# 16   lc_classifier_transient   hierarchical_rf_1.1.0            SNII
# 17          stamp_classifier  stamp_classifier_1.0.0              VS
# 18             lc_classifier   hierarchical_rf_1.1.0            SLSN
# 19    lc_classifier_periodic   hierarchical_rf_1.1.0             RRL
# 20  lc_classifier_stochastic   hierarchical_rf_1.1.0         CV/Nova
# 21   lc_classifier_transient   hierarchical_rf_1.1.0            SLSN
# 22          stamp_classifier  stamp_classifier_1.0.0        asteroid
# 23             lc_classifier   hierarchical_rf_1.1.0             QSO
# 24    lc_classifier_periodic   hierarchical_rf_1.1.0             CEP
# 25  lc_classifier_stochastic   hierarchical_rf_1.1.0             YSO
# 26          stamp_classifier  stamp_classifier_1.0.0           bogus
# 27             lc_classifier   hierarchical_rf_1.1.0             AGN
# 28    lc_classifier_periodic   hierarchical_rf_1.1.0  Periodic-Other
# 29             lc_classifier   hierarchical_rf_1.1.0          Blazar
# 30             lc_classifier   hierarchical_rf_1.1.0         CV/Nova
# 31             lc_classifier   hierarchical_rf_1.1.0             YSO
# 32             lc_classifier   hierarchical_rf_1.1.0             LPV
# 33             lc_classifier   hierarchical_rf_1.1.0               E
# 34             lc_classifier   hierarchical_rf_1.1.0            DSCT
# 35             lc_classifier   hierarchical_rf_1.1.0             RRL
# 36             lc_classifier   hierarchical_rf_1.1.0             CEP
# 37             lc_classifier   hierarchical_rf_1.1.0  Periodic-Other
#
#     probability  ranking
# 0      0.137760        3
# 1      0.332000        1
# 2      0.008000        4
# 3      0.984000        1
# 4      0.140000        3
# 5      0.813201        1
# 6      0.525456        1
# 7      0.090000        5
# 8      0.006000        5
# 9      0.006000        3
# 10     0.534000        1
# 11     0.047046        3
# 12     0.271584        2
# 13     0.060000        6
# 14     0.024000        2
# 15     0.010000        2
# 16     0.276000        2
# 17     0.044129        4
# 18     0.049200        4
# 19     0.226000        2
# 20     0.940000        1
# 21     0.050000        4
# 22     0.040433        5
# 23     0.000048       14
# 24     0.164000        3
# 25     0.022000        3
# 26     0.055191        2
# 27     0.000036       15
# 28     0.128000        4
# 29     0.000144       12
# 30     0.005640        5
# 31     0.000132       13
# 32     0.003320        6
# 33     0.000900       10
# 34     0.000600       11
# 35     0.002260        7
# 36     0.001640        8
# 37     0.001280        9

# %% [markdown]
# We see that we get many rows for a single object. This shows all the probabilities associated to all the ALeRCE classifiers and the classes in their associated taxonomies. The columns indicate the name of the classifier (`classifier_name`), its version (`classifier_version`), the class (`class_name`), the probability (`probability`) and the ranking (`ranking`) growing from most to least likely.

# %% [markdown]
# Let's check the unique classifier versions associated to each classifier:

# %%
for clf in query_results.classifier_name.unique():
    mask = query_results.classifier_name == clf
    print(clf, query_results.loc[mask].classifier_version.unique())
# Out:
# lc_classifier ['hierarchical_rf_1.1.0']
# lc_classifier_periodic ['hierarchical_rf_1.1.0']
# lc_classifier_stochastic ['hierarchical_rf_1.1.0']
# lc_classifier_top ['hierarchical_rf_1.1.0']
# lc_classifier_transient ['hierarchical_rf_1.1.0']
# stamp_classifier ['stamp_classifier_1.0.0']

# %% [markdown]
# And now the unique classes associated to each classifier:

# %%
for clf in query_results.classifier_name.unique():
    mask = query_results.classifier_name == clf
    print(clf, query_results.loc[mask].class_name.unique())
# Out:
# lc_classifier ['SNIa' 'SNIbc' 'SNII' 'SLSN' 'QSO' 'AGN' 'Blazar' 'CV/Nova' 'YSO' 'LPV'
#  'E' 'DSCT' 'RRL' 'CEP' 'Periodic-Other']
# lc_classifier_periodic ['LPV' 'E' 'DSCT' 'RRL' 'CEP' 'Periodic-Other']
# lc_classifier_stochastic ['QSO' 'AGN' 'Blazar' 'CV/Nova' 'YSO']
# lc_classifier_top ['Transient' 'Stochastic' 'Periodic']
# lc_classifier_transient ['SNIa' 'SNIbc' 'SNII' 'SLSN']
# stamp_classifier ['SN' 'AGN' 'VS' 'asteroid' 'bogus']

# %% [markdown]
# The classifiers are two classifiers, the `lc_classifier` and the `stamp_classifier`, where `lc_classifier` is a hierarchical classifier composed of four independent classifiers: `lc_classifier_top`, `lc_classifier_periodic`, `lc_classifier_stochastic`, and `lc_classifier_transient`. You can see more details about these classifiers in [Sánchez-Sáez+2021](https://ui.adsabs.harvard.edu/abs/2021AJ....161..141S/abstract) and [Carrasco-Davis+2021](https://ui.adsabs.harvard.edu/abs/2020arXiv200803309C/abstract).
#
# `lc_classifier`:
# * AGN
# * Blazar
# * CEP
# * CV/Nova
# * DSCT
# * E
# * LPV
# * Periodic-Other
# * QSO
# * RRL
# * SLSN
# * SNIa
# * SNIbc
# * SNII
# * YSO
#
# `stamp_classifier`:
# * AGN
# * asteroid
# * bogus
# * SN
# * VS
#
#
# `lc_classifier_top`:
# * Periodic
# * Stochastic
# * Transient
#
# `lc_classifier_periodic`:
# * CEP
# * DSCT
# * E
# * LPV
# * Periodic-Other
# * RRL
#
# `lc_classifier_stochastic`:
# * AGN
# * Blazar
# * CV/Nova
# * QSO
# * YSO
#
# `lc_classifier_transient`:
# * SLSN
# * SNIa
# * SNIbc
# * SNII

# %% [markdown]
# # Query global properties of a set of objects

# %% [markdown]
# ## Query objects based on the most likely class

# %% [markdown]
# We will query the top 200 objects classified SNIa according to the light curve classifier. In here we ask for the top 200 objects in pandas format. By default this query asks for objects with classification `ranking=1`. We will ask for the results to be ordered by probability in descending order (`DESC`).

# %%
query_results = client.query_objects(
        classifier="lc_classifier",
        class_name="SNIa",
        page_size=200,
        order_by='probability',
        order_mode='DESC',
        format='pandas')

# %%
query_results
# Out:
#               oid ndethist  ncovhist  mjdstarthist    mjdendhist  corrected  \
# 0    ZTF20acobvxk      102       502  59149.448125  59204.198831      False
# 1    ZTF22aalpfln       59      2921  59724.250000  59766.250000      False
# 2    ZTF21abuyhau       53      2702  59448.184097  59478.194873      False
# 3    ZTF21abywdxt       44      1171  59464.267917  59502.204410      False
# 4    ZTF21abufayv      129      1744  59443.328588  59491.236620      False
# ..            ...      ...       ...           ...           ...        ...
# 195  ZTF19aavnwyt       43       918  58632.183414  58679.198808       True
# 196  ZTF22abekkwn      159      2493  59821.250000  59879.250000      False
# 197  ZTF22abfxmvf      104      2435  59839.250000  59883.250000       True
# 198  ZTF22aapscub       49      1475  59757.250000  59845.250000      False
# 199  ZTF20accxzmn       53       490  59114.511100  59171.460428      False
#
#      stellar  ndet   g_r_max  g_r_max_corr  ...       lastmjd    deltajd  \
# 0      False    37 -0.185314      0.588599  ...  59204.198831  54.750706
# 1      False    28 -0.179750           NaN  ...  59766.241782  41.892627
# 2      False    28 -0.180090      0.486082  ...  59478.194873  28.030926
# 3      False    27 -0.098903           NaN  ...  59502.204410  37.007465
# 4      False    30 -0.000980           NaN  ...  59491.235683  44.840289
# ..       ...   ...       ...           ...  ...           ...        ...
# 195     True    29 -0.063013     -0.025981  ...  58679.198808  46.022407
# 196    False    34 -0.075892           NaN  ...  59879.265486  57.971343
# 197    False    67 -0.137380     -0.074808  ...  59883.297627  44.026343
# 198    False    49 -0.085884           NaN  ...  59845.159607  87.831968
# 199    False    51  0.079184           NaN  ...  59171.460428  56.949329
#
#          meanra    meandec   sigmara  sigmadec  class     classifier  \
# 0     37.673533 -14.569121  0.000080  0.000059   SNIa  lc_classifier
# 1    224.503742  49.953109  0.000049  0.000022   SNIa  lc_classifier
# 2    244.075462  37.636849  0.000064  0.000032   SNIa  lc_classifier
# 3    326.503610  21.962614  0.000025  0.000023   SNIa  lc_classifier
# 4     12.033976  24.440807  0.000031  0.000026   SNIa  lc_classifier
# ..          ...        ...       ...       ...    ...            ...
# 195  163.775977  57.648915  0.000055  0.000023   SNIa  lc_classifier
# 196  345.782189  23.646366  0.000035  0.000027   SNIa  lc_classifier
# 197  358.404814  11.382791  0.000047  0.000029   SNIa  lc_classifier
# 198  288.368340  53.288031  0.000035  0.000019   SNIa  lc_classifier
# 199   90.533878  46.508562  0.000025  0.000020   SNIa  lc_classifier
#
#      probability      step_id_corr
# 0       0.722000   corr_bulk_0.0.1
# 1       0.722000               dev
# 2       0.720000  correction_1.0.6
# 3       0.716564  correction_1.0.6
# 4       0.712000  correction_1.0.6
# ..           ...               ...
# 195     0.630000   corr_bulk_0.0.1
# 196     0.630000             1.1.6
# 197     0.630000             1.1.6
# 198     0.630000               dev
# 199     0.628928   corr_bulk_0.0.1
#
# [200 rows x 23 columns]

# %% [markdown]
# Note that now the columns `class`, `classifier`, and `probability` are included.

# %% [markdown]
# ## Query objects by classified ranking

# %% [markdown]
# When an object is classified by our classifiers, a `ranking` column is available to quickly extract the most likely class (`ranking=1`). We can also extract objects that were classified as SNIa as the 2nd or 3rd most likely classes. Note that not asking for a ranking is equivalent to asking for `ranking=1` (the most likely class).

# %%
fig, ax = plt.subplots()

for ranking in [1, 2, 3]:
    query_results = client.query_objects(
        classifier="lc_classifier",
        class_name="SNIa",
        ranking=ranking,
        page_size=200,
        order_by='probability',
        order_mode='DESC',        format='pandas')
    query_results.probability.plot.hist(bins=20, ax=ax, lw=2, log=True,
                                        alpha=0.5, histtype='step', label="ranking=%i" % ranking)
query_results = client.query_objects(
        classifier="lc_classifier",
        class_name="SNIa",
        page_size=200,
        order_by='probability',
        order_mode='DESC',
        format='pandas')
query_results.probability.plot.hist(bins=20, ax=ax, lw=2, log=True, histtype='step', label="no ranking")

ax.set_xlabel("probability")
plt.legend()

# %% [markdown]
# You can see that the probabilities when no ranking is specified and `ranking=1` overlap because `ranking=1` is the default value. Also, the typical probabilities of `ranking=1` > `ranking=2` > `ranking=3`.

# %% [markdown]
# # Let's now generate a link to look at all the previous objects

# %% [markdown]
# Here we restrict the number of objects to 200, which is the maximum number that the ALeRCE explorer can accept.

# %%
suffix = "&count=true&page=1&perPage=1000&sortDesc=true&selectedClassifier=lc_classifier"
url = "https://alerce.online/?" + "&".join("oid=%s" % i for i in query_results.oid.iloc[:200]) + suffix
print(url)
# Out:
# https://alerce.online/?oid=ZTF20acobvxk&oid=ZTF22aalpfln&oid=ZTF21abuyhau&oid=ZTF21abywdxt&oid=ZTF21abufayv&oid=ZTF22abqdmwt&oid=ZTF21achqzub&oid=ZTF22abnemvx&oid=ZTF20acoqlav&oid=ZTF19aavounq&oid=ZTF22abhuvug&oid=ZTF19aclljyq&oid=ZTF19abahvdh&oid=ZTF21abrmefg&oid=ZTF21abaaipx&oid=ZTF20acgznau&oid=ZTF20aaljgcp&oid=ZTF20aakbtyz&oid=ZTF21abhtaiv&oid=ZTF22abhodtl&oid=ZTF21abbzcxe&oid=ZTF22abitewv&oid=ZTF20acynaba&oid=ZTF20abisvtr&oid=ZTF22aboisvs&oid=ZTF21abflmkk&oid=ZTF21abbytmm&oid=ZTF20aazsyvu&oid=ZTF21abjeyoh&oid=ZTF21aapfowm&oid=ZTF21abrhggj&oid=ZTF21abcouxj&oid=ZTF20aahptds&oid=ZTF22abgteub&oid=ZTF18aazjztm&oid=ZTF22abizgac&oid=ZTF21abjtqyq&oid=ZTF20accsfkt&oid=ZTF19achejoc&oid=ZTF21abwfnru&oid=ZTF21abwurky&oid=ZTF22aawodgn&oid=ZTF20acpxvez&oid=ZTF22abdstgi&oid=ZTF18aatjfoe&oid=ZTF19abakjao&oid=ZTF21aahargb&oid=ZTF21aaqafcf&oid=ZTF20acoaqpm&oid=ZTF20acnzcmp&oid=ZTF22aambnsg&oid=ZTF21abasxdp&oid=ZTF20actpatx&oid=ZTF20abatfzl&oid=ZTF22abhxptt&oid=ZTF22abfvshc&oid=ZTF20aamgdkb&oid=ZTF20aaeopvv&oid=ZTF18abfchzq&oid=ZTF22absiyyk&oid=ZTF20acwxbyr&oid=ZTF20abkacis&oid=ZTF20abcsbux&oid=ZTF22aamfvrs&oid=ZTF21aaqzkhx&oid=ZTF20acbovrt&oid=ZTF20abeeytg&oid=ZTF19aazlsfj&oid=ZTF22abkaaje&oid=ZTF21abubxmc&oid=ZTF20acuoclk&oid=ZTF21abegynu&oid=ZTF21aarcldd&oid=ZTF21aahvuvi&oid=ZTF20acpumut&oid=ZTF20abndzyc&oid=ZTF19abowcic&oid=ZTF19aaripqw&oid=ZTF22aaoelte&oid=ZTF22aakndny&oid=ZTF22abivrnq&oid=ZTF21aaoqcnh&oid=ZTF21aaxgzln&oid=ZTF20acwmpsj&oid=ZTF20actvpyc&oid=ZTF20abupbub&oid=ZTF20aaxxepr&oid=ZTF19abhzewi&oid=ZTF19aanfyey&oid=ZTF22aaonqcc&oid=ZTF21aaqvmix&oid=ZTF21aagolqa&oid=ZTF20acovrzx&oid=ZTF20aaglivt&oid=ZTF19aazzpje&oid=ZTF18aawmeiw&oid=ZTF22abjeeqt&oid=ZTF22abeigxz&oid=ZTF21abfnjya&oid=ZTF21abbjybk&oid=ZTF21aavqwhh&oid=ZTF20abzjads&oid=ZTF19abjarhj&oid=ZTF19aavorpa&oid=ZTF22abiyeae&oid=ZTF21abvhxyk&oid=ZTF21aaxkckg&oid=ZTF20acnigox&oid=ZTF20acjhhqx&oid=ZTF20aamdqiz&oid=ZTF19acbswdq&oid=ZTF22abjpcjy&oid=ZTF22abiysva&oid=ZTF22aajrjrc&oid=ZTF18aarikzk&oid=ZTF22abmxzxm&oid=ZTF22aazjgoi&oid=ZTF20abjcuep&oid=ZTF22aawtunt&oid=ZTF21aaujuqq&oid=ZTF21aasaxdk&oid=ZTF21aagxmcs&oid=ZTF20acpkzxq&oid=ZTF22abeskuc&oid=ZTF21abvfacx&oid=ZTF21abcgxwy&oid=ZTF21aarwlht&oid=ZTF19abxdnhr&oid=ZTF19aaozplq&oid=ZTF22aayrxbb&oid=ZTF21abkavmp&oid=ZTF22abodqjf&oid=ZTF21accibae&oid=ZTF20acxncha&oid=ZTF19abitbcj&oid=ZTF21abkaoxe&oid=ZTF21abhhari&oid=ZTF22abcuctb&oid=ZTF22abeodtz&oid=ZTF22ablcfaj&oid=ZTF22aamiomf&oid=ZTF21aasctwo&oid=ZTF20acrdemq&oid=ZTF20abxzrqw&oid=ZTF19aavnwxf&oid=ZTF21achhwdz&oid=ZTF22aaknvcz&oid=ZTF21abvyxfs&oid=ZTF20acezpem&oid=ZTF21acbpbia&oid=ZTF21abbcsfu&oid=ZTF21aaskwgm&oid=ZTF20acwxhka&oid=ZTF20acgzjje&oid=ZTF20abqcvtk&oid=ZTF20aaxablt&oid=ZTF19abuayqg&oid=ZTF22abbsbys&oid=ZTF18abdfwur&oid=ZTF21abahgst&oid=ZTF19acdtpow&oid=ZTF19acbqzvu&oid=ZTF21aaufvpg&oid=ZTF21aaufthj&oid=ZTF21aarmkuj&oid=ZTF20abgfvav&oid=ZTF20abewogd&oid=ZTF20aairvsi&oid=ZTF20aaeuxqk&oid=ZTF18abmmdif&oid=ZTF22abhfwmr&oid=ZTF21abrghol&oid=ZTF19abqmjdq&oid=ZTF21aateglh&oid=ZTF21abdthxn&oid=ZTF21aaoexgy&oid=ZTF20aajvwfh&oid=ZTF19aavqoop&oid=ZTF22ablhldn&oid=ZTF22aajvhrj&oid=ZTF21acbpdlz&oid=ZTF22abjgawo&oid=ZTF22aalunvy&oid=ZTF20acxnafa&oid=ZTF20acdmcgv&oid=ZTF22abhyzjq&oid=ZTF20acqelhh&oid=ZTF20acchxpm&oid=ZTF19acttpsv&oid=ZTF21abjciip&oid=ZTF21abcwsho&oid=ZTF20acxqnhn&oid=ZTF20aaactgu&oid=ZTF19acbpxwt&oid=ZTF19abimzvh&oid=ZTF19aavnwyt&oid=ZTF22abekkwn&oid=ZTF22abfxmvf&oid=ZTF22aapscub&oid=ZTF20accxzmn&count=true&page=1&perPage=1000&sortDesc=true&selectedClassifier=lc_classifier

# %% [markdown]
# Open the link in your browser to see the explore the objects.
