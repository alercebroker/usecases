# %% [markdown]
# # Solar system use case notebook
#
# ```Authors: José Peña & Francisco Förster, modifications: Kay Medina, Alejandra Muñoz Arancibia. Last updated: 20260625```
#
# ALeRCE starter notebook for asteroid science using the ALeRCE python client and the ALeRCE Table Access Protocol (TAP) service.
#
# In this notebook you will connect to the ALeRCE database, download asteroid candidates, and plot their trajectories.
#
# You will plot their spatial distribution using datashader aggregation.
#
# *It is highly recommended that you try this notebook in Google Colab using the following [link](https://colab.research.google.com/github/alercebroker/usecases/blob/master/notebooks/ZTF/ALeRCE_Asteroid_Starter.ipynb).*
# This will avoid you from having to sort out library installation problems and focus on the contents of the tutorial. You can try installing the dependencies later in your own system.

# %% [markdown]
# Will install first the ALeRCE client.

# %%
#!pip install alerce

# %% [markdown]
# ### Load libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import astropy.units as u
from astropy import coordinates
from astropy.table import Table
from astropy.time import Time
from datetime import datetime

# %%
from IPython.display import HTML
from ipywidgets import Layout, Box, widgets
from mpl_toolkits.axes_grid1 import make_axes_locatable
from matplotlib.cm import viridis

# %%
#!pip install pyvo
import pyvo

# %%
from alerce.core import Alerce
client = Alerce()

# %% [markdown]
# ### TAP connection setup
#
# Instead of using a direct PostgreSQL connection, we connect to the ALeRCE ZTF legacy database using Astronomical Data Query Language ([ADQL](https://www.ivoa.net/documents/ADQL/)) queries to the ALeRCE TAP service, returning results as pandas dataframes. Database table names are prefixed with `ztf.` (e.g. `ztf.object`, `ztf.detection`, etc.).

# %%
TAP_URL = "https://tap.alerce.online/tap"
tap_service = pyvo.dal.TAPService(TAP_URL)

def tap_query(query, maxrec=10_000_000):
    result = tap_service.search(query, maxrec=maxrec)
    return result.to_table().to_pandas()

def tap_query_idlist(query, index, maxrec=10_000_000):
    # Upload oid (or other identifier fields) list as a TAP table.
    # IMPORTANT: call the upload column something other than "oid", as "oid" collides
    # with PostgreSQL's system column and breaks the join ("objectid" works)
    col = 'objectid'
    oid_table = Table({col: index})
    result = tap_service.search(query, uploads={'mylist': oid_table},
                                maxrec=maxrec).to_table().to_pandas()
    if col in result.columns:
        result.drop(columns=[col], inplace=True)
    return result

# %% [markdown]
# The DB contains the following tables, among others:
#
# * `object`: filter and bandpass aggregated properties per object
# * `probability`: classification probabilities
# * `magstat`: time aggregated bandpass dependent properties per object
# * `ps1_ztf`: closest PanSTARRS object as reported by ZTF
# * `ss_ztf`: closest MPC object as reported by ZTF
# * `gaia_ztf`: closet GAIA source as reported by ZTF
# * `detection`: individual detections, time and bandpass disaggregated
# * `feature`: advanced object features, used for machine learning classification
# * `non_detection`: limiting magnitudes in previous observations, the largest table of all

# %% [markdown]
# ### Show all the available tables

# %%
query = """
SELECT table_name
FROM tap_schema.tables
WHERE schema_name = 'ztf'
ORDER BY table_name
"""
tables = tap_query(query)
tables
# Out:
#                table_name
# 0             ztf.allwise
# 1         ztf.dataquality
# 2           ztf.detection
# 3             ztf.feature
# 4     ztf.feature_version
# 5   ztf.forced_photometry
# 6            ztf.gaia_ztf
# 7             ztf.magstat
# 8       ztf.non_detection
# 9              ztf.object
# 10        ztf.probability
# 11            ztf.ps1_ztf
# 12          ztf.reference
# 13             ztf.ss_ztf
# 14           ztf.taxonomy
# 15             ztf.xmatch

# %% [markdown]
# ### For each table, show column names and column types

# %%
alltabs = []
for tab in sorted(tables.table_name):
    query = '''
    SELECT column_name, datatype
    FROM tap_schema.columns
    WHERE table_name = '%s'
    ORDER BY column_name
    ''' % tab
    results = tap_query(query)
    results["table"] = tab
    alltabs.append(results)
dftab = pd.concat(alltabs)
pd.options.display.max_rows = 999
display(dftab[["table", "column_name", "datatype"]])
pd.options.display.max_rows = 101
# Out:
#                     table         column_name datatype
# 0             ztf.allwise                 dec   double
# 1             ztf.allwise           h_m_2mass   double
# 2             ztf.allwise        h_msig_2mass   double
# 3             ztf.allwise           j_m_2mass   double
# 4             ztf.allwise        j_msig_2mass   double
# 5             ztf.allwise           k_m_2mass   double
# 6             ztf.allwise        k_msig_2mass   double
# 7             ztf.allwise         oid_catalog     char
# 8             ztf.allwise                  ra   double
# 9             ztf.allwise              w1mpro   double
# 10            ztf.allwise           w1sigmpro   double
# 11            ztf.allwise              w2mpro   double
# 12            ztf.allwise           w2sigmpro   double
# 13            ztf.allwise              w3mpro   double
# 14            ztf.allwise           w3sigmpro   double
# 15            ztf.allwise              w4mpro   double
# 16            ztf.allwise           w4sigmpro   double
# 0         ztf.dataquality              aimage    float
# 1         ztf.dataquality           aimagerat    float
# 2         ztf.dataquality              bimage    float
# 3         ztf.dataquality           bimagerat    float
# 4         ztf.dataquality              candid     long
# 5         ztf.dataquality              chipsf    float
# 6         ztf.dataquality            classtar    float
# 7         ztf.dataquality            clrcoeff    float
# 8         ztf.dataquality            clrcounc    float
# 9         ztf.dataquality              clrmed    float
# 10        ztf.dataquality              clrrms    float
# 11        ztf.dataquality              dsnrms    float
# 12        ztf.dataquality             exptime    float
# 13        ztf.dataquality                 fid      int
# 14        ztf.dataquality                fwhm    float
# 15        ztf.dataquality            magzpsci    float
# 16        ztf.dataquality         magzpscirms    float
# 17        ztf.dataquality         magzpsciunc    float
# 18        ztf.dataquality          mindtoedge    float
# 19        ztf.dataquality                nbad      int
# 20        ztf.dataquality            nmatches      int
# 21        ztf.dataquality                nneg      int
# 22        ztf.dataquality                 oid     char
# 23        ztf.dataquality               scorr    float
# 24        ztf.dataquality            seeratio    float
# 25        ztf.dataquality                 sky    float
# 26        ztf.dataquality              ssnrms    float
# 27        ztf.dataquality              sumrat    float
# 28        ztf.dataquality                xpos    float
# 29        ztf.dataquality                ypos    float
# 30        ztf.dataquality            zpclrcov    float
# 31        ztf.dataquality               zpmed    float
# 0           ztf.detection              candid     long
# 1           ztf.detection           corrected  boolean
# 2           ztf.detection                 dec   double
# 3           ztf.detection          diffmaglim    float
# 4           ztf.detection              distnr    float
# 5           ztf.detection                 drb    float
# 6           ztf.detection          drbversion     char
# 7           ztf.detection             dubious  boolean
# 8           ztf.detection                 fid      int
# 9           ztf.detection           has_stamp  boolean
# 10          ztf.detection           isdiffpos      int
# 11          ztf.detection               magap    float
# 12          ztf.detection            magapbig    float
# 13          ztf.detection              magpsf    float
# 14          ztf.detection         magpsf_corr    float
# 15          ztf.detection                 mjd   double
# 16          ztf.detection                 nid      int
# 17          ztf.detection                 oid     char
# 18          ztf.detection       parent_candid     long
# 19          ztf.detection                 pid   double
# 20          ztf.detection                  ra   double
# 21          ztf.detection                  rb    float
# 22          ztf.detection           rbversion     char
# 23          ztf.detection                rfid      int
# 24          ztf.detection            sigmagap    float
# 25          ztf.detection         sigmagapbig    float
# 26          ztf.detection            sigmapsf    float
# 27          ztf.detection       sigmapsf_corr    float
# 28          ztf.detection   sigmapsf_corr_ext    float
# 29          ztf.detection        step_id_corr     char
# 0             ztf.feature                 fid      int
# 1             ztf.feature                name     char
# 2             ztf.feature                 oid     char
# 3             ztf.feature               value   double
# 4             ztf.feature             version     char
# 0     ztf.feature_version     step_id_feature     char
# 1     ztf.feature_version  step_id_preprocess     char
# 2     ztf.feature_version             version     char
# 0   ztf.forced_photometry           adpctdif1    float
# 1   ztf.forced_photometry           adpctdif2    float
# 2   ztf.forced_photometry               chinr    float
# 3   ztf.forced_photometry            clrcoeff    float
# 4   ztf.forced_photometry            clrcounc    float
# 5   ztf.forced_photometry           corrected  boolean
# 6   ztf.forced_photometry                 dec   double
# 7   ztf.forced_photometry               decnr   double
# 8   ztf.forced_photometry          diffmaglim    float
# 9   ztf.forced_photometry              distnr    float
# 10  ztf.forced_photometry             dubious  boolean
# 11  ztf.forced_photometry               e_dec    float
# 12  ztf.forced_photometry               e_mag    float
# 13  ztf.forced_photometry          e_mag_corr    float
# 14  ztf.forced_photometry      e_mag_corr_ext    float
# 15  ztf.forced_photometry                e_ra    float
# 16  ztf.forced_photometry             exptime    float
# 17  ztf.forced_photometry                 fid      int
# 18  ztf.forced_photometry               field      int
# 19  ztf.forced_photometry           has_stamp  boolean
# 20  ztf.forced_photometry           isdiffpos      int
# 21  ztf.forced_photometry                 mag    float
# 22  ztf.forced_photometry            mag_corr    float
# 23  ztf.forced_photometry               magnr    float
# 24  ztf.forced_photometry            magzpsci    float
# 25  ztf.forced_photometry         magzpscirms    float
# 26  ztf.forced_photometry         magzpsciunc    float
# 27  ztf.forced_photometry                 mjd   double
# 28  ztf.forced_photometry                 oid     char
# 29  ztf.forced_photometry       parent_candid     char
# 30  ztf.forced_photometry                 pid     long
# 31  ztf.forced_photometry          procstatus     char
# 32  ztf.forced_photometry           programid      int
# 33  ztf.forced_photometry                  ra   double
# 34  ztf.forced_photometry                ranr   double
# 35  ztf.forced_photometry                rcid      int
# 36  ztf.forced_photometry                rfid     long
# 37  ztf.forced_photometry           scibckgnd    float
# 38  ztf.forced_photometry        sciinpseeing    float
# 39  ztf.forced_photometry           scisigpix    float
# 40  ztf.forced_photometry             sharpnr    float
# 41  ztf.forced_photometry            sigmagnr    float
# 0            ztf.gaia_ztf              candid     long
# 1            ztf.gaia_ztf             maggaia    float
# 2            ztf.gaia_ztf       maggaiabright    float
# 3            ztf.gaia_ztf            neargaia    float
# 4            ztf.gaia_ztf      neargaiabright    float
# 5            ztf.gaia_ztf                 oid     char
# 6            ztf.gaia_ztf             unique1  boolean
# 0             ztf.magstat           corrected  boolean
# 1             ztf.magstat            dm_first    float
# 2             ztf.magstat          dmdt_first    float
# 3             ztf.magstat            dt_first    float
# 4             ztf.magstat                 fid      int
# 5             ztf.magstat            firstmjd   double
# 6             ztf.magstat             lastmjd   double
# 7             ztf.magstat            magfirst    float
# 8             ztf.magstat       magfirst_corr    float
# 9             ztf.magstat             maglast    float
# 10            ztf.magstat        maglast_corr    float
# 11            ztf.magstat              magmax    float
# 12            ztf.magstat         magmax_corr    float
# 13            ztf.magstat             magmean    float
# 14            ztf.magstat        magmean_corr    float
# 15            ztf.magstat           magmedian    float
# 16            ztf.magstat      magmedian_corr    float
# 17            ztf.magstat              magmin    float
# 18            ztf.magstat         magmin_corr    float
# 19            ztf.magstat            magsigma    float
# 20            ztf.magstat       magsigma_corr    float
# 21            ztf.magstat                ndet      int
# 22            ztf.magstat            ndubious      int
# 23            ztf.magstat                 oid     char
# 24            ztf.magstat     saturation_rate   double
# 25            ztf.magstat       sigmadm_first    float
# 26            ztf.magstat             stellar  boolean
# 27            ztf.magstat        step_id_corr     char
# 0       ztf.non_detection          diffmaglim    float
# 1       ztf.non_detection                 fid      int
# 2       ztf.non_detection                 mjd   double
# 3       ztf.non_detection                 oid     char
# 0              ztf.object           corrected  boolean
# 1              ztf.object             deltajd   double
# 2              ztf.object             diffpos  boolean
# 3              ztf.object            firstmjd   double
# 4              ztf.object             g_r_max    float
# 5              ztf.object        g_r_max_corr    float
# 6              ztf.object            g_r_mean    float
# 7              ztf.object       g_r_mean_corr    float
# 8              ztf.object             lastmjd   double
# 9              ztf.object             meandec   double
# 10             ztf.object              meanra   double
# 11             ztf.object          mjdendhist   double
# 12             ztf.object        mjdstarthist   double
# 13             ztf.object            ncovhist      int
# 14             ztf.object                ndet      int
# 15             ztf.object            ndethist      int
# 16             ztf.object                 oid     char
# 17             ztf.object    reference_change  boolean
# 18             ztf.object            sigmadec   double
# 19             ztf.object             sigmara   double
# 20             ztf.object             stellar  boolean
# 21             ztf.object        step_id_corr     char
# 0         ztf.probability          class_name     char
# 1         ztf.probability     classifier_name     char
# 2         ztf.probability  classifier_version     char
# 3         ztf.probability                 oid     char
# 4         ztf.probability         probability    float
# 5         ztf.probability             ranking      int
# 0             ztf.ps1_ztf              candid     long
# 1             ztf.ps1_ztf           distpsnr1    float
# 2             ztf.ps1_ztf           distpsnr2    float
# 3             ztf.ps1_ztf           distpsnr3    float
# 4             ztf.ps1_ztf             nmtchps      int
# 5             ztf.ps1_ztf         objectidps1   double
# 6             ztf.ps1_ztf         objectidps2   double
# 7             ztf.ps1_ztf         objectidps3   double
# 8             ztf.ps1_ztf                 oid     char
# 9             ztf.ps1_ztf              sgmag1    float
# 10            ztf.ps1_ztf              sgmag2    float
# 11            ztf.ps1_ztf              sgmag3    float
# 12            ztf.ps1_ztf            sgscore1    float
# 13            ztf.ps1_ztf            sgscore2    float
# 14            ztf.ps1_ztf            sgscore3    float
# 15            ztf.ps1_ztf              simag1    float
# 16            ztf.ps1_ztf              simag2    float
# 17            ztf.ps1_ztf              simag3    float
# 18            ztf.ps1_ztf              srmag1    float
# 19            ztf.ps1_ztf              srmag2    float
# 20            ztf.ps1_ztf              srmag3    float
# 21            ztf.ps1_ztf              szmag1    float
# 22            ztf.ps1_ztf              szmag2    float
# 23            ztf.ps1_ztf              szmag3    float
# 24            ztf.ps1_ztf             unique1  boolean
# 25            ztf.ps1_ztf             unique2  boolean
# 26            ztf.ps1_ztf             unique3  boolean
# 0           ztf.reference              candid     long
# 1           ztf.reference               chinr    float
# 2           ztf.reference               decnr   double
# 3           ztf.reference                 fid      int
# 4           ztf.reference               field      int
# 5           ztf.reference               magnr    float
# 6           ztf.reference           mjdendref   double
# 7           ztf.reference         mjdstartref   double
# 8           ztf.reference          nframesref      int
# 9           ztf.reference                 oid     char
# 10          ztf.reference                ranr   double
# 11          ztf.reference                rcid      int
# 12          ztf.reference                rfid     long
# 13          ztf.reference             sharpnr    float
# 14          ztf.reference            sigmagnr    float
# 0              ztf.ss_ztf              candid     long
# 1              ztf.ss_ztf                 oid     char
# 2              ztf.ss_ztf            ssdistnr    float
# 3              ztf.ss_ztf             ssmagnr    float
# 4              ztf.ss_ztf            ssnamenr     char
# 0            ztf.taxonomy             classes     char
# 1            ztf.taxonomy     classifier_name     char
# 2            ztf.taxonomy  classifier_version     char
# 0              ztf.xmatch               catid     char
# 1              ztf.xmatch       class_catalog     char
# 2              ztf.xmatch                dist   double
# 3              ztf.xmatch                 oid     char
# 4              ztf.xmatch         oid_catalog     char
# 5              ztf.xmatch              period   double

# %% [markdown]
# # Query objects

# %% [markdown]
# Query objects which appeared between March 1st 2021 and Apr 1st 2021, which have at most one detection, and which are classified as asteroids by the stamp classifier with a probability greater than 0.7
#
# Objects can share the same `oid` (not the `candid`) if they appear at the same position. Asteroids move, so we choose those than appear only once (`ndet=1`).
#
# The probability of being an asteroid is computed by the stamp classifier and is stored in the table `probability`, so we need to do an inner join with the table `object`.
#
# This query takes about 4 min.

# %%
mjd_first = Time("2021-03-01T00:00:00", scale='utc').mjd
mjd_last  = Time("2021-04-01T00:00:00", scale='utc').mjd

query = '''
SELECT
    o.oid, o.meanra, o.meandec, o.firstmjd,
    o.ndet, p.probability
FROM
    ztf.object AS o
INNER JOIN ztf.probability AS p
ON o.oid = p.oid
WHERE
    o.firstmjd > %s
    AND o.firstmjd < %s
    AND o.ndet = 1
    AND p.classifier_name = 'stamp_classifier'
    AND p.ranking = 1
    AND p.class_name = 'asteroid'
    AND p.probability > 0.7
''' % (mjd_first, mjd_last)

ast = tap_query(query)
ast.set_index('oid', inplace=True)
print(ast.shape)
ast.head()
# Out:
# (106638, 5)
#                   meanra    meandec      firstmjd  ndet  probability
# oid
# ZTF21aanqpxc  157.088644  15.424231  59274.212454     1     0.728637
# ZTF21aanqsij  166.507409   5.767901  59274.234097     1     0.737139
# ZTF21aanqstg  166.023145  20.596190  59274.239144     1     0.738226
# ZTF21aanqsty  156.042696   6.830062  59274.240544     1     0.744554
# ZTF21aanqsyn  155.721404   7.951704  59274.240544     1     0.728550

# %% [markdown]
# # Check whether these objects are reported as known asteroids
#
# Once we have all asteroids candidates, we wonder if some of them are known asteroids. So we go to table `ss_ztf` to look for our asteroids candidates using their `oid`.
#
# Table `ss_ztf` gives data from the Minor Planet Center (MPC) of the nearest known body. If there is not a reported nearby SS object the table will contain a `ssdistnr` value of -999.

# %%
oids = list(ast.index)
query = """
SELECT s.*
FROM ztf.ss_ztf AS s
JOIN tap_upload.mylist AS u ON s.oid = u.objectid
WHERE s.ssdistnr >= 0
ORDER BY s.oid
"""
ss = tap_query_idlist(query, oids)
print(ss.shape)
ss.head()
# Out:
# (106374, 5)
#             oid               candid  ssdistnr    ssmagnr ssnamenr
# 0  ZTF18aaavzci  1549155913415015015       0.0  19.900000    77314
# 1  ZTF18aaaxbqb  1549153564115015003       1.0  19.500000    36263
# 2  ZTF18aaaxbuo  1547212622015015006       0.0  18.100000    13289
# 3  ZTF18aabqfyb  1550307190015015012       0.0  19.799999   349197
# 4  ZTF18aabwrag  1549239930415015008       0.0  20.000000   175315

# %% [markdown]
# We can see that most objects previously found were known to MPC.

# %% [markdown]
# # Plot distribution of separations for those objects with a xmatch in MPC
#
# How many bodies are known asteroids?
#
# How close is a detected body to the estimated nearest known body?

# %%
ax = ss.ssdistnr.plot.hist(bins=30, log=True)
ax.set_xlabel('arcsec');

# %% [markdown]
# There is  small tail (we are using log scale) going to large separations, probably poorly determined asteroid trajectories in MPC or detections that do not correspond to any known asteroid.

# %% [markdown]
# # Move to ecliptic coordinates
#
# Using `astropy.coordinates.SkyCoord` is very easy to move from one coordinate system to another. But be careful: you might be including unnecesary corrections (light-travel time corrections, different origins, etc.)
#
# We tell `astropy` to go from `icrs` to `barycentrictrueecliptic` (both barycentric) since it only applies a simple rotation (althoug we observe from the Earth, not the barycenter).

# %%
from astropy.coordinates import SkyCoord
eq = SkyCoord(ast['meanra'].values, ast['meandec'].values, unit='deg', frame='icrs')
ecl = eq.barycentrictrueecliptic

# %%
ast["ecl_lat"] = ecl.lat.deg
ast["ecl_long"] = ecl.lon.deg

# %% [markdown]
# # Plot histogram of ecliptic latitudes

# %%
fig, ax = plt.subplots()
ax.hist(ast.ecl_lat, bins=100)
ax.set_xlabel("ecliptic latitude", fontsize=20)
ax.set_ylabel("N", fontsize=20);

# %% [markdown]
# Note that most selected objects are around the ecliptic. We will also look at the individual tracks in what follows.

# %% [markdown]
# # Plot ecliptic coordinates in the sky using datashader

# %% [markdown]
# Let's use datashader to plot the ecliptic coordinates of all the previous asteroids.

# %%
#!pip install datashader
import datashader as ds

# %%
# do datashade aggregation
x_range = [0, 360]
y_range = [-90, 90]
cvs = ds.Canvas(plot_width=150, plot_height=50, x_range=x_range, y_range=y_range)
agg = cvs.points(ast, 'ecl_long', 'ecl_lat')

# show result
fig, ax = plt.subplots(figsize=(14, 10))
im = ax.imshow(np.log10(agg), extent=x_range + y_range)
ax.set_xlabel("Ecliptic latitude")
ax.set_ylabel("Ecliptic longitude")
ax.axhline(0, c='k')

# add colorbar
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="2%", pad=0.05)
plt.colorbar(im, cax=cax)
plt.show()
# Out:
# /home/ammunoz1/.local/lib/python3.11/site-packages/xarray/core/computation.py:821: RuntimeWarning: divide by zero encountered in log10
#   result_data = func(*input_data)

# %% [markdown]
# As expected, almost all asteroids are near the ecliptic plane. We cannot see the entire ecliptic in one month of data alone.

# %% [markdown]
# # Show the object with the largest number of detections
#
# Lets look for a pretty example. Lets find the (known) asteroid with the most detections and see how it looks like.

# %%
ndet = ss.groupby("ssnamenr").apply(lambda df: df.shape[0], include_groups=False)

# %%
ax = ndet.plot.hist(log=True,
                    bins=np.linspace(1, max(ndet) + 1, max(ndet) + 1) - .5)
ax.set_xticks(np.linspace(1, max(ndet), max(ndet)))
ax.set_xlabel('Number of detections');

# %% [markdown]
# `ndet` is a table with the amount of appearances of each known asteroid.

# %%
ndet.head()
# Out:
# ssnamenr
# 10002     3
# 100028    1
# 10004     3
# 100040    3
# 100041    3
# dtype: int64

# %% [markdown]
# # Plot the trajectories of all asteroids with at least 9 detections in equatorial and ecliptic coordinates

# %%
fig, ax = plt.subplots(ncols=2, figsize=(18,7), sharey=True)
ndetmin = 9

# Getting the names of asteroids with at least 9 detections
for ssnamenr in ndet.loc[ndet>=ndetmin].index:
    # Getting the oids of the known asteroid in table 'ss'
    oids = ss.loc[ss.ssnamenr==ssnamenr].oid

    # Getting if oids in table 'ast' is in oids (from 'ss' of known bodies)
    mask = ast.index.isin(oids)                  
    
    ax[0].plot(ast.loc[mask].meanra, ast.loc[mask].meandec, alpha=0.4)
    ax[0].set_title(">%i detections" % ndetmin)
    ax[0].set_xlabel("RA"); ax[0].set_ylabel("DEC")

    ax[1].plot(ast.loc[mask].ecl_long, ast.loc[mask].ecl_lat, alpha=0.4)
    ax[1].set_title(r">%i detections" % ndetmin)
    ax[1].set_xlabel("ECL LONG")
    ax[1].set_ylabel("ECL LAT")

# %% [markdown]
# The trajectories in ecliptic coordinates look more horizontal, as expected.

# %% [markdown]
# # Focus on the asteroid with the most detections (*153935*)

# %%
bestast = ndet.idxmax()
print(bestast, ndet[bestast])
# Out:
# 153935 16

# %%
fig, ax = plt.subplots(ncols=2, figsize=(18, 7))
oids = ss.loc[ss.ssnamenr == bestast].oid
maskbest = ast.index.isin(oids)

ax[0].scatter(ast.loc[maskbest].meanra, ast.loc[maskbest].meandec, alpha=0.4)
ax[0].set_title(bestast); ax[0].set_xlabel("RA")
ax[0].set_ylabel("DEC")

ax[1].scatter(ast.loc[maskbest].ecl_long, ast.loc[maskbest].ecl_lat, alpha=0.4)
ax[1].set_title(bestast); ax[1].set_xlabel("ECL LONG")
ax[1].set_ylabel("ECL LAT")
plt.show()

# %% [markdown]
# Note that second panel is about ~0.3 deg tall and ~5 deg wide.

# %% [markdown]
# # Query and plot the light curve of *153935*
#
# Magnitudes, colors and light curves give are important for asteroids' analysis. Having the `oid` of the detections we want (in this case, for the asteroid _153935_) we can get their magnitudes from table `detection` (we could also have used the table `magstat`).

# %%
query = '''
SELECT
    oid, mjd, fid, magap, sigmagap, has_stamp
FROM
    ztf.detection AS d
JOIN tap_upload.mylist AS u ON d.oid = u.objectid
ORDER BY oid
'''

dets = tap_query_idlist(query, oids)
print(dets.shape)
dets
# Out:
# (16, 6)
#              oid           mjd  fid      magap  sigmagap  has_stamp
# 0   ZTF21aanzble  59276.257963    1  18.554501    0.0909       True
# 1   ZTF21aaqoxdu  59297.207396    1  18.406601    0.1152       True
# 2   ZTF21aaqpjvj  59297.258113    2  18.521099    0.1409       True
# 3   ZTF21aaqsnyf  59298.308194    2  18.068399    0.4209       True
# 4   ZTF21aaqyrqn  59303.279120    1  18.889601    0.2237       True
# 5   ZTF21aaqyzoj  59303.316192    2  18.664000    0.1742       True
# 6   ZTF21aarbeuz  59302.237153    2  18.611700    0.2218       True
# 7   ZTF21aarbleq  59302.263218    2  18.713499    0.2541       True
# 8   ZTF21aarcgki  59302.328241    1  18.770300    0.2773       True
# 9   ZTF21aarchtw  59302.332037    1  19.069300    0.3458       True
# 10  ZTF21aardyyf  59304.172708    2  18.554501    0.0915       True
# 11  ZTF21aaredlw  59304.213461    1  18.540800    0.1002       True
# 12  ZTF21aarefqd  59304.235903    1  18.891100    0.1588       True
# 13  ZTF21aaremfh  59304.277083    2  18.463499    0.1251       True
# 14  ZTF21aarervg  59304.306736    2  18.449699    0.1217       True
# 15  ZTF21aarfcpt  59304.349143    1  19.297701    0.2617       True

# %% [markdown]
# Plot the predicted light curve (by MPC) and compare it to the observed light curve in g and r bands

# %%
# Just how we got oids, we can get MPC's magnitudes
#Vmpc = ss.loc[ss.oid.isin(oids)].ssmagnr.values
Vmpc = ss.loc[ss.ssnamenr == bestast].ssmagnr.values

# We extract mjds and magnitudes we got from table 'detection'
t = dets.mjd.values; mags = dets.magap.values; mags_err = dets.sigmagap.values
# ZTF observes in two filters: g & r
filters = dets.fid.values; g = filters==1; r = filters==2

fig, ax = plt.subplots(ncols=2, figsize=(10,4))
fig.subplots_adjust(top=0.96, bottom=.17, hspace=0.05, wspace=0.25)

ax[0].scatter(t, Vmpc, color='y')
ax[0].set_title(bestast); ax[0].set_xlabel("MJD"); ax[0].set_ylabel("V [MPC]")

ax[1].errorbar(t[g], mags[g], yerr=mags_err[g], color='g', label='g', fmt='o')
ax[1].errorbar(t[r], mags[r], yerr=mags_err[r], color='r', label='r', fmt='o')
ax[1].set_title(bestast); ax[1].set_xlabel("MJD"); ax[1].set_ylabel("MAG [ZTF]")
ax[1].legend(loc="upper left")

plt.show()

# %% [markdown]
# # Show the image stamps of *153935*
#
# If you want to do your own photometry or your own image subtraction or get some morphological characterization (important for comets), do some visual inspection or just a nice gif, you may want to access the stamps of your candidates.
#
# To get the stamps, you need to use the `client` of `Alerce`.

# %%
import sys
from astropy.visualization import ZScaleInterval, ImageNormalize

for oid in oids:
    try:
        stamps = client.get_stamps(oid) # get_stamps(oid) returns three fits-like images
        if stamps is None:
          print("Could not find stamp for object id %s" % oid)
          continue
        
        fig, ax = plt.subplots(ncols=3, figsize=(12, 4))
        science, ref, difference = stamps[0].data, stamps[1].data, stamps[2].data
        titles = ['Science', 'Reference', 'Difference']
        for idx, im in enumerate([science, ref, difference]):
            norm = ImageNormalize(im, interval=ZScaleInterval()) 
            ax[idx].imshow(im, cmap='viridis', norm=norm, interpolation='nearest') # Log scale for visualization
            ax[idx].axes.get_xaxis().set_visible(False); ax[idx].axes.get_yaxis().set_visible(False)
            ax[idx].set_title(titles[idx])
        plt.show()
    except: print("%s ERROR:" %oid, sys.exc_info())
# Out:
# WARNING: VerifyWarning: Keyword name 'STAMP_TYPE' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'STAMP_TYPE' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'STAMP_TYPE' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'STAMP_TYPE' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'STAMP_TYPE' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'STAMP_TYPE' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'STAMP_TYPE' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'STAMP_TYPE' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'STAMP_TYPE' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'STAMP_TYPE' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'STAMP_TYPE' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'STAMP_TYPE' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'STAMP_TYPE' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'STAMP_TYPE' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'STAMP_TYPE' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'STAMP_TYPE' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]

# %% [markdown]
# # Get entire light curve for this object

# %%
query = '''
SELECT
    *
FROM
    ztf.ss_ztf
WHERE 
    ssnamenr = '%s'
''' % bestast

selast = tap_query(query)
selast.set_index("candid", inplace=True)
print(selast.shape)
selast.head()
# Out:
# (108, 4)
#                               oid  ssdistnr    ssmagnr ssnamenr
# candid
# 1494421411215015006  ZTF21aagsiea       0.0  18.600000   153935
# 1514352983415015007  ZTF21aamupwt       0.0  18.200001   153935
# 1469398285015015008  ZTF21aacsrya       1.0  19.200001   153935
# 1536316095715015018  ZTF21aaphstx       0.0  18.299999   153935
# 1536341505715015012  ZTF21aapilca      12.0  18.299999   153935

# %% [markdown]
# The columns in this table are the unique detection identifier `candid`, the unique object identifier `oid`, the distance to the nearest MPC source in arcsec `ssdistnr`, the V magnitude of the nearest MPC source `ssmagnr`, and the name of the nearest MPC soure `ssnamenr`.
#
# Get the magnitudes

# %%
query = '''
SELECT
    candid, mjd, fid, magpsf, sigmapsf
FROM
    ztf.detection as d
JOIN tap_upload.mylist AS u ON d.candid = u.objectid
'''

selast_lc = tap_query_idlist(query, selast.index)
selast_lc.set_index("candid", inplace=True)
print(selast_lc.shape)
selast_lc.head()
# Out:
# (107, 4)
#                               mjd  fid     magpsf  sigmapsf
# candid
# 1494421411215015006  59248.421412    2  18.601583  0.066065
# 1514352983415015007  59268.352986    2  18.134296  0.056090
# 1469398285015015008  59223.398287    1  19.698408  0.208465
# 1536316095715015018  59290.316099    1  18.652458  0.081407
# 1536341505715015012  59290.341505    2  19.025639  0.201007

# %% [markdown]
# Now we can use the previous magnitudes to get a more complete light curve.

# %%
colors = {1: 'g', 2: 'r'}
fig, ax = plt.subplots(figsize=(12,5))
for fid in selast_lc.fid.unique():
  mask = (selast_lc.fid == fid)
  ax.errorbar(selast_lc.loc[mask].mjd, selast_lc.loc[mask].magpsf,
              yerr=selast_lc.loc[mask].sigmapsf, c=colors[fid],
              label = "ZTF %s" % colors[fid])
ax.plot(selast_lc.mjd, selast.loc[selast_lc.index].ssmagnr, c='y', label='MPC V')
ax.set_ylim(ax.get_ylim()[::-1])
ax.set_xlabel("MJD", fontsize=18)
ax.set_ylabel("mag", fontsize=18)
ax.legend();

# %% [markdown]
# And now we will use the MPC magnitude to look for any deviations.

# %%
fig, ax = plt.subplots(figsize=(12,5))
for fid in selast_lc.fid.unique():
  mask = (selast_lc.fid == fid)
  ax.errorbar(selast_lc.loc[mask].mjd,
              selast_lc.loc[mask].magpsf \
              - selast.loc[selast_lc.loc[mask].index].ssmagnr,
              yerr=selast_lc.loc[mask].sigmapsf,
              c=colors[fid], label='ZTF %s - MPC V' % colors[fid])
ax.set_ylim(ax.get_ylim()[::-1])
ax.set_xlim(59200,ax.get_xlim()[1])
ax.legend()
ax.set_xlabel("MJD", fontsize=18)
ax.set_ylabel(r"$\Delta$ mag", fontsize=18);

# %% [markdown]
# Is that decrease in brightness real?

# %% [markdown]
# # Getting the ephemerides

# %% [markdown]
# ALEPH: Alerce Ephemerides (under construction, but preview available):
#
#     from aleph_test import Query
#     from astropy.coordinates import EarthLocation
#     from astropy import units as u
#
#     observer = EarthLocation.of_site('Palomar')
#     q = Query.Query()
#
#     ras_aleph = []; decs_aleph = []
#     ras = []; decs = []
#     for idx in np.where(maskbest)[0]:
#         epoch = Time(ast.firstmjd[idx], format='mjd', scale='utc')
#         center = SkyCoord(ast.meanra[idx], ast.meandec[idx], unit='deg')
#         eph = q.query_nb(center, 1*u.deg, epoch=epoch, observer=observer, ast_idxs=(int(bestast)-1,))
#         ras_aleph.append(eph['ra'][0]); decs_aleph.append(eph['dec'][0])
#         ras.append(ast.meanra[idx]); decs.append(ast.meandec[idx])
#     coords_aleph = SkyCoord(ras_aleph, decs_aleph)
#     coords_ztf = SkyCoord(ras, decs, unit='deg')

# %% [markdown]
# Although ALEPH is not yet publicly available, we have precomputed the ephemerides for the asteroid with the most detections.

# %%
from astropy import units as u
import urllib.request
import pickle

coords_aleph = pickle.load(urllib.request.urlopen(
    "https://github.com/alercebroker/usecases/blob/master/example_data/ephs_153935_20210301-20210402.pkl?raw=true"
))
coords_ztf = SkyCoord(ast.loc[maskbest].meanra.values, ast.loc[maskbest].meandec.values, unit='deg')

# %%
coords_aleph.separation(coords_ztf).arcsec
# Out:
# array([[2.93660196e-02, 1.44738909e+04, 1.45030641e+04, 1.50611209e+04,
#         1.73746478e+04, 1.73909875e+04, 1.77286432e+04, 1.77458020e+04,
#         1.77551419e+04, 1.77727498e+04, 1.77851667e+04, 1.78030619e+04,
#         1.69453750e+04, 1.69775467e+04, 1.69756251e+04, 1.69330132e+04],
#        [1.44738491e+04, 3.41196137e-01, 3.00673293e+01, 6.07355899e+02,
#         3.04673040e+03, 3.06443854e+03, 3.43068217e+03, 3.44928018e+03,
#         3.45944008e+03, 3.47853503e+03, 3.49214283e+03, 3.51163655e+03,
#         2.58621387e+03, 2.62059663e+03, 2.61855915e+03, 2.57308013e+03],
#        [1.45030702e+04, 3.02322919e+01, 2.34404326e-01, 5.77200535e+02,
#         3.01669904e+03, 3.03440934e+03, 3.40069786e+03, 3.41929807e+03,
#         3.42945927e+03, 3.44855651e+03, 3.46216636e+03, 3.48166266e+03,
#         2.55613927e+03, 2.59052494e+03, 2.58848733e+03, 2.54300465e+03],
#        [1.50612560e+04, 6.07511352e+02, 5.77373587e+02, 3.60705276e-01,
#         2.44164092e+03, 2.45939223e+03, 2.82652810e+03, 2.84516940e+03,
#         2.85535528e+03, 2.87449516e+03, 2.88814420e+03, 2.90768927e+03,
#         1.98027500e+03, 2.01471468e+03, 2.01267488e+03, 1.96712446e+03],
#        [1.73746224e+04, 3.04686620e+03, 3.01684353e+03, 2.44172031e+03,
#         1.06878204e-01, 1.78208041e+01, 3.87235569e+02, 4.05978438e+02,
#         4.16231529e+02, 4.35477782e+02, 4.49248701e+02, 4.68929254e+02,
#         4.63100498e+02, 4.28560719e+02, 4.30601141e+02, 4.76264694e+02],
#        [1.73910954e+04, 3.06465570e+03, 3.03463493e+03, 2.45954858e+03,
#         1.79681231e+01, 1.49858411e-01, 3.69315830e+02, 3.88058712e+02,
#         3.98311901e+02, 4.17558194e+02, 4.31329479e+02, 4.51010270e+02,
#         4.81017216e+02, 4.46478023e+02, 4.48518356e+02, 4.94180945e+02],
#        [1.69331222e+04, 2.57331571e+03, 2.54325091e+03, 1.96731368e+03,
#         4.76085614e+02, 4.93940124e+02, 8.63164050e+02, 8.81901097e+02,
#         8.92148332e+02, 9.11388085e+02, 9.25144041e+02, 9.44811996e+02,
#         1.30357594e+01, 4.75789706e+01, 4.55370387e+01, 1.39828217e-01],
#        [1.69453628e+04, 2.58636999e+03, 2.55630616e+03, 1.98038753e+03,
#         4.62981884e+02, 4.80836831e+02, 8.50068822e+02, 8.68806170e+02,
#         8.79053644e+02, 8.98293718e+02, 9.12050192e+02, 9.31718641e+02,
#         1.58946274e-01, 3.44717570e+01, 3.24298806e+01, 1.32441814e+01],
#        [1.69757362e+04, 2.61885495e+03, 2.58879379e+03, 2.01292694e+03,
#         4.30339634e+02, 4.48195268e+02, 8.17441987e+02, 8.36179920e+02,
#         8.46427862e+02, 8.65668563e+02, 8.79426074e+02, 8.99095509e+02,
#         3.27194543e+01, 1.83945722e+00, 2.72457468e-01, 4.58889180e+01],
#        [1.69774966e+04, 2.62074177e+03, 2.59068078e+03, 2.01481717e+03,
#         4.28442209e+02, 4.46297864e+02, 8.15545205e+02, 8.34283165e+02,
#         8.44531129e+02, 8.63771859e+02, 8.77529419e+02, 8.97198901e+02,
#         3.46169177e+01, 2.50291484e-01, 2.12108264e+00, 4.77862799e+01],
#        [1.77286059e+04, 3.43078242e+03, 3.40080486e+03, 2.82655911e+03,
#         3.87276031e+02, 3.69409154e+02, 8.60236305e-03, 1.87495347e+01,
#         2.90029914e+01, 4.82493190e+01, 6.20234691e+01, 8.17063072e+01,
#         8.50140382e+02, 8.15618538e+02, 8.17656807e+02, 8.63292803e+02],
#        [1.77458531e+04, 3.44947517e+03, 3.41949974e+03, 2.84529482e+03,
#         4.06113641e+02, 3.88246768e+02, 1.88309674e+01, 8.80922130e-02,
#         1.01658378e+01, 2.94118862e+01, 4.31873756e+01, 6.28705048e+01,
#         8.68972611e+02, 8.34451424e+02, 8.36489626e+02, 8.82124641e+02],
#        [1.77553757e+04, 3.45981749e+03, 3.42984329e+03, 2.85566225e+03,
#         4.16544269e+02, 3.98677416e+02, 2.92617528e+01, 1.05190204e+01,
#         2.69994522e-01, 1.89809671e+01, 3.27569259e+01, 5.24400745e+01,
#         8.79398737e+02, 8.44878013e+02, 8.46916168e+02, 8.92550496e+02],
#        [1.77728308e+04, 3.47881821e+03, 3.44884640e+03, 2.87471180e+03,
#         4.35723368e+02, 4.17856588e+02, 4.84421071e+01, 2.96999771e+01,
#         1.94460478e+01, 2.67210496e-01, 1.35760907e+01, 3.32591021e+01,
#         8.98566626e+02, 8.64046948e+02, 8.66084996e+02, 9.11717779e+02],
#        [1.77853386e+04, 3.49246940e+03, 3.46249941e+03, 2.88840031e+03,
#         4.49516103e+02, 4.31649409e+02, 6.22370137e+01, 4.34955997e+01,
#         3.32417445e+01, 1.39997716e+01, 2.20137186e-01, 1.94630240e+01,
#         9.12348898e+02, 8.77830132e+02, 8.79868088e+02, 9.25499528e+02],
#        [1.78030590e+04, 3.51186229e+03, 3.48189505e+03, 2.90784950e+03,
#         4.69129728e+02, 4.51263217e+02, 8.18563285e+01, 6.31163522e+01,
#         5.28628554e+01, 3.36222711e+01, 1.98426342e+01, 3.22416294e-01,
#         9.31944126e+02, 8.97426896e+02, 8.99464697e+02, 9.45093886e+02]])

# %%
plt.scatter(coords_ztf.ra.deg, coords_ztf.dec.deg, color='r', label="ZTF")
#plt.scatter(coords_aleph.ra.deg, coords_aleph.dec.deg, color='k', marker='+', label="ALEPH")
plt.xlabel("RA")
plt.ylabel('DEC')
plt.legend();

# %% [markdown]
# # ALEPH vs. Public Services
#
# We now show the distribution of distances between the observed coordinates and those computed by the MPC, the IMCCE, and ALEPH.
#
# * MPC: https://minorplanetcenter.net/cgi-bin/checkmp.cgi (it only allows time precision of 0.01 days)
# * IMCCE: http://vo.imcce.fr/webservices/miriade/?ephemph and Python's `astroquery.imcce.Skybot`
#
# <img src="https://raw.githubusercontent.com/alercebroker/usecases/master/notebooks/ZTF/figures/dists_contours.png">
#
# IMCCE and ALEPH's ephemerides consider the gravitational pull from the Sun and the planets (plus Pluto). ALEPH's coordinates are more precise and less biased!
# (and calculated in similar times).
