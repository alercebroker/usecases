# %% [markdown]
# # ALeRCE basics
#
# ```Author: Alejandra Muñoz-Arancibia. Last updated: 20251023```
#
# A brief set of examples on how to interact with the ALeRCE data using our custom python client (https://alerce.readthedocs.io/en/latest/index.html), including how to display object light curves and stamp cutouts.
#
# *It is highly recommended that you try this notebook in Google Colab using the following [link](https://colab.research.google.com/github/alercebroker/usecases/blob/master/notebooks/MAS_Oct2025_tutorial/ALeRCE_Basics_MAS.ipynb).* This will avoid you from having to sort out library installation problems and focus on the contents of the tutorial. You can try installing the dependencies later in your own system.

# %% [markdown]
# ### Some settings

# %% [markdown]
# First install the ALeRCE python client (uncomment the following line)

# %%
#!pip install alerce

# %% [markdown]
# Load libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from astropy.coordinates import SkyCoord
import astropy.units as u
from IPython.core.display import HTML

# %%
from alerce.core import Alerce

# %% [markdown]
# Initialize the ALeRCE client

# %%
client = Alerce()

# %% [markdown]
# ### Choose a ZTF object

# %%
oid = "ZTF25abansec"

# %% [markdown]
# We can find this object in the ALeRCE Explorer as https://alerce.online/object/ZTF25abansec.

# %% [markdown]
# ### Show its light curve

# %%
obj_dets = client.query_detections(oid, format='pandas')
obj_nondets = client.query_non_detections(oid, format='pandas')
obj_fp = client.query_forced_photometry(oid, format='pandas')

# %% [markdown]
# Note that when LSST starts its public stream, we will use an updated ALeRCE client version. The queries will change a little:

# %%
## Uncomment the following lines after the LSST stream starts
## Will work for an updated ALeRCE client version

#obj_dets = client.query_detections(oid, survey='ztf', format='pandas')
#obj_nondets = client.query_non_detections(oid, survey='ztf', format='pandas')
#obj_fp = client.query_forced_photometry(oid, survey='ztf', format='pandas')

# %% [markdown]
# We define a function to plot the light curve using difference magnitudes

# %%
def plot_lc(oid, obj_dets, obj_nondets, obj_fp):
    fig, ax = plt.subplots(figsize=(10, 4))
    labels = {1: 'g', 2: 'r', 3: 'i'}
    markers = {1: 'o', 2: 's', 3: 'X'}
    colors = {1: '#56E03A', 2: '#D42F4B', 3: '#F4D617'} 
    
    for fid in [1, 2]:
        mask = obj_dets["fid"] == fid
        if len(obj_dets[mask]) > 0:
            ax.errorbar(obj_dets[mask]["mjd"], obj_dets[mask]["magpsf"],
                        yerr=obj_dets[mask]["sigmapsf"], c=colors[fid],
                        label="%s (detection)" % labels[fid],
                        marker=markers[fid], linestyle='None')
        
        mask = (obj_nondets["fid"] == fid) & (obj_nondets["diffmaglim"] > -900)
        if len(obj_nondets[mask]) > 0:     
            ax.scatter(obj_nondets[mask]["mjd"],
                       obj_nondets[mask]["diffmaglim"],
                       c=colors[fid], alpha=0.5, marker='v',
                       label="%s (limit mag)" % labels[fid], s=20)

        if len(obj_fp) == 0:
            continue
        mask = (obj_fp["fid"] == fid) \
               & (obj_fp["mag"] / obj_fp["e_mag"] >= 3) \
               & (obj_fp["e_mag"] < 1.)
        if len(obj_fp[mask]) > 0:
            ax.errorbar(obj_fp[mask]["mjd"], obj_fp[mask]["mag"], 
                        yerr=obj_fp[mask]["e_mag"], c=colors[fid],
                        label="%s (forced phot)" % labels[fid],
                        marker=markers[fid], linestyle='None', alpha=0.3)
            
    ax.set_title(oid, fontsize=15)
    ax.set_xlabel("MJD", fontsize=15)
    ax.set_ylabel("Difference magnitude", fontsize=15)
    ax.legend()
    ax.set_ylim(ax.get_ylim()[::-1])

# %%
plot_lc(oid, obj_dets, obj_nondets, obj_fp)

# %% [markdown]
# ### Show its first stamps (science, template and difference)

# %% [markdown]
# We first find the identifier of the first detection that has stamps

# %%
candid = obj_dets[obj_dets["has_stamp"]].sort_values(by="mjd").iloc[0]["candid"]

# %%
stamps = client.plot_stamps(oid, candid)
# Out:
#         <div>ZTF oid: ZTF25abansec, candid: 3111260546015015001</div>
#         <div>&emsp;&emsp;&emsp;&emsp;&emsp;
#         Science
#         &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;
#         Template
#         &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;
#         Difference
#         <div class="container">
#         <div style="float:left;width:20%"><img src="https://avro.alerce.online/get_stamp?oid=ZTF25abansec&candid=3111260546015015001&type=science&format=png"></div>
#         <div style="float:left;width:20%"><img src="https://avro.alerce.online/get_stamp?oid=ZTF25abansec&candid=3111260546015015001&type=template&format=png"></div>
#         <div style="float:left;width:20%"><img src="https://avro.alerce.online/get_stamp?oid=ZTF25abansec&candid=3111260546015015001&type=difference&format=png"></div>
#         </div>

# %% [markdown]
# And when LSST starts, this query will be:

# %%
## Uncomment the following lines after the LSST stream starts
## Will work for an updated ALeRCE client version

#stamps = client.plot_stamps(oid, candid, survey='ztf')

# %% [markdown]
# ### Query a list of ZTF objects based on their most likely class (i.e. their ranking = 1 probability) according to an ALeRCE light curve classifier

# %% [markdown]
# We query the top 500 objects classified as SNIa by `lc_classifier_BHRF_forced_phot` (Cabrera-Vives et al., in preparation), sort by probability in descending order:

# %%
query_results = client.query_objects(
    classifier="lc_classifier_BHRF_forced_phot",
    class_name="SNIa",
    page_size=500,
    order_by='probability',
    order_mode='DESC',
    format='pandas')

# %% [markdown]
# And for LSST, this becomes:

# %%
## Uncomment the following lines after the LSST stream starts
## Will work for an updated ALeRCE client version

#query_results = client.query_objects(
#    classifier="lc_classifier_BHRF_forced_phot",
#    class_name="SNIa",
#    page_size=500,
#    order_by='probability',
#    order_mode='DESC',
#    survey='ztf',
#    format='pandas')

# %% [markdown]
# We show some relevant columns

# %%
cols = ["oid", "ndet", "meanra", "meandec",
        "firstmjd", "lastmjd", "deltajd",
        "probability"]
query_results[cols]
# Out:
#               oid  ndet      meanra    meandec      firstmjd       lastmjd  \
# 0    ZTF25abioriw    44  353.977209  47.076469  60901.373599  60968.132639
# 1    ZTF25abckwuq    46  277.626621  26.831028  60878.257627  60948.219965
# 2    ZTF25aavdmzf   168  331.058529  -1.997467  60841.363715  60948.288472
# 3    ZTF25aakbqpl    33  136.705877  48.768694  60757.194803  60818.261759
# 4    ZTF25aaxnchn    65  316.960654  18.152163  60851.341424  60932.289687
# ..            ...   ...         ...        ...           ...           ...
# 495  ZTF25aamkdzv    21  246.109028  16.677673  60775.435706  60824.320035
# 496  ZTF25abugbyo    17  263.974826  55.673664  60948.158079  60969.162164
# 497  ZTF25absbrdm    18  278.813290  59.057612  60938.174039  60967.113276
# 498  ZTF25abagvaw    22    9.664391   9.996267  60863.467164  60889.323229
# 499  ZTF25aaqemjr    16  191.172039 -12.018992  60810.210405  60845.205891
#
#         deltajd  probability
# 0     66.759039     0.884000
# 1     69.962338     0.874248
# 2    106.924757     0.852852
# 3     61.066956     0.838000
# 4     80.948264     0.823472
# ..          ...          ...
# 495   48.884329     0.404064
# 496   21.004086     0.404000
# 497   28.939236     0.403920
# 498   25.856065     0.403920
# 499   34.995486     0.403260
#
# [500 rows x 8 columns]

# %% [markdown]
# ### Show their distribution of probabilities

# %%
col = "probability"
fig, ax = plt.subplots(figsize=(6, 4))
ax.hist(query_results[col], bins=50)
ax.set_xlabel(col, fontsize=15)
ax.set_ylabel("Frequency", fontsize=15);

# %% [markdown]
# ### Show their spatial coordinates

# %% [markdown]
# We display them together with the Galactic plane ($b = 0$)

# %%
gal_plane_l = np.linspace(0., 360., 360)
gal_plane_b = 0. * gal_plane_l
gal_plane_coords = SkyCoord(l=gal_plane_l, b=gal_plane_b,
                            unit=(u.deg, u.deg), frame="galactic")
gal_plane_ra = gal_plane_coords.icrs.ra.value
gal_plane_dec = gal_plane_coords.icrs.dec.value

# %%
fig, ax = plt.subplots(figsize=(6, 4))
ax.scatter(gal_plane_ra, gal_plane_dec, s=3, c="gray", alpha=0.5)
ax.scatter(query_results["meanra"], query_results["meandec"], alpha=0.3)
ax.set_xlabel("RA [deg]", fontsize=15)
ax.set_ylabel("Dec [deg]", fontsize=15)
ax.set_xlim([0, 360])
ax.set_ylim([-30, 90]);

# %% [markdown]
# ### Generate an ALeRCE Explorer link for the first 200 objects (maximum accepted by the interface)

# %%
def print_link(index=None, classifier="stamp_classifier"):
    if len(index) == 1:
        expr = "https://alerce.online/object/" + index[0]
    else:
        expr1 = "https://alerce.online/?oid="
        expr2 = "&oid=".join(list(index))
        expr3 = "&selectedClassifier=" + classifier + "&page=1"
        expr = expr1 + expr2 + expr3
    
    display(HTML("<a href='%s' target=\"_blank\"> %s <a>" % (expr, expr)))

# %%
index = query_results["oid"].iloc[0:200].tolist()
print_link(index=index)
# Out:
# <a href='https://alerce.online/?oid=ZTF25abioriw&oid=ZTF25abckwuq&oid=ZTF25aavdmzf&oid=ZTF25aakbqpl&oid=ZTF25aaxnchn&oid=ZTF25aajcusp&oid=ZTF25ablmtlg&oid=ZTF25aalsxks&oid=ZTF25aaxjntk&oid=ZTF25aarxine&oid=ZTF25aapjruy&oid=ZTF25aakbssn&oid=ZTF25aahrlwa&oid=ZTF25aaoefsh&oid=ZTF25abllldx&oid=ZTF25aaxeojh&oid=ZTF25abieqtz&oid=ZTF25abadtsx&oid=ZTF25abiwxpf&oid=ZTF25abogvjf&oid=ZTF25aascfmn&oid=ZTF25aavhjcz&oid=ZTF25abcfyxt&oid=ZTF25aakrsbo&oid=ZTF25aajrlbu&oid=ZTF25abbwsqe&oid=ZTF25aaqzagd&oid=ZTF25aaortzp&oid=ZTF25abscivt&oid=ZTF25abikaaq&oid=ZTF25aazxxqi&oid=ZTF25abgoqzv&oid=ZTF25aanpulo&oid=ZTF25aanqbbl&oid=ZTF25ablhwja&oid=ZTF25abbshoi&oid=ZTF25absdyqi&oid=ZTF25aapuxul&oid=ZTF25aanxgnn&oid=ZTF25aapjaog&oid=ZTF25aaktazi&oid=ZTF25abceqol&oid=ZTF25aavinas&oid=ZTF25aaxjzzz&oid=ZTF25aapqzzl&oid=ZTF25abghglc&oid=ZTF25abhibmk&oid=ZTF25aaluvkb&oid=ZTF25aauijjd&oid=ZTF25abnqzug&oid=ZTF25aaowtpy&oid=ZTF25abjbwhq&oid=ZTF25abewmjr&oid=ZTF25aaurwnn&oid=ZTF25abjqeok&oid=ZTF25aamrath&oid=ZTF25aanvpit&oid=ZTF25aaucqjp&oid=ZTF25aaoxgwp&oid=ZTF25aavihnr&oid=ZTF18aawrotg&oid=ZTF25aaqoukg&oid=ZTF25abfdjel&oid=ZTF25aapwxhm&oid=ZTF25aboruxa&oid=ZTF25aaptbyd&oid=ZTF25aalocpf&oid=ZTF25aazufyf&oid=ZTF25abmhmbk&oid=ZTF25abqimds&oid=ZTF25abqkiqr&oid=ZTF25abkqros&oid=ZTF25abskhhq&oid=ZTF25absfiyt&oid=ZTF25aapnvqx&oid=ZTF25abqixdv&oid=ZTF25abacyxb&oid=ZTF25aawnphj&oid=ZTF25aatvtvy&oid=ZTF25aaqqcld&oid=ZTF25aayxghj&oid=ZTF25absblvn&oid=ZTF25abpxqho&oid=ZTF25abakvtg&oid=ZTF25aaqiijt&oid=ZTF25aaittqc&oid=ZTF19abkrlew&oid=ZTF25aasctdu&oid=ZTF25abrgeib&oid=ZTF25aankzpg&oid=ZTF25aapxsjb&oid=ZTF25aaizkcc&oid=ZTF19abvhduf&oid=ZTF25aaluens&oid=ZTF25aapwiux&oid=ZTF25abjkphq&oid=ZTF25aboscbc&oid=ZTF25aaoqltj&oid=ZTF25abekolv&oid=ZTF25aaopvlb&oid=ZTF25aavkuxo&oid=ZTF25abqzdbd&oid=ZTF25aapuibm&oid=ZTF25abqxnbr&oid=ZTF25abbofpg&oid=ZTF25aatvqjw&oid=ZTF25ablufrt&oid=ZTF25aaxbmmx&oid=ZTF18aasrlze&oid=ZTF25aaugkzj&oid=ZTF25aawurka&oid=ZTF25aayxsry&oid=ZTF25abtsusb&oid=ZTF25ablvccx&oid=ZTF25aawebdp&oid=ZTF25aaqvyht&oid=ZTF25aatnwif&oid=ZTF25aarxlrd&oid=ZTF25aavczxs&oid=ZTF25aatoqiw&oid=ZTF25aayyxoc&oid=ZTF25aajsaas&oid=ZTF25aakhihh&oid=ZTF25abrmciv&oid=ZTF25aaqzixq&oid=ZTF25abpkect&oid=ZTF25abansec&oid=ZTF25abaefwo&oid=ZTF25aaqfhvh&oid=ZTF25aanwmhr&oid=ZTF25aaqfffi&oid=ZTF25aadgckg&oid=ZTF25aauscfu&oid=ZTF25aaozezq&oid=ZTF25aaprggu&oid=ZTF25aatzejc&oid=ZTF25aafjpdg&oid=ZTF24abtartn&oid=ZTF18aakitiq&oid=ZTF25abjcgdu&oid=ZTF25abkhjln&oid=ZTF25abnnpmt&oid=ZTF25aajffqa&oid=ZTF25aaowwja&oid=ZTF25absejds&oid=ZTF25abpgjdk&oid=ZTF25aargzjz&oid=ZTF23aavneat&oid=ZTF25aarutoh&oid=ZTF25abeehah&oid=ZTF25aaqsuda&oid=ZTF25abidcdj&oid=ZTF25abikugi&oid=ZTF25absfedk&oid=ZTF25aauefrh&oid=ZTF25abhoijc&oid=ZTF25abmhpuo&oid=ZTF25aawscge&oid=ZTF25abeckqg&oid=ZTF25abdglia&oid=ZTF25abhkhny&oid=ZTF25abmxvln&oid=ZTF25aapqvqk&oid=ZTF25abioepd&oid=ZTF25aaohuyd&oid=ZTF25aavpehi&oid=ZTF25abseukx&oid=ZTF23aaritkm&oid=ZTF25abkoomo&oid=ZTF25aareirf&oid=ZTF25aaoxfui&oid=ZTF25aalziig&oid=ZTF25abbsaee&oid=ZTF25aaqostr&oid=ZTF25abofroq&oid=ZTF25abflwya&oid=ZTF25aaskxwm&oid=ZTF25aarwoeg&oid=ZTF25abgpuno&oid=ZTF25aaqylva&oid=ZTF25aalpqkg&oid=ZTF25aaxiwgb&oid=ZTF25aaqwcmq&oid=ZTF25aarsdkv&oid=ZTF25abdzkae&oid=ZTF25aaldcfz&oid=ZTF25abjbclh&oid=ZTF25abcxtvx&oid=ZTF25abhjxpt&oid=ZTF25abbnidh&oid=ZTF25abrfzvc&oid=ZTF25abltwjb&oid=ZTF25abrggxu&oid=ZTF25abhutjc&oid=ZTF25aajitmc&oid=ZTF25aayxhar&oid=ZTF25aajfyro&oid=ZTF25abmtvgm&oid=ZTF25abirwfv&oid=ZTF25aaxdrtc&selectedClassifier=stamp_classifier&page=1' target="_blank"> https://alerce.online/?oid=ZTF25abioriw&oid=ZTF25abckwuq&oid=ZTF25aavdmzf&oid=ZTF25aakbqpl&oid=ZTF25aaxnchn&oid=ZTF25aajcusp&oid=ZTF25ablmtlg&oid=ZTF25aalsxks&oid=ZTF25aaxjntk&oid=ZTF25aarxine&oid=ZTF25aapjruy&oid=ZTF25aakbssn&oid=ZTF25aahrlwa&oid=ZTF25aaoefsh&oid=ZTF25abllldx&oid=ZTF25aaxeojh&oid=ZTF25abieqtz&oid=ZTF25abadtsx&oid=ZTF25abiwxpf&oid=ZTF25abogvjf&oid=ZTF25aascfmn&oid=ZTF25aavhjcz&oid=ZTF25abcfyxt&oid=ZTF25aakrsbo&oid=ZTF25aajrlbu&oid=ZTF25abbwsqe&oid=ZTF25aaqzagd&oid=ZTF25aaortzp&oid=ZTF2 ...

# %% [markdown]
# We can open this link in a browser to continue our exploration :)
