# %% [markdown]
# # ALeRCE basics
#
# ```Author: Alejandra Muñoz-Arancibia. Last updated: 20251015```
#
# Very simple examples on how to interact with the ALeRCE client https://alerce.readthedocs.io/en/latest/index.html, which can be installed with pip. See https://alerce.readthedocs.io/en/latest/apis.html for the API documentation.
#
# For more information about the ALeRCE broker, please visit http://alerce.science/, or read our publications:
# * The Automatic Learning for the Rapid Classification of Events (ALeRCE) Alert Broker, [Förster et al. 2021, AJ, 161, 242](https://arxiv.org/abs/2008.03303)
# * Alert Classification for the ALeRCE Broker System: The Real-time Stamp Classifier, [Carrasco-Davis et al. 2021, AJ, 162, 231](https://arxiv.org/abs/2008.03309)
# * Alert Classification for the ALeRCE Broker System: The Light Curve Classifier, [Sánchez-Sáez et al. 2021, AJ, 161, 141](https://arxiv.org/abs/2008.03311)
#
# *It is highly recommended that you try this notebook in Google Colab using the following [link](https://colab.research.google.com/github/alercebroker/usecases/blob/master/notebooks/SOCHIAS_XX_Oct2025_tutorial/ALeRCE_Basics_SOCHIAS.ipynb).* This will avoid you from having to sort out library installation problems and focus on the contents of the tutorial. You can try installing the dependencies later in your own system.

# %% [markdown]
# Load libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors
from IPython.core.display import HTML

pd.set_option('display.max_colwidth', 1000)
pd.set_option('display.max_columns', None)

# %%
#!pip install alerce

# %%
from alerce.core import Alerce

# %% [markdown]
# # Initialize alerce api object

# %% [markdown]
# Let's start the ALeRCE client

# %%
client = Alerce()

# %% [markdown]
# We will explore different methods from the client:
#
# * Query global properties of an individual object
# * Query properties per band of an individual object
# * Query detections of an individual object
# * Query image stamps
# * Crossmatch with objects in the vicinity
# * Query non detections of an individual object
# * Query features of an individual object
# * Query probabilities of an individual object
# * Query global properties of a group of objects

# %% [markdown]
# # Query properties for an individual object

# %% [markdown]
# We will now query the global properties of one object based on a given object id, ZTF25abansec in this case. You can see this object in the website https://alerce.online/object/ZTF25abansec.

# %%
oid = "ZTF25abansec"
query_results = client.query_objects(
    oid=oid,
    format='pandas'
)
properties = query_results # save for later
query_results
# Out:
#             oid ndethist  ncovhist  mjdstarthist    mjdendhist  corrected  \
# 0  ZTF25abansec       74      5561  58431.171181  60921.178912      False
#
#    stellar  ndet g_r_max g_r_max_corr g_r_mean g_r_mean_corr      firstmjd  \
# 0    False   103    None         None     None          None  60865.260544
#
#         lastmjd    deltajd      meanra    meandec   sigmara  sigmadec class  \
# 0  60921.178912  55.918368  279.675753  37.048353  0.008936  0.007132  None
#
#   classifier probability step_id_corr
# 0       None        None       27.5.6

# %% [markdown]
# The columns are described in here https://alerce.readthedocs.io/en/latest/models.html

# %% [markdown]
# # Query properties per band for an indivual object

# %%
query_results = client.query_magstats(
    oid=oid,
    format='pandas'
)
query_results
# Out:
#    fid  stellar  corrected  ndet  ndubious    magmean  magmedian     magmax  \
# 0    1    False      False    55         0  18.354134  18.210037  19.856400
# 1    2    False      False    48        22  17.498535  17.537512  18.653774
#
#       magmin  magsigma    maglast   magfirst   firstmjd    lastmjd  \
# 0  17.377064  0.731732  19.592247  19.235132  60865.260  60921.180
# 1  16.872883  0.454666  18.653774  18.014395  60867.277  60919.203
#
#   step_id_corr
# 0       27.5.6
# 1       27.5.6

# %% [markdown]
# You can see that the results are different statistics in two rows, one per band. The columns are described in here https://alerce.readthedocs.io/en/latest/models.html

# %% [markdown]
# # Query detections, non-detections and forced photometry epochs for an individual object

# %% [markdown]
# Now we obtain a list of all the detections, non-detections (limiting magnitude) and forced photometry epochs in two bands. Note that ALeRCE started to ingest forced photometry on December 2023, so objects that stopped having detections before that time give an empty dataframe of forced photometry.
#
# Also note that all dataframes include a unique identifier for the telescope (`tid`), which hints at the multi-stream nature of ALeRCE (soon to be available).

# %%
obj_dets = client.query_detections(oid, format='pandas')
obj_dets = obj_dets.sort_values("mjd")

obj_nondets = client.query_non_detections(oid, format='pandas')
obj_nondets = obj_nondets.sort_values("mjd")

obj_fp = client.query_forced_photometry(oid, format='pandas')
if len(obj_fp) > 0:
    obj_fp = obj_fp.sort_values("mjd")

# %% [markdown]
# Note that when LSST starts its public stream, we will use an updated ALeRCE client version. The queries will change a little:

# %%
## Uncomment the following lines after the LSST stream starts
## Will work for an updated ALeRCE client version

#obj_dets = client.query_detections(oid, survey='ztf', format='pandas')
#obj_dets = obj_dets.sort_values("mjd")
#
#obj_nondets = client.query_non_detections(oid, survey='ztf', format='pandas')
#obj_nondets = obj_nondets.sort_values("mjd")
#
#obj_fp = client.query_forced_photometry(oid, survey='ztf', format='pandas')
#if len(obj_fp) > 0:
#    obj_fp = obj_fp.sort_values("mjd")

# %% [markdown]
# Let's see the contents of these tables

# %%
display(obj_dets)
# Out:
#      tid           mjd               candid  fid            pid  diffmaglim  \
# 0    ztf  60865.260544  3111260546015015001    1  3111260546015   19.906770
# 1    ztf  60867.276863  3113276860715015009    2  3113276860715   20.050188
# 2    ztf  60867.276863  3113276860715025009    2  3113276860715   20.050200
# 3    ztf  60867.277407  3113277406015015000    2  3113277406015   20.038403
# 4    ztf  60867.343819  3113343816015015000    1  3113343816015   19.749186
# ..   ...           ...                  ...  ...            ...         ...
# 98   ztf  60910.305023  3156305026015015001    2  3156305026015   20.311400
# 99   ztf  60914.210845  3160210846015015000    2  3160210846015   20.781937
# 100  ztf  60917.211076  3163211076015015001    2  3163211076015   20.566599
# 101  ztf  60919.201447  3165201446015015000    2  3165201446015   20.537264
# 102  ztf  60921.178912  3167178916015015000    1  3167178916015   20.279613
#
#      isdiffpos   nid    distnr     magpsf    magap  sigmapsf  sigmagap  \
# 0            1  3111  2.240241  19.235132  18.9577  0.132558    0.1764
# 1            1  3113  2.507732  18.014395  18.1461  0.080080    0.0849
# 2            1  3113  2.507730  18.014400  18.1461  0.080080    0.0849
# 3            1  3113  1.328118  18.011831  18.1406  0.067473    0.0900
# 4            1  3113  2.123990  18.519320  18.5784  0.103419    0.1403
# ..         ...   ...       ...        ...      ...       ...       ...
# 98           1  3156  1.337920  18.267700  18.1283  0.087084    0.0801
# 99           1  3160  1.281801  18.501610  18.6862  0.101026    0.1081
# 100          1  3163  1.443469  18.570757  18.9032  0.125715    0.1421
# 101          1  3165  1.478121  18.653774  18.8601  0.112439    0.1373
# 102          1  3167  2.182836  19.592247  19.5602  0.184315    0.2400
#
#              ra        dec        rb  rbversion       drb  magapbig  \
# 0    279.675715  37.048398  0.772857  t17_f5_c3  0.999124   18.8737
# 1    279.675737  37.048378  0.714286  t17_f5_c3  0.999665   18.0617
# 2    279.675737  37.048378  0.714286  t17_f5_c3       NaN   18.0617
# 3    279.675754  37.048362  0.768571  t17_f5_c3  0.996253   18.2142
# 4    279.675769  37.048336  0.914286  t17_f5_c3  0.996875   18.6589
# ..          ...        ...       ...        ...       ...       ...
# 98   279.675761  37.048353  0.697143  t17_f5_c3       NaN   18.0568
# 99   279.675741  37.048366  0.761429  t17_f5_c3  0.955733   18.6267
# 100  279.675796  37.048335  0.617143  t17_f5_c3  0.962248   18.8605
# 101  279.675806  37.048345  0.751429  t17_f5_c3  0.977683   18.9180
# 102  279.675887  37.048281  0.645714  t17_f5_c3  0.974034   19.3639
#
#      sigmagapbig         rfid  has_stamp  corrected  dubious step_id_corr  \
# 0         0.2058  684120160.0       True      False    False       27.5.6
# 1         0.0961  726120207.0       True      False    False       27.5.6
# 2         0.0961          NaN      False      False    False       27.5.6
# 3         0.1178  684120260.0       True       True     True       27.5.6
# 4         0.1910  684120160.0       True      False    False       27.5.6
# ..           ...          ...        ...        ...      ...          ...
# 98        0.0895          NaN      False       True     True       27.5.6
# 99        0.1195  684120260.0       True       True     True       27.5.6
# 100       0.1622  684120260.0       True      False    False       27.5.6
# 101       0.1719  684120260.0       True      False    False       27.5.6
# 102       0.2500  684120160.0       True      False    False       27.5.6
#
#      phase  parent_candid  magpsf_corr  sigmapsf_corr  sigmapsf_corr_ext
# 0      0.0            NaN          NaN            NaN                NaN
# 1      0.0            NaN          NaN            NaN                NaN
# 2      0.0   3.143237e+18          NaN            NaN                NaN
# 3      0.0            NaN    16.818190          100.0           0.022474
# 4      0.0            NaN          NaN            NaN                NaN
# ..     ...            ...          ...            ...                ...
# 98     0.0   3.167179e+18    16.896902          100.0           0.024639
# 99     0.0            NaN    16.958134          100.0           0.024380
# 100    0.0            NaN          NaN            NaN                NaN
# 101    0.0            NaN          NaN            NaN                NaN
# 102    0.0            NaN          NaN            NaN                NaN
#
# [103 rows x 30 columns]

# %%
display(obj_nondets)
# Out:
#     tid           mjd  fid  diffmaglim
# 0   ztf  60836.359734    2     19.8631
# 1   ztf  60836.429792    1     19.6831
# 2   ztf  60838.357593    2     19.9399
# 3   ztf  60838.378773    2     19.2741
# 4   ztf  60838.422535    1     19.7213
# ..  ...           ...  ...         ...
# 70  ztf  60917.268819    1     20.6443
# 71  ztf  60919.163183    1     20.2628
# 72  ztf  60919.200486    2     20.4268
# 73  ztf  60919.312465    1     20.3748
# 74  ztf  60921.156134    2     20.2688
#
# [75 rows x 4 columns]

# %%
display(obj_fp)
# Out:
#                        candid  tid            pid           oid           mjd  \
# 82  ZTF25abansec3084378776015  ztf  3084378776015  ZTF25abansec  60838.378773
# 71  ZTF25abansec3084423000715  ztf  3084423000715  ZTF25abansec  60838.423009
# 65  ZTF25abansec3086241330715  ztf  3086241330715  ZTF25abansec  60840.241331
# 83  ZTF25abansec3086341850715  ztf  3086341850715  ZTF25abansec  60840.341852
# 72  ZTF25abansec3089264100715  ztf  3089264100715  ZTF25abansec  60843.264109
# ..                        ...  ...            ...           ...           ...
# 27  ZTF25abansec3151375266015  ztf  3151375266015  ZTF25abansec  60905.375266
# 26  ZTF25abansec3154224210715  ztf  3154224210715  ZTF25abansec  60908.224213
# 25  ZTF25abansec3156217970715  ztf  3156217970715  ZTF25abansec  60910.217974
# 24  ZTF25abansec3160282216015  ztf  3160282216015  ZTF25abansec  60914.282211
# 28  ZTF25abansec3165312466015  ztf  3165312466015  ZTF25abansec  60919.312465
#
#     fid          ra  e_ra        dec e_dec        mag     e_mag   mag_corr  \
# 82    2  279.675715  None  37.048398  None  22.922562  4.360516  17.252128
# 71    1  279.675758  None  37.048350  None  21.734627  0.915500        NaN
# 65    1  279.675751  None  37.048368  None  23.203648  2.094131        NaN
# 83    2  279.675751  None  37.048368  None  21.966974  0.707477        NaN
# 72    2  279.675751  None  37.048365  None  21.645630  0.385192        NaN
# ..  ...         ...   ...        ...   ...        ...       ...        ...
# 27    1  279.675887  None  37.048281  None  19.523758  0.075878        NaN
# 26    2  279.675887  None  37.048281  None  18.232244  0.023036        NaN
# 25    1  279.675887  None  37.048281  None  19.794607  0.066866        NaN
# 24    1  279.675887  None  37.048281  None  20.175356  0.120060        NaN
# 28    1  279.675887  None  37.048281  None  19.955091  0.109325        NaN
#
#     e_mag_corr  e_mag_corr_ext  isdiffpos  corrected  dubious  \
# 82       100.0        0.023516          1       True    False
# 71         NaN             NaN         -1      False     True
# 65         NaN             NaN          1      False    False
# 83         NaN             NaN          1      False    False
# 72         NaN             NaN         -1      False     True
# ..         ...             ...        ...        ...      ...
# 27         NaN             NaN          1      False    False
# 26         NaN             NaN          1      False    False
# 25         NaN             NaN          1      False    False
# 24         NaN             NaN          1      False    False
# 28         NaN             NaN          1      False    False
#
#           parent_candid  has_stamp   scibckgnd  exptime      magnr  scisigpix  \
# 82  3111260546015015001      False  136.873001     30.0  17.257999   13.82780
# 71  3113344300715015013      False   94.219704     30.0  18.395000   13.86800
# 65  3115280310715015006      False   92.709602     30.0  18.395000    8.97642
# 83  3115280310715015006      False  311.173004     30.0  17.909000    9.32023
# 72  3119239970715015019      False  316.683990     30.0  17.909000    7.30467
# ..                  ...        ...         ...      ...        ...        ...
# 27  3167178916015015000      False   84.992401     30.0  18.582001    6.84649
# 26  3167178916015015000      False  306.989014     30.0  17.909000    6.26543
# 25  3167178916015015000      False   89.106003     30.0  18.395000    6.38985
# 24  3167178916015015000      False   87.157600     30.0  18.582001    6.01272
# 28  3167178916015015000      False   81.696297     30.0  18.582001    6.65440
#
#     adpctdif1  sigmagnr   magzpsci  adpctdif2  chinr  diffmaglim  programid  \
# 82   0.058403     0.109  25.966700   0.075399  6.787   19.274099          1
# 71   0.052569     0.083  26.320200   0.067838  6.419   19.623301          1
# 65   0.051883     0.083  26.299601   0.062555  6.419   20.173300          1
# 83   0.057341     0.102  26.253799   0.070704  5.790   20.237000          1
# 72   0.049480     0.102  26.265400   0.064952  5.790   20.486601          1
# ..        ...       ...        ...        ...    ...         ...        ...
# 27   0.066706     0.084  26.124100   0.069765  4.796   20.417000          1
# 26   0.051244     0.102  26.252899   0.068209  5.790   20.507200          1
# 25   0.047296     0.083  26.251900   0.061236  6.419   20.695400          1
# 24   0.057964     0.084  26.176100   0.066045  4.796   20.573200          1
# 28   0.056313     0.084  26.093901   0.069645  4.796   20.374800          1
#
#     sharpnr  field   magzpsciunc procstatus  rcid  magzpscirms    distnr  \
# 82    0.549    684  2.503800e-06          0    60     0.021481  1.225562
# 71    0.263    726  2.544200e-06          0     7     0.020545  2.229136
# 65    0.263    726  1.853700e-06          0     7     0.017506  2.207147
# 83    0.225    726  1.565900e-06          0     7     0.016207  3.772682
# 72    0.225    726  9.523000e-07          0     7     0.012586  3.776947
# ..      ...    ...           ...        ...   ...          ...       ...
# 27    0.248    684  2.284800e-06          0    60     0.020907  3.027458
# 26    0.225    726  9.553000e-07          0     7     0.012652  3.519523
# 25    0.263    726  1.590700e-06          0     7     0.016444  2.620558
# 24    0.248    684  2.052400e-06          0    60     0.019502  3.027458
# 28    0.248    684  2.130500e-06          0    60     0.020225  3.027458
#
#          rfid  clrcoeff        ranr  sciinpseeing  clrcounc      decnr
# 82  684120260  0.075347  279.675293        2.2839  0.000008  37.048374
# 71  726120107 -0.057361  279.674988        2.2499  0.000009  37.048378
# 65  726120107 -0.070433  279.674988        2.1203  0.000006  37.048378
# 83  726120207  0.074709  279.677002        1.4884  0.000005  37.048683
# 72  726120207  0.073921  279.677002        1.9122  0.000003  37.048683
# ..        ...       ...         ...           ...       ...        ...
# 27  684120160 -0.030109  279.674866        2.0240  0.000008  37.048519
# 26  726120207  0.071473  279.677002        2.1124  0.000003  37.048683
# 25  726120107 -0.054785  279.674988        1.8167  0.000005  37.048378
# 24  684120160 -0.055684  279.674866        2.1247  0.000007  37.048519
# 28  684120160 -0.034428  279.674866        2.1191  0.000007  37.048519
#
# [84 rows x 44 columns]

# %% [markdown]
# The most important columns for the detections are the time (`mjd`), the unique detection identifier (`candid`), the band (`fid`), the difference magnitude (`magpsf`) and its error (`sigmapsf`). For forced photometry epochs, the difference magnitude and its error are `mag`) and `e_mag` respectively.
#
# The columns for the non-detections are the time (`mjd`), the band (`fid`), and the limiting magnitude (`diffmaglim`).
#
# All the columns are described in here https://alerce.readthedocs.io/en/latest/models.html.

# %% [markdown]
# We can now plot the light curve for this object

# %%
def plot_lc(oid, obj_dets, obj_nondets, obj_fp):
    fig, ax = plt.subplots(figsize = (10, 4))
    labels = {1: 'g', 2: 'r', 3: 'i'}
    markers = {1: 'o', 2: 's', 3: 'x'}
    sizes = {1: 20, 2: 30, 3: 25}

    # Color blind friendly green and red 
    colors = {1: '#56E03A', 2: '#D42F4B'} 
    
    for fid in [1, 2]:
        mask = obj_dets["fid"] == fid
        if np.sum(mask) > 0:
            ax.errorbar(obj_dets[mask]["mjd"], obj_dets[mask]["magpsf"],
                        yerr=obj_dets[mask]["sigmapsf"], c=colors[fid],
                        label=labels[fid], marker=markers[fid],
                        linestyle='None')
        
        mask = (obj_nondets["fid"] == fid) & (obj_nondets["diffmaglim"] > -900)
        if np.sum(mask) > 0:     
            ax.scatter(obj_nondets[mask]["mjd"], obj_nondets[mask]["diffmaglim"],
                       c=colors[fid], alpha=0.5, marker='v',
                       label="lim. mag. %s" % labels[fid], s=sizes[fid])

        if len(obj_fp) == 0:
            continue
        mask = (obj_fp["fid"] == fid) \
               & (obj_fp["mag"] / obj_fp["e_mag"] >= 3) \
               & (obj_fp["e_mag"] < 1.)
        if np.sum(mask) > 0:
            ax.errorbar(obj_fp[mask]["mjd"], obj_fp[mask]["mag"], 
                        yerr=obj_fp[mask]["e_mag"], c=colors[fid], marker=markers[fid],
                        alpha=0.5, label="forced phot. %s" % labels[fid],
                        linestyle='None')
            
    ax.set_title(oid, fontsize=15)
    ax.set_xlabel("MJD", fontsize=15)
    ax.set_ylabel("Difference magnitude", fontsize=15)
    ax.legend()
    ax.set_ylim(ax.get_ylim()[::-1])

# %%
plot_lc(oid, obj_dets, obj_nondets, obj_fp)

# %% [markdown]
# # Query image stamps
#
# We can also query the image stamps associated to a specific object and candid.

# %% [markdown]
# We will use the first candid from the previously queried detections.

# %%
stamps = client.get_stamps(oid, obj_dets.iloc[0]["candid"])
print(stamps)
# Out:
# [<astropy.io.fits.hdu.image.PrimaryHDU object at 0x7fc20ec2c110>, <astropy.io.fits.hdu.image.ImageHDU object at 0x7fc20f8b1890>, <astropy.io.fits.hdu.image.ImageHDU object at 0x7fc20e8ecb50>]
# WARNING: VerifyWarning: Keyword name 'STAMP_TYPE' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]

# %% [markdown]
# The image stamps are a triplet of science, reference and difference images. Let's look at the first image:

# %%
fig, ax = plt.subplots(ncols=3)
for i in range(3):
    ax[i].imshow(stamps[i].data)

# %% [markdown]
# We can also directly plot the images stamps using the plot_stamps command.

# %%
client.plot_stamps(oid, obj_dets.iloc[0]["candid"])
# Out:
#         <div>ZTF oid: ZTF25abansec, candid: 3111260546015015001</div>
#         <div>&emsp;&emsp;&emsp;&emsp;&emsp;
#         Science
#         &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;
#         Template
#         &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;
#         Difference
#         <div class="container">
#         <div style="float:left;width:20%"><img src="https://avro.alerce.online/get_stamp?oid=ZTF25abansec&candid=3111260546015015001&type=science&format=png"></div>
#         <div style="float:left;width:20%"><img src="https://avro.alerce.online/get_stamp?oid=ZTF25abansec&candid=3111260546015015001&type=template&format=png"></div>
#         <div style="float:left;width:20%"><img src="https://avro.alerce.online/get_stamp?oid=ZTF25abansec&candid=3111260546015015001&type=difference&format=png"></div>
#         </div>

# %% [markdown]
# And when LSST starts, these queries will be:

# %%
## Uncomment the following lines after the LSST stream starts
## Will work for an updated ALeRCE client version

#stamps = client.get_stamps(oid, obj_dets.iloc[0]["candid"], survey='ztf')
#
#client.plot_stamps(oid, obj_dets.iloc[0]["candid"], survey='ztf')

# %% [markdown]
# # Query probabilities for an individual object

# %% [markdown]
# Similarly, we can query the classification probabilities for a given object.
#
# Note that an object can be classified by different classifiers with different versions, which is shown in the columns `classifier_name` and `classifier_version`, respectively.

# %%
oid
# Out:
# 'ZTF25abansec'

# %%
query_results = client.query_probabilities(
    oid=oid,
    format='pandas'
)
query_results
# Out:
#                               classifier_name    classifier_version  \
# 0                               lc_classifier  lc_classifier_1.1.13
# 1        LC_classifier_ATAT_forced_phot(beta)                 1.0.0
# 2              lc_classifier_BHRF_forced_phot                 2.1.0
# 3     lc_classifier_BHRF_forced_phot_periodic                 2.1.0
# 4   lc_classifier_BHRF_forced_phot_stochastic                 2.1.0
# ..                                        ...                   ...
# 87       LC_classifier_ATAT_forced_phot(beta)                 1.0.0
# 88             lc_classifier_BHRF_forced_phot                 2.1.0
# 89       LC_classifier_ATAT_forced_phot(beta)                 1.0.0
# 90             lc_classifier_BHRF_forced_phot                 2.1.0
# 91       LC_classifier_ATAT_forced_phot(beta)                 1.0.0
#
#       class_name   probability  ranking
# 0           SNIa  3.418440e-01        1
# 1           SNIa  3.714632e-01        2
# 2           SNIa  5.788400e-01        1
# 3            LPV  1.000000e-01        6
# 4   Microlensing  2.000000e-01        2
# ..           ...           ...      ...
# 87         RRLab  7.050051e-08       10
# 88          RRLc  0.000000e+00       19
# 89          RRLc  5.381826e-10       17
# 90          DSCT  0.000000e+00       13
# 91          DSCT  1.152314e-10       18
#
# [92 rows x 5 columns]

# %% [markdown]
# We see that we get many rows for a single object. This shows all the probabilities associated to all the ALeRCE classifiers and the classes in their associated taxonomies. The columns indicate the name of the classifier (`classifier_name`), its version (`classifier_version`), the class (`class_name`), the probability (`probability`) and the ranking (`ranking`) growing from most to least likely.

# %% [markdown]
# Let's check the unique classifier versions associated to each classifier:

# %%
for clf in query_results.classifier_name.unique():
    mask = query_results.classifier_name == clf
    print(clf, query_results.loc[mask].classifier_version.unique())
# Out:
# lc_classifier ['lc_classifier_1.1.13']
# LC_classifier_ATAT_forced_phot(beta) ['1.0.0']
# lc_classifier_BHRF_forced_phot ['2.1.0']
# lc_classifier_BHRF_forced_phot_periodic ['2.1.0']
# lc_classifier_BHRF_forced_phot_stochastic ['2.1.0']
# lc_classifier_BHRF_forced_phot_top ['2.1.0']
# lc_classifier_BHRF_forced_phot_transient ['2.1.0']
# stamp_classifier ['stamp_classifier_1.0.4']
# stamp_classifier_2025_beta ['2.1.1_beta']

# %% [markdown]
# And now the unique classes associated to each classifier:

# %%
for clf in query_results.classifier_name.unique():
    mask = query_results.classifier_name == clf
    print(clf + ':')
    print(query_results.loc[mask].class_name.unique())
    print('')
# Out:
# lc_classifier:
# ['SNIa' 'SNIbc' 'SNII' 'SLSN' 'QSO' 'AGN' 'Blazar' 'CV/Nova' 'YSO' 'LPV'
#  'E' 'DSCT' 'RRL' 'CEP' 'Periodic-Other']
#
# LC_classifier_ATAT_forced_phot(beta):
# ['SNIa' 'SNIbc' 'SNII' 'SNIIn' 'SLSN' 'TDE' 'Microlensing' 'QSO' 'AGN'
#  'Blazar' 'YSO' 'CV/Nova' 'LPV' 'EA' 'EB/EW' 'Periodic-Other' 'RSCVn'
#  'CEP' 'RRLab' 'RRLc' 'DSCT']
#
# lc_classifier_BHRF_forced_phot:
# ['SNIa' 'SESN' 'SNII' 'SNIIn' 'SLSN' 'TDE' 'Microlensing' 'QSO' 'AGN'
#  'Blazar' 'YSO' 'CV/Nova' 'LPV' 'EA' 'EB/EW' 'Periodic-Other' 'RSCVn'
#  'CEP' 'RRLab' 'RRLc' 'DSCT']
#
# lc_classifier_BHRF_forced_phot_periodic:
# ['LPV' 'EA' 'EB/EW' 'Periodic-Other' 'RSCVn' 'CEP' 'RRLab' 'RRLc' 'DSCT']
#
# lc_classifier_BHRF_forced_phot_stochastic:
# ['Microlensing' 'QSO' 'AGN' 'Blazar' 'YSO' 'CV/Nova']
#
# lc_classifier_BHRF_forced_phot_top:
# ['Transient' 'Stochastic' 'Periodic']
#
# lc_classifier_BHRF_forced_phot_transient:
# ['SNIa' 'SESN' 'SNII' 'SNIIn' 'SLSN' 'TDE']
#
# stamp_classifier:
# ['SN' 'AGN' 'VS' 'asteroid' 'bogus']
#
# stamp_classifier_2025_beta:
# ['SN' 'AGN' 'VS' 'asteroid' 'bogus' 'satellite']

# %% [markdown]
# The classifiers are two classifiers, the `lc_classifier` and the `stamp_classifier`, where `lc_classifier` is a hierarchical classifier composed of four independent classifiers: `lc_classifier_top`, `lc_classifier_periodic`, `lc_classifier_stochastic`, and `lc_classifier_transient`. You can see more details about `lc_classifier` in [Sánchez-Sáez+2021](https://ui.adsabs.harvard.edu/abs/2021AJ....161..141S/abstract) and about `stamp_classifier` in [Carrasco-Davis+2021](https://ui.adsabs.harvard.edu/abs/2020arXiv200803309C/abstract). Details about `lc_classifier_BHRF_forced_phot` will appear in Cabrera-Vives et al. (in preparation).

# %% [markdown]
# # Query global properties of a set of objects

# %% [markdown]
# ## Query objects based on the most likely class

# %% [markdown]
# We will query the top 200 objects classified SNIa according to the light curve classifier. In here we ask for the top 200 objects in pandas format. By default this query asks for objects with classification `ranking=1`. We will ask for the results to be ordered by probability in descending order (`DESC`).

# %%
query_results = client.query_objects(
    classifier="lc_classifier",
    class_name="SNIa",
    page_size=200,
    order_by='probability',
    order_mode='DESC',
    format='pandas')

# %%
query_results
# Out:
#               oid ndethist  ncovhist  mjdstarthist    mjdendhist  corrected  \
# 0    ZTF20acobvxk      102       502  59149.448125  59204.198831      False
# 1    ZTF22aalpfln       59      2921  59724.250000  59766.250000      False
# 2    ZTF21abuyhau       53      2702  59448.184097  59478.194873      False
# 3    ZTF21abywdxt       44      1171  59464.267917  59502.204410      False
# 4    ZTF22abqdmwt       28       699  59877.250000  59932.250000      False
# ..            ...      ...       ...           ...           ...        ...
# 195  ZTF21aaufthj       27       659  59313.207350  59361.195984      False
# 196  ZTF21aarmkuj       35      1237  59306.233287  59350.217257      False
# 197  ZTF20abgfvav       44      1264  59019.234178  59063.179873      False
# 198  ZTF20abewogd       57       293  59013.243611  59075.306400      False
# 199  ZTF20aairvsi      106      1139  58873.195289  58915.143796      False
#
#      stellar  ndet   g_r_max  g_r_max_corr  g_r_mean  g_r_mean_corr  \
# 0      False    37 -0.185314      0.588599  0.071720       0.685924
# 1      False    28 -0.179750           NaN  0.170184            NaN
# 2      False    28 -0.180090      0.486082 -0.071212       1.191339
# 3      False    27 -0.098903           NaN  0.024772            NaN
# 4      False    21 -0.086032           NaN  0.009395            NaN
# ..       ...   ...       ...           ...       ...            ...
# 195    False    28 -0.013462           NaN  0.150079            NaN
# 196    False    35 -0.110087           NaN  0.099922            NaN
# 197    False    44 -0.008980           NaN  0.098345            NaN
# 198    False    57 -0.022940           NaN -0.043098            NaN
# 199    False    33 -0.161451           NaN -0.054895            NaN
#
#          firstmjd       lastmjd    deltajd      meanra    meandec   sigmara  \
# 0    59149.448125  59204.198831  54.750706   37.673533 -14.569121  0.000080
# 1    59724.349155  59766.241782  41.892627  224.503742  49.953109  0.000049
# 2    59450.163947  59478.194873  28.030926  244.075462  37.636849  0.000064
# 3    59465.196944  59502.204410  37.007465  326.503610  21.962614  0.000025
# 4    59878.310451  59932.210451  53.900000   28.288162 -14.140191  0.000040
# ..            ...           ...        ...         ...        ...       ...
# 195  59313.207350  59361.195984  47.988634  151.805684  14.773050  0.000036
# 196  59306.233287  59350.217257  43.983970  136.109002   8.012789  0.000021
# 197  59019.234178  59063.179873  43.945695  226.922647  32.009601  0.000034
# 198  59013.243611  59075.306400  62.062789  312.095377  83.077586  0.000341
# 199  58873.195289  58915.143796  41.948507  108.453967  35.836392  0.000035
#
#      sigmadec class     classifier  probability      step_id_corr
# 0    0.000059  SNIa  lc_classifier     0.722000   corr_bulk_0.0.1
# 1    0.000022  SNIa  lc_classifier     0.722000               dev
# 2    0.000032  SNIa  lc_classifier     0.720000  correction_1.0.6
# 3    0.000023  SNIa  lc_classifier     0.716564  correction_1.0.6
# 4    0.000052  SNIa  lc_classifier     0.714568             1.1.6
# ..        ...   ...            ...          ...               ...
# 195  0.000027  SNIa  lc_classifier     0.636000  correction_0.0.1
# 196  0.000015  SNIa  lc_classifier     0.636000  correction_0.0.1
# 197  0.000020  SNIa  lc_classifier     0.636000   corr_bulk_0.0.1
# 198  0.000026  SNIa  lc_classifier     0.636000   corr_bulk_0.0.1
# 199  0.000043  SNIa  lc_classifier     0.636000   corr_bulk_0.0.1
#
# [200 rows x 23 columns]

# %% [markdown]
# Note that now the columns `class`, `classifier`, and `probability` are included.

# %% [markdown]
# And for LSST, this becomes:

# %%
## Uncomment the following lines after the LSST stream starts
## Will work for an updated ALeRCE client version

#query_results = client.query_objects(
#    classifier="lc_classifier",
#    class_name="SNIa",
#    page_size=200,
#    order_by='probability',
#    order_mode='DESC',
#    survey='ztf',
#    format='pandas')

# %% [markdown]
# ## Query objects by classified ranking

# %% [markdown]
# When an object is classified by our classifiers, a `ranking` column is available to quickly extract the most likely class (`ranking=1`). Note that not asking for a ranking is equivalent to asking for `ranking=1` (the most likely class).

# %%
fig, ax = plt.subplots()
query_results = client.query_objects(
    classifier="lc_classifier",
    class_name="SNIa",
    ranking=1,
    page_size=200,
    order_by='probability',
    order_mode='DESC',
    format='pandas')
query_results.probability.plot.hist(bins=20, ax=ax, lw=1, log=True,
                                    histtype='step', label='ranking=1')

ax.set_xlabel("probability");

# %% [markdown]
# # Let's now generate a link to look at all the previous objects

# %%
def print_link(index=None, classifier='stamp_classifier'):
    if len(index) == 1:
        expr = 'https://alerce.online/object/' + index[0]
    else:
        expr1 = 'https://alerce.online/?oid='
        expr2 = '&oid='.join(list(index))
        expr3 = '&selectedClassifier=' + classifier + '&page=1'
        expr = expr1 + expr2 + expr3
    
    display(HTML("<a href='%s' target=\"_blank\"> %s <a>" % (expr, expr)))

# %%
print_link(index=query_results["oid"].iloc[0:200], classifier='stamp_classifier')
# Out:
# <a href='https://alerce.online/?oid=ZTF20acobvxk&oid=ZTF22aalpfln&oid=ZTF21abuyhau&oid=ZTF21abywdxt&oid=ZTF22abqdmwt&oid=ZTF23abcegjv&oid=ZTF21abufayv&oid=ZTF21achqzub&oid=ZTF22abnemvx&oid=ZTF20acoqlav&oid=ZTF23aaedsfn&oid=ZTF19aavounq&oid=ZTF23aapogvn&oid=ZTF22abhuvug&oid=ZTF19aclljyq&oid=ZTF19abahvdh&oid=ZTF21abrmefg&oid=ZTF21abaaipx&oid=ZTF20acgznau&oid=ZTF22aboisvs&oid=ZTF20aaljgcp&oid=ZTF23abfroaw&oid=ZTF20aakbtyz&oid=ZTF23abbjstt&oid=ZTF21abhtaiv&oid=ZTF22abhodtl&oid=ZTF21abbzcxe&oid=ZTF23abetodb&oid=ZTF22abitewv&oid=ZTF20acynaba&oid=ZTF20abisvtr&oid=ZTF23aaoxngr&oid=ZTF21abflmkk&oid=ZTF21abbytmm&oid=ZTF20aazsyvu&oid=ZTF23abijnsm&oid=ZTF21abjeyoh&oid=ZTF21aapfowm&oid=ZTF23abgspys&oid=ZTF21abrhggj&oid=ZTF21abcouxj&oid=ZTF20aahptds&oid=ZTF22abgteub&oid=ZTF18aazjztm&oid=ZTF22abizgac&oid=ZTF21abjtqyq&oid=ZTF23abegkob&oid=ZTF20accsfkt&oid=ZTF19achejoc&oid=ZTF21abwfnru&oid=ZTF21abwurky&oid=ZTF22aawodgn&oid=ZTF20acpxvez&oid=ZTF23abjwegr&oid=ZTF22abdstgi&oid=ZTF18aatjfoe&oid=ZTF19abakjao&oid=ZTF23aakawpn&oid=ZTF21aahargb&oid=ZTF21aaqafcf&oid=ZTF20acoaqpm&oid=ZTF20acnzcmp&oid=ZTF23abjyjpb&oid=ZTF22aambnsg&oid=ZTF21abasxdp&oid=ZTF20actpatx&oid=ZTF20abatfzl&oid=ZTF23aakcszy&oid=ZTF22abhxptt&oid=ZTF23aaqpbhu&oid=ZTF22abfvshc&oid=ZTF20aamgdkb&oid=ZTF20aaeopvv&oid=ZTF23aaotvsl&oid=ZTF18abfchzq&oid=ZTF22abyuxlq&oid=ZTF20acwxbyr&oid=ZTF20abkacis&oid=ZTF20abcsbux&oid=ZTF23abjaule&oid=ZTF22aamfvrs&oid=ZTF21aaqzkhx&oid=ZTF20acbovrt&oid=ZTF20abeeytg&oid=ZTF19aazlsfj&oid=ZTF22abkaaje&oid=ZTF21abubxmc&oid=ZTF20acuoclk&oid=ZTF21abegynu&oid=ZTF21aarcldd&oid=ZTF21aahvuvi&oid=ZTF20acpumut&oid=ZTF20abndzyc&oid=ZTF19abowcic&oid=ZTF19aaripqw&oid=ZTF23abgbytx&oid=ZTF22aaoelte&oid=ZTF22aakndny&oid=ZTF22abivrnq&oid=ZTF21aaoqcnh&oid=ZTF21aaxgzln&oid=ZTF20acwmpsj&oid=ZTF20actvpyc&oid=ZTF20abupbub&oid=ZTF20aaxxepr&oid=ZTF19abhzewi&oid=ZTF19aanfyey&oid=ZTF23abjhvzr&oid=ZTF22aaonqcc&oid=ZTF23aapphlk&oid=ZTF21aaqvmix&oid=ZTF21aagolqa&oid=ZTF20acovrzx&oid=ZTF20aaglivt&oid=ZTF19aazzpje&oid=ZTF18aawmeiw&oid=ZTF22abjeeqt&oid=ZTF23aatorzk&oid=ZTF22abeigxz&oid=ZTF21abfnjya&oid=ZTF21abbjybk&oid=ZTF21aavqwhh&oid=ZTF20abzjads&oid=ZTF19abjarhj&oid=ZTF19aavorpa&oid=ZTF23aajscgu&oid=ZTF23aaelkos&oid=ZTF21abvhxyk&oid=ZTF21aaxkckg&oid=ZTF20acnigox&oid=ZTF20acjhhqx&oid=ZTF20aamdqiz&oid=ZTF19acbswdq&oid=ZTF22abjpcjy&oid=ZTF22aajrjrc&oid=ZTF18aarikzk&oid=ZTF22abmxzxm&oid=ZTF22aazjgoi&oid=ZTF20abjcuep&oid=ZTF22aawtunt&oid=ZTF21aaujuqq&oid=ZTF21aasaxdk&oid=ZTF21aagxmcs&oid=ZTF20acpkzxq&oid=ZTF22abeskuc&oid=ZTF22abqiyik&oid=ZTF21abvfacx&oid=ZTF21abcgxwy&oid=ZTF21aarwlht&oid=ZTF19abxdnhr&oid=ZTF19aaozplq&oid=ZTF22aayrxbb&oid=ZTF21abkavmp&oid=ZTF23aaojwkb&oid=ZTF21accibae&oid=ZTF20acxncha&oid=ZTF19abitbcj&oid=ZTF21abkaoxe&oid=ZTF21abhhari&oid=ZTF22abcuctb&oid=ZTF22abeodtz&oid=ZTF22abiysva&oid=ZTF22ablcfaj&oid=ZTF22aamiomf&oid=ZTF22abvebdc&oid=ZTF23aazqikj&oid=ZTF21aasctwo&oid=ZTF20acrdemq&oid=ZTF20abxzrqw&oid=ZTF19aavnwxf&oid=ZTF23abhvzbm&oid=ZTF23abclpxs&oid=ZTF21achhwdz&oid=ZTF22aaknvcz&oid=ZTF21abvyxfs&oid=ZTF22abiyeae&oid=ZTF23aapmokr&oid=ZTF23abhtsna&oid=ZTF20acezpem&oid=ZTF21acbpbia&oid=ZTF21abbcsfu&oid=ZTF21aaskwgm&oid=ZTF20acwxhka&oid=ZTF20acgzjje&oid=ZTF20abqcvtk&oid=ZTF20aaxablt&oid=ZTF19abuayqg&oid=ZTF23abkkajk&oid=ZTF22abbsbys&oid=ZTF18abdfwur&oid=ZTF21abahgst&oid=ZTF23aapswvv&oid=ZTF19acdtpow&oid=ZTF19acbqzvu&oid=ZTF21aaufvpg&oid=ZTF21aaufthj&oid=ZTF21aarmkuj&oid=ZTF20abgfvav&oid=ZTF20abewogd&oid=ZTF20aairvsi&selectedClassifier=stamp_classifier&page=1' target="_blank"> https://alerce.online/?oid=ZTF20acobvxk&oid=ZTF22aalpfln&oid=ZTF21abuyhau&oid=ZTF21abywdxt&oid=ZTF22abqdmwt&oid=ZTF23abcegjv&oid=ZTF21abufayv&oid=ZTF21achqzub&oid=ZTF22abnemvx&oid=ZTF20acoqlav&oid=ZTF23aaedsfn&oid=ZTF19aavounq&oid=ZTF23aapogvn&oid=ZTF22abhuvug&oid=ZTF19aclljyq&oid=ZTF19abahvdh&oid=ZTF21abrmefg&oid=ZTF21abaaipx&oid=ZTF20acgznau&oid=ZTF22aboisvs&oid=ZTF20aaljgcp&oid=ZTF23abfroaw&oid=ZTF20aakbtyz&oid=ZTF23abbjstt&oid=ZTF21abhtaiv&oid=ZTF22abhodtl&oid=ZTF21abbzcxe&oid=ZTF23abetodb&oid=ZTF2 ...

# %% [markdown]
# Open the link in your browser to see the explore the objects.
